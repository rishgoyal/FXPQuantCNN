# %%
import keras
from keras.datasets import mnist
import sys
sys.path.append('C:/Users/320060820/experiments/')
import os
import fxp_quantize
import model_data

from model_gen import keras_cnn
import copy

import tensorflow as tf
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

from tqdm import tnrange, tqdm_notebook

# to restart layer numbering
from keras import backend as K
K.clear_session()
# Out:
# Using TensorFlow backend.

# %%
def brute_force_analysis(model_obj, name, test_data, layer_names, bw_range, f_range, 
                         fix_quant=False, parameters=None, eval_metric='acc_drop'):
    if fix_quant and parameters is None:
        raise ValueError('parameters is empty')
    
    if not isinstance(layer_names, list):
        layer_names = [layer_names]
        
    for i in range(len(layer_names)):
        
        scores_matrix = []
        
        for j in tnrange(len(bw_range), desc=f'BW Layer {layer_names[i]}', leave=False):
            
            scores_row = []
            for k in tqdm_notebook(range(len(f_range)), desc='F', leave=False):
                
                quant_params = {
                    layer_names[i]: [bw_range[j], f_range[k]]
                }
                if fix_quant:
                    quant_params = {**quant_params, **parameters}
                
                keras_model = model_data.Model(name, test_data, model=model_obj.get_fxp_model(quant_params))
                scores_row.append(keras_model.evaluate_accuracy()[1])
                
            scores_matrix.append(scores_row)
            
        scores = np.array(scores_matrix)

        if i == 0:
            model_scores = scores
        else:
            model_scores = np.dstack((model_scores, scores))
        
        print(f'Layer {layer_names[i]} done.')
    
    model = model_data.Model(name, test_data, model=model_obj.get_float_model())
    s = model.evaluate_accuracy()[1]
    
    if eval_metric == 'acc_drop':
        model_scores = (s - model_scores) / s
        
    elif eval_metric == 'acc_ratio':
        model_scores = model_scores / s
        
    elif eval_metric == 'quant_acc':
        pass
    
    return model_scores

# %%
def plot_results(scores, layer_names, rows, columns, figsize, shrink, bw_range, f_range, invert=False, vmax=None, name=None):
    
    plt.rcParams.update({'font.size': 12, 'font.weight':520})
    if len(scores.shape) < 3:
        scores = np.expand_dims(scores, axis=3)
    fig, ax = plt.subplots(rows, columns, figsize=figsize)
    cbar_ax = fig.add_axes([.91, 0.1, .02, 0.8])
    if rows == 1 and columns == 1:
        ax = [ax]
    else:
        ax = ax.flatten()
    vmin = scores.min()
    if vmax is None:
        vmax = scores.max()
    else:
        vmax=vmax
    t = np.arange(0.0, vmax, 0.1).tolist()
    for i in range(scores.shape[2]):
        sns.heatmap(scores[:, :, i], annot=True, fmt='.3f', ax=ax[i], xticklabels=f_range, 
                    yticklabels=bw_range, vmin = vmin, vmax=vmax, cbar_ax=cbar_ax)#, cbar_kws={"ticks":t})
#         sns.heatmap(scores[:, :, i], annot=True, fmt='.2f', vmin=vmin, vmax=vmax, cbar_ax=cbar_ax)
        ax[i].set_xlabel('Fractional offset')
        ax[i].set_ylabel('Bitwidth')
        ax[i].set_title(f'Layer {layer_names[i]}')
        if invert:
            ax[i].invert_yaxis()
    if rows*columns - scores.shape[2] != 0:
        for i in range(1, rows*columns - scores.shape[2] + 1):
            fig.delaxes(ax[-i])
    if name:
        plt.savefig(f'C:/Users/320060820/OneDrive - Philips/Thesis docs/Thesis/Images/Brute force results/{name}.png', 
                    bbox_inches='tight')

# %%
input_shape = (28, 28, 1)
num_outputs = 10 # number of classes
path_trained_weights = 'C:/Users/320060820/experiments/test_models/mnist_custom/mnist_keras_w.h5'
name = 'mnist_keras'

from test_models.mnist_custom import data
_, test_data = data.get_data()

keras_mnist = keras_cnn.KerasCNN(input_shape, num_outputs, path_trained_weights)

# %%
bw_range = np.arange(1, 11, 1)
f_range = np.arange(-4, 10, 1)
layer_names = [f'conv2d_{i}' for i in range(1, 5)] + ['dense_1']

# %%
scores_1 = brute_force_analysis(keras_mnist, name, test_data, layer_names, bw_range, f_range)
# Out:
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_1', max=10, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# WARNING:tensorflow:From C:\Users\320060820\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\320060820\Anaconda3\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# Layer conv2d_1 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_2', max=10, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# Layer conv2d_2 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_3', max=10, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# Layer conv2d_3 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_4', max=10, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# Layer conv2d_4 done.
# HBox(children=(IntProgress(value=0, description='BW Layer dense_1', max=10, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# Layer dense_1 done.

# %% [markdown]
# # MNIST

# %% [markdown]
# ## Results from experiments

# %%
parameters = {
    '2_1': {
        'conv2d_1': [6, 7]
    },
    '2_2': {
        'conv2d_1': [5, 6]
    },
    '2_3': {
        'conv2d_1': [4, 5]
    },
    '3': {
        'conv2d_1': [6, 7],
        'conv2d_2': [5, 2]
    },
    '4': {
        'conv2d_1': [6, 7],
        'conv2d_2': [5, 2],
        'conv2d_3': [4, 0],
    },
    '5': {
        'conv2d_1': [6, 7],
        'conv2d_2': [5, 2],
        'conv2d_3': [4, 0],
        'conv2d_4': [3, 0]
    }
}

# %%
load_path = 'C:/Users/320060820/experiments/outputs/Brute_Force_Analysis/Activations/Keras_MNIST/'
scores_1 = np.load(load_path + 'scores_1.npy')
scores_2_1 = np.load(load_path + 'scores_2_1.npy')
scores_2_2 = np.load(load_path + 'scores_2_2.npy')
scores_2_3 = np.load(load_path + 'scores_2_3.npy')
scores_3 = np.load(load_path + 'scores_3.npy')
scores_4 = np.load(load_path + 'scores_4.npy')
scores_5 = np.load(load_path + 'scores_5.npy')

# %%
plot_results(scores_1, layer_names, 3, 2, (22, 19), 0.8, bw_range, f_range, name='keras_mnist_a')

# %%
plot_results(scores_2_1, layer_names[1:], 2, 2, (20, 15), 0.8, bw_range, f_range)

# %%
plot_results(scores_2_2, layer_names[1:], 2, 2, (20, 15), 0.8, bw_range, f_range)

# %%
plot_results(scores_2_3, layer_names[1:], 2, 2, (20, 15), 0.8, bw_range, f_range)

# %%
plot_results(scores_3, layer_names[2:], 2, 2, (20, 15), 0.8, bw_range, f_range)

# %%
plot_results(scores_4, layer_names[3:], 1, 2, (20, 7), 0.8, bw_range, f_range)

# %%
plot_results(scores_5, layer_names[4:], 1, 1, (10, 7), 0.8, bw_range, f_range)
# Out:
# C:\Users\320060820\Anaconda3\envs\tf_gpu\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   after removing the cwd from sys.path.

# %% [markdown]
# ##### Observations
#
# - Quantization of activations here is again independent as long as we quantize conservatively, trying to smallest inference accuracy drop.
# - Fixing quantization leads to some level of deviation in the values for the same bit-widths and fractional offsets. Therefore it is important to try and maintain using larger bitwidths (while still minimizing it), with minimal loss in inference accuracy, especially for the smaller layers in the network.

# %% [markdown]
# #### Observing activations after quantization

# %%
keras_model = model_data.Model(name, test_data, model=keras_mnist.get_float_model())
print(f'Floating point model accuracy: {keras_model.evaluate_accuracy()[1]}')
act_maps_before_quant = keras_model.get_activation_maps(keras_model.x_test[0].reshape(1, 28, 28, 1), 'conv2d_2')
# Out:
# Floating point model accuracy: 0.9911

# %%
parameters = {
    'conv2d_1': [6, 7],
    'conv2d_2': [5, 2],
    'conv2d_3': [4, 0],
    'conv2d_4': [3, 0],
    'dense_1': [4, -1],
}
keras_model = model_data.Model(name, test_data, model=keras_mnist.get_fxp_model(parameters))
print(f'Quantized fixed-point model accuracy: {keras_model.evaluate_accuracy()[1]}')
act_maps_after_quant = keras_model.get_activation_maps(keras_model.x_test[0].reshape(1, 28, 28, 1), 'lambda_2')
# Out:
# Quantized fixed-point model accuracy: 0.9875

# %%
fig = plt.figure(figsize=(15, 5))
plt.hist(act_maps_before_quant.flat, bins=100, label='before');
plt.hist(act_maps_after_quant.flat, bins=100, label='after');
plt.legend()

# %%
d = act_maps_after_quant - act_maps_before_quant
plt.hist(d.flat, bins=30);
plt.title('Difference in activation distributions before and after quantization');

# %%
fig, axes = plt.subplots(2, 5, figsize=(20, 6))
ax = axes.flat
for i in range(10):
    ax[i].imshow(act_maps_before_quant[0, :, :, i])

# %%
fig, axes = plt.subplots(2, 5, figsize=(20, 6))
ax = axes.flat
for i in range(10):
    ax[i].imshow(act_maps_after_quant[0, :, :, i])

# %% [markdown]
# ### Reverse Quantization

# %%
parameters = {
    '1_1': {
        'dense_1': [4, -1]
    },
    '1_2': {
        'dense_1': [3, -2]
    },
    '2': {
        'conv2d_4': [3, 0],
        'dense_1': [4, -1]
    },
    '3': {
        'conv2d_3': [4, 0],
        'conv2d_4': [3, 0],
        'dense_1': [4, -1]
    },
    '4': {
        'conv2d_2': [5, 2],
        'conv2d_3': [4, 0],
        'conv2d_4': [3, 0],
        'dense_1': [4, -1]
    }
}

# %%
scores_r1_1 = brute_force_analysis(keras_mnist, name, test_data, layer_names[:-1], bw_range, f_range,
                                fix_quant=True, parameters=parameters['1_1'])
np.save(load_path + 'scores_r1_1', arr=scores_r1_1)
# Out:
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_1', max=10, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# Layer conv2d_1 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_2', max=10, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# Layer conv2d_2 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_3', max=10, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# Layer conv2d_3 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_4', max=10, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# Layer conv2d_4 done.

# %%
scores_r1_2 = brute_force_analysis(keras_mnist, name, test_data, layer_names[:-1], bw_range, f_range,
                                fix_quant=True, parameters=parameters['1_2'])
np.save(load_path + 'scores_r1_2', arr=scores_r1_2)
# Out:
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_1', max=10, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# Layer conv2d_1 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_2', max=10, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# Layer conv2d_2 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_3', max=10, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# Layer conv2d_3 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_4', max=10, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# Layer conv2d_4 done.

# %%
scores_r2 = brute_force_analysis(keras_mnist, name, test_data, layer_names[:-2], bw_range, f_range,
                                fix_quant=True, parameters=parameters['2'])
np.save(load_path + 'scores_r2', arr=scores_r2)
# Out:
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_1', max=10, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# Layer conv2d_1 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_2', max=10, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# Layer conv2d_2 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_3', max=10, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# Layer conv2d_3 done.

# %%
scores_r3 = brute_force_analysis(keras_mnist, name, test_data, layer_names[:-3], bw_range, f_range,
                                fix_quant=True, parameters=parameters['3'])
np.save(load_path + 'scores_r3', arr=scores_r3)
# Out:
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_1', max=10, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# Layer conv2d_1 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_2', max=10, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# Layer conv2d_2 done.

# %%
scores_r4 = brute_force_analysis(keras_mnist, name, test_data, layer_names[:-4], bw_range, f_range,
                                fix_quant=True, parameters=parameters['4'])
np.save(load_path + 'scores_r4', arr=scores_r4)
# Out:
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_1', max=10, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# HBox(children=(IntProgress(value=0, description='F', max=14, style=ProgressStyle(description_width='initial'))…
# Layer conv2d_1 done.

# %%
plot_results(scores_r1_1, layer_names[:-1], 2, 2, (20, 15), 0.8, bw_range, f_range)

# %%
plot_results(scores_r1_2, layer_names[:-1], 2, 2, (20, 15), 0.8, bw_range, f_range)

# %%
plot_results(scores_r2, layer_names[:-2], 2, 2, (20, 15), 0.8, bw_range, f_range)

# %%
plot_results(scores_r3, layer_names[:-3], 1, 2, (20, 6), 0.8, bw_range, f_range)

# %%
plot_results(scores_r4, layer_names[:-4], 1, 1, (10, 6), 0.8, bw_range, f_range)
# Out:
# C:\Users\320060820\Anaconda3\envs\tf_gpu\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   after removing the cwd from sys.path.
