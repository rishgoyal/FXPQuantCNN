# %%
import sys
sys.path.append('C:/Users/320060820/experiments/')
import fxp_quantize
import model_data

import keras
import tensorflow as tf
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

from tqdm import tnrange, tqdm_notebook

# to restart layer numbering
from keras import backend as K
K.clear_session()
# Out:
# Using TensorFlow backend.

# %%
def fix_weights_quantization(model, parameters):
    
    for k in parameters.keys():
        model.model = fxp_quantize.quantize_weights(model.model, parameters[k][0], parameters[k][1],
                                                   layer_name=[k])
    return model
    

def brute_force_analysis_weights(model, layer_names, bw_range, f_range, fix_quant=False, parameters=None, 
                         eval_metric='acc_drop'):
    
    if fix_quant and parameters is None:
        raise ValueError('Parameters is empty')
    
    if not isinstance(layer_names, list):
        layer_names = [layer_names]
    
    for i in layer_names:

        scores_matrix = []

        for j in tnrange(len(bw_range), desc=f'BW Layer {i}', leave=False):
            scores_row = []
            
            for k in tqdm_notebook(range(len(f_range)), desc='F', leave=False):

                model.load_model_from_path()

                if fix_quant:
                    #fix quantization for certain layers
                    model = fix_weights_quantization(model, parameters)

                model.model = fxp_quantize.quantize_weights(model.model, bw_range[j], f_range[k],
                                                            layer_name=[i])
                scores_row.append(model.evaluate_accuracy()[1])

            scores_matrix.append(scores_row)

        scores = np.array(scores_matrix)

        if layer_names.index(i) == 0:
            model_scores = scores
        else:
            model_scores = np.dstack((model_scores, scores))
        
        print(f'Layer {i} done.')
        
    model.load_model_from_path()
    s = model.evaluate_accuracy()[1]
    
    if eval_metric == 'acc_drop':
        model_scores = (s - model_scores) / s
        
    elif eval_metric == 'acc_ratio':
        model_scores = model_scores / s
        
    elif eval_metric == 'quant_acc':
        pass
        
    return model_scores

# %%
def plot_results(scores, layer_names, rows, columns, figsize, shrink, bw_range, f_range, invert=False, vmax=None):
    
    if len(scores.shape) < 3:
        scores = np.expand_dims(scores, axis=3)
    fig, ax = plt.subplots(rows, columns, figsize=figsize)
    cbar_ax = fig.add_axes([.91, 0.1, .02, 0.8])
    if rows == 1 and columns == 1:
        ax = [ax]
    else:
        ax = ax.flatten()
    vmin = scores.min()
    if vmax is None:
        vmax = scores.max()
    else:
        vmax=vmax
    t = np.arange(0.0, vmax, 0.1).tolist()
    for i in range(scores.shape[2]):
        sns.heatmap(scores[:, :, i], annot=True, fmt='.3f', ax=ax[i], xticklabels=f_range, 
                    yticklabels=bw_range, vmin = vmin, vmax=vmax, cbar_ax=cbar_ax)#, cbar_kws={"ticks":t})
#         sns.heatmap(scores[:, :, i], annot=True, fmt='.2f', vmin=vmin, vmax=vmax, cbar_ax=cbar_ax)
        ax[i].set_xlabel('Fractional offset')
        ax[i].set_ylabel('Bitwidth')
        ax[i].set_title(f'Layer {layer_names[i]}')
        if invert:
            ax[i].invert_yaxis()
    if rows*columns - scores.shape[2] != 0:
        for i in range(1, rows*columns - scores.shape[2] + 1):
            fig.delaxes(ax[-i])

# %%
# config
save_path = 'C:/Users/320060820/experiments/test_models/'
output_path = 'C:/Users/320060820/experiments/outputs/Brute_Force_Analysis/Weights/DF_Fashion/'
bw_range = np.arange(1, 7, 1)
f_range = np.arange(-4, 4, 1)
layer_names = ['conv2d_1', 'conv2d_2', 'conv2d_3', 'conv2d_4', 'conv2d_10', 'conv2d_11', 
               'conv2d_16', 'conv2d_17', 'conv2d_19', 'conv2d_20'] + ['binary']
vmax=0.1

# %%
t_layer_names = ['conv2d_1', 'conv2d_2', 'conv2d_3', 'conv2d_5', 'conv2d_9', 'conv2d_10', 'conv2d_12', 'conv2d_19', 'binary']

# %% [markdown]
# # Fashion-MNIST

# %% [markdown]
# ## Quantizing Weights

# %%
name = 'fashion_df'
model_path = 'fashion_df/fashion_df.h5'

from test_models.fashion_df import data
_, test_data = data.get_data()

df_fashion = model_data.Model(name, test_data, path=save_path + model_path)
# Out:
# WARNING:tensorflow:From C:\Users\320060820\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\320060820\Anaconda3\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\320060820\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From C:\Users\320060820\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\ops\math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.

# %%
df_fashion.evaluate_accuracy()[1]
# Out:
# 0.9106

# %%
bw_r = np.arange(1, 3, 1)
f_r = np.arange(-4, 4, 1)
layer_names = ['conv2d_1', 'conv2d_2', 'conv2d_3', 'conv2d_4', 'conv2d_5', 'conv2d_9', 'conv2d_10', 
               'conv2d_12', 'conv2d_15', 'conv2d_16', 'conv2d_17', 'conv2d_19', 'conv2d_20', 
               'conv2d_22'] + ['binary']

# %%
s = brute_force_analysis_weights(df_fashion, layer_names, bw_r, f_r)
# Out:
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_1', max=2, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_1 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_2', max=2, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_2 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_3', max=2, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_3 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_4', max=2, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_4 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_5', max=2, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_5 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_9', max=2, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_9 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_10', max=2, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_10 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_12', max=2, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_12 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_15', max=2, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_15 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_16', max=2, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_16 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_17', max=2, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_17 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_19', max=2, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_19 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_20', max=2, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_20 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_22', max=2, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_22 done.
# HBox(children=(IntProgress(value=0, description='BW Layer binary', max=2, style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer binary done.

# %%
plot_results(s, layer_names, 5, 3, (20, 25), 0.8, bw_r, f_r)

# %%
scores_1 = brute_force_analysis_weights(df_fashion, t_layer_names, bw_range, f_range)
np.save(output_path + 'scores_1', arr=scores_1)
# Out:
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_1', max=6, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_1 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_2', max=6, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_2 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_3', max=6, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_3 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_5', max=6, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_5 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_9', max=6, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_9 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_10', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_10 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_12', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_12 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_19', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_19 done.
# HBox(children=(IntProgress(value=0, description='BW Layer binary', max=6, style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer binary done.

# %%
plot_results(scores_1, t_layer_names, 3, 3, (20, 20), 0.8, bw_range, f_range)

# %%
params = {
    'conv2d_1': [6, 3]
}
scores_2 = brute_force_analysis_weights(df_fashion, t_layer_names[1:], bw_range, f_range, fix_quant=True, parameters=params)
np.save(output_path + 'scores_2', arr=scores_2)
# Out:
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_2', max=6, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_2 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_3', max=6, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_3 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_5', max=6, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_5 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_9', max=6, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_9 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_10', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_10 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_12', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_12 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_19', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_19 done.
# HBox(children=(IntProgress(value=0, description='BW Layer binary', max=6, style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer binary done.

# %%
plot_results(scores_2, t_layer_names[1:], 3, 3, (20, 20), 0.8, bw_range, f_range)

# %%
params = {
    'conv2d_1': [4, 1]
}
scores_2_alt = brute_force_analysis_weights(df_fashion, t_layer_names[1:], bw_range, f_range, fix_quant=True, parameters=params)
np.save(output_path + 'scores_2_alt', arr=scores_2_alt)
# Out:
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_2', max=6, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_2 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_3', max=6, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_3 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_5', max=6, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_5 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_9', max=6, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_9 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_10', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_10 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_12', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_12 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_19', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_19 done.
# HBox(children=(IntProgress(value=0, description='BW Layer binary', max=6, style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer binary done.

# %%
plot_results(scores_2_alt, t_layer_names[1:], 3, 3, (20, 20), 0.8, bw_range, f_range)

# %%
params = {
    'conv2d_1': [6, 3],
    'conv2d_2': [3, 0]
}
scores_3 = brute_force_analysis_weights(df_fashion, t_layer_names[2:], bw_range, f_range, fix_quant=True, parameters=params)
np.save(output_path + 'scores_3', arr=scores_3)
# Out:
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_3', max=6, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_3 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_5', max=6, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_5 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_9', max=6, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_9 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_10', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_10 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_12', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_12 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_19', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_19 done.
# HBox(children=(IntProgress(value=0, description='BW Layer binary', max=6, style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer binary done.

# %%
plot_results(scores_3, t_layer_names[2:], 3, 3, (20, 20), 0.8, bw_range, f_range)

# %%
params = {
    'conv2d_1': [6, 3],
    'conv2d_2': [2, -1]
}
scores_3_alt = brute_force_analysis_weights(df_fashion, t_layer_names[2:], bw_range, f_range, fix_quant=True, parameters=params)
np.save(output_path + 'scores_3_alt', arr=scores_3_alt)
# Out:
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_3', max=6, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_3 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_5', max=6, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_5 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_9', max=6, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_9 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_10', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_10 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_12', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_12 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_19', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_19 done.
# HBox(children=(IntProgress(value=0, description='BW Layer binary', max=6, style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer binary done.

# %%
plot_results(scores_3_alt, t_layer_names[2:], 3, 3, (20, 20), 0.8, bw_range, f_range)

# %%
params = {
    'conv2d_1': [6, 3],
    'conv2d_2': [3, 0],
    'conv2d_3': [3, 0]
}
scores_4 = brute_force_analysis_weights(df_fashion, t_layer_names[3:], bw_range, f_range, fix_quant=True, parameters=params)
np.save(output_path + 'scores_4', arr=scores_4)
# Out:
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_5', max=6, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_5 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_9', max=6, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_9 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_10', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_10 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_12', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_12 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_19', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_19 done.
# HBox(children=(IntProgress(value=0, description='BW Layer binary', max=6, style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer binary done.

# %%
plot_results(scores_4, t_layer_names[3:], 2, 3, (20, 15), 0.8, bw_range, f_range)

# %%
params = {
    'conv2d_1': [6, 3],
    'conv2d_2': [3, 0],
    'conv2d_3': [3, 0],
    'conv2d_5': [3, -1]
}
scores_5 = brute_force_analysis_weights(df_fashion, t_layer_names[4:], bw_range, f_range, fix_quant=True, parameters=params)
np.save(output_path + 'scores_5', arr=scores_5)
# Out:
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_9', max=6, style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_9 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_10', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_10 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_12', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_12 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_19', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_19 done.
# HBox(children=(IntProgress(value=0, description='BW Layer binary', max=6, style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer binary done.

# %%
plot_results(scores_5, t_layer_names[4:], 2, 3, (20, 15), 0.8, bw_range, f_range)

# %%
params = {
    'conv2d_1': [6, 3],
    'conv2d_2': [3, 0],
    'conv2d_3': [3, 0],
    'conv2d_5': [3, -1],
    'conv2d_9': [2, -2]
}
scores_6 = brute_force_analysis_weights(df_fashion, t_layer_names[5:], bw_range, f_range, fix_quant=True, parameters=params)
np.save(output_path + 'scores_6', arr=scores_6)
# Out:
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_10', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_10 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_12', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_12 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_19', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_19 done.
# HBox(children=(IntProgress(value=0, description='BW Layer binary', max=6, style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer binary done.

# %%
plot_results(scores_6, t_layer_names[5:], 2, 2, (20, 15), 0.8, bw_range, f_range)

# %%
params = {
    'conv2d_1': [6, 3],
    'conv2d_2': [3, 0],
    'conv2d_3': [3, 0],
    'conv2d_5': [3, -1],
    'conv2d_9': [2, -2],
    'conv2d_10': [3, -1]
}
scores_7 = brute_force_analysis_weights(df_fashion, t_layer_names[6:], bw_range, f_range, fix_quant=True, parameters=params)
np.save(output_path + 'scores_7', arr=scores_7)
# Out:
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_12', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_12 done.
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_19', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_19 done.
# HBox(children=(IntProgress(value=0, description='BW Layer binary', max=6, style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer binary done.

# %%
plot_results(scores_7, t_layer_names[6:], 2, 2, (20, 15), 0.8, bw_range, f_range)

# %%
params = {
    'conv2d_1': [6, 3],
    'conv2d_2': [3, 0],
    'conv2d_3': [3, 0],
    'conv2d_5': [3, -1],
    'conv2d_9': [2, -2],
    'conv2d_10': [3, -1],
    'conv2d_12': [3, -1]
}
scores_8 = brute_force_analysis_weights(df_fashion, t_layer_names[7:], bw_range, f_range, fix_quant=True, parameters=params)
np.save(output_path + 'scores_8', arr=scores_8)
# Out:
# HBox(children=(IntProgress(value=0, description='BW Layer conv2d_19', max=6, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer conv2d_19 done.
# HBox(children=(IntProgress(value=0, description='BW Layer binary', max=6, style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer binary done.

# %%
plot_results(scores_8, t_layer_names[7:], 1, 2, (20, 6), 0.8, bw_range, f_range)

# %%
params = {
    'conv2d_1': [6, 3],
    'conv2d_2': [3, 0],
    'conv2d_3': [3, 0],
    'conv2d_5': [3, -1],
    'conv2d_9': [2, -2],
    'conv2d_10': [3, -1],
    'conv2d_12': [3, -1],
    'conv2d_19': [3, 0]
}
scores_9 = brute_force_analysis_weights(df_fashion, t_layer_names[8:], bw_range, f_range, fix_quant=True, parameters=params)
np.save(output_path + 'scores_9', arr=scores_9)
# Out:
# HBox(children=(IntProgress(value=0, description='BW Layer binary', max=6, style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='F', max=8, style=ProgressStyle(description_width='initial')),…
# Layer binary done.

# %%
plot_results(scores_9, t_layer_names[8:], 1, 1, (10, 7), 0.8, bw_range, f_range)
# Out:
# C:\Users\320060820\Anaconda3\envs\tf_gpu\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   after removing the cwd from sys.path.
