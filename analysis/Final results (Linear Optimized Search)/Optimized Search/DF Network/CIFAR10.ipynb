# %%
import sys
sys.path.append('C:/Users/320060820/experiments/')
import fxp_quantize
import model_data
from algorithms import fixed_bitwidth
from model_gen import inception_cnn
from algorithms.optimized_search import OptimizedSearch
import evaluation_metrics

import keras
import tensorflow as tf
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import pandas as pd
import pickle

# to restart layer numbering
from keras import backend as K
K.clear_session()
# Out:
# Using TensorFlow backend.

# %%
# Functions specific to this file
def save_results(scores, acc_drop, opt_params, output_path):
    
    with open(output_path + f'opt_params.p', 'wb') as f:
        pickle.dump(opt_params, f)
    
    with open(output_path + f'acc_drop.p', 'wb') as f:
        pickle.dump(acc_drop, f)
    
    with open(output_path + f'scores.p', 'wb') as f:
        pickle.dump(scores, f)

# %%
input_shape = (96, 96, 3)
num_outputs = 10 # number of classes
path_trained_weights = 'C:/Users/320060820/experiments/test_models/cifar_df2/model_32_0.75_w.h5'
output_path = 'C:/Users/320060820/experiments/outputs/Comp_Dependent_Optimized_Search/DF CIFAR10/'
name = 'cifar_df'
total_acc_drop = 0.005

from test_models.cifar_df2 import data
_, test_data = data.get_data()

model_arch = inception_cnn.InceptionCNN(input_shape, num_outputs, dropout=True, 
                                        pool_layer_type='max', path_trained_weights=path_trained_weights)
model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
float_model_acc = model_obj.evaluate_accuracy()[1]
print(float_model_acc)
# Out:
# WARNING:tensorflow:From C:\Users\320060820\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\320060820\Anaconda3\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
layer_num = [1, 5, 3, 8, 2, 6, 4, 7, 12, 10, 15, 9, 13, 11, 14, 19, 17, 22, 16, 20, 18, 21]
layer_names = [f'conv2d_{i}' for i in layer_num] + ['binary']

# %%
linear = lambda x, total_acc_drop, num_layers, offset=0: total_acc_drop/num_layers * x + offset

# %%
x = np.arange(1, len(layer_names) + 1)
plt.figure(figsize=(10, 7));
plt.title('Ideal budget allocation per layer for weights and activations');
y1 = linear(x, total_acc_drop, len(layer_names))
y2 = linear(x, total_acc_drop, len(layer_names), total_acc_drop)
plt.plot(x, y1, 'o-', label='Component 1');
plt.plot(x, y2, 'o-', label='Component 2');
plt.xticks(x, layer_names, rotation='vertical')
plt.plot(x, np.ones(y2.shape) * total_acc_drop, label='(total) Component 1 budget');
plt.plot(x, np.ones(y2.shape) * total_acc_drop*2, label='(total) Component 2 budget')
plt.grid();
plt.legend();

# %%
acc_drop_config = {
    layer_names[i - 1]: linear(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(model_arch, name, test_data, float_model_acc)
w_scores, opt_params_weights, acc_drop_w = opts.run(acc_drop_config, 'weights', start_bw = 12)
# Out:
# {'conv2d_1': [12, 8], 'conv2d_5': [12, 8], 'conv2d_3': [12, 8], 'conv2d_6': [12, 8], 'conv2d_2': [12, 8], 'conv2d_4': [12, 8], 'conv2d_7': [12, 8], 'conv2d_8': [12, 8], 'conv2d_12': [12, 8], 'conv2d_10': [12, 7], 'conv2d_13': [12, 8], 'conv2d_9': [12, 7], 'conv2d_11': [12, 7], 'conv2d_14': [12, 8], 'conv2d_15': [12, 8], 'conv2d_19': [12, 7], 'conv2d_17': [12, 8], 'conv2d_20': [12, 7], 'conv2d_16': [12, 8], 'conv2d_18': [12, 8], 'conv2d_21': [12, 8], 'conv2d_22': [12, 8], 'binary': [12, 10]}
# Quantizing layer conv2d_1
# Global opt: (10, 7) Local opt: (9, 6) Performance diff: 0.000403
# Chosen:  (9, 6)
# After quantizing weights of layer conv2d_1 | Measured accuracy drop -0.000805 | Acceptable accuracy drop: 0.000217
# Quantizing layer conv2d_5
# Global opt: (3, 0) Local opt: (4, 0) Performance diff: 0.000134
# Chosen:  (3, 0)
# After quantizing weights of layer conv2d_5 | Measured accuracy drop -0.001744 | Acceptable accuracy drop: 0.000435
# Quantizing layer conv2d_3
# Global opt: (4, 1) Local opt: (5, 1) Performance diff: 0.003892
# Chosen:  (5, 1)
# After quantizing weights of layer conv2d_3 | Measured accuracy drop -0.003623 | Acceptable accuracy drop: 0.000652
# Quantizing layer conv2d_8
# Global opt: (1, -3) Local opt: (2, -3) Performance diff: 0.001476
# Chosen:  (1, -3)
# After quantizing weights of layer conv2d_8 | Measured accuracy drop -0.002684 | Acceptable accuracy drop: 0.000870
# Quantizing layer conv2d_2
# Global opt: (4, 1) Local opt: (5, 1) Performance diff: 0.001074
# Chosen:  (4, 1)
# After quantizing weights of layer conv2d_2 | Measured accuracy drop -0.005368 | Acceptable accuracy drop: 0.001087
# Quantizing layer conv2d_6
# Global opt: (3, 0) Local opt: (4, 1) Performance diff: 0.006978
# Chosen:  (4, 1)
# After quantizing weights of layer conv2d_6 | Measured accuracy drop -0.006307 | Acceptable accuracy drop: 0.001304
# Quantizing layer conv2d_4
# Global opt: (4, 1) Local opt: (5, 2) Performance diff: 0.000671
# Chosen:  (4, 1)
# After quantizing weights of layer conv2d_4 | Measured accuracy drop -0.003489 | Acceptable accuracy drop: 0.001522
# Quantizing layer conv2d_7
# Global opt: (3, 0) Local opt: (4, 1) Performance diff: 0.002013
# Chosen:  (4, 1)
# After quantizing weights of layer conv2d_7 | Measured accuracy drop -0.004965 | Acceptable accuracy drop: 0.001739
# Quantizing layer conv2d_12
# Global opt: (3, -1) Local opt: (3, -1) Performance diff: 0.000000
# Chosen:  (3, -1)
# After quantizing weights of layer conv2d_12 | Measured accuracy drop -0.003086 | Acceptable accuracy drop: 0.001957
# Quantizing layer conv2d_10
# Global opt: (4, 0) Local opt: (5, 0) Performance diff: 0.001208
# Chosen:  (4, 0)
# After quantizing weights of layer conv2d_10 | Measured accuracy drop -0.001476 | Acceptable accuracy drop: 0.002174
# Quantizing layer conv2d_15
# Global opt: (2, -2) Local opt: (2, -2) Performance diff: 0.000000
# Chosen:  (2, -2)
# After quantizing weights of layer conv2d_15 | Measured accuracy drop -0.000134 | Acceptable accuracy drop: 0.002391
# Quantizing layer conv2d_9
# Global opt: (3, -1) Local opt: (3, -1) Performance diff: 0.000000
# Chosen:  (3, -1)
# After quantizing weights of layer conv2d_9 | Measured accuracy drop 0.000671 | Acceptable accuracy drop: 0.002609
# Quantizing layer conv2d_13
# Global opt: (3, -1) Local opt: (3, -1) Performance diff: 0.000000
# Chosen:  (3, -1)
# After quantizing weights of layer conv2d_13 | Measured accuracy drop -0.007515 | Acceptable accuracy drop: 0.002826
# Quantizing layer conv2d_11
# Global opt: (4, 0) Local opt: (5, 1) Performance diff: 0.006978
# Chosen:  (5, 1)
# After quantizing weights of layer conv2d_11 | Measured accuracy drop -0.008991 | Acceptable accuracy drop: 0.003043
# Quantizing layer conv2d_14
# Global opt: (4, 0) Local opt: (5, 1) Performance diff: 0.002818
# Chosen:  (5, 1)
# After quantizing weights of layer conv2d_14 | Measured accuracy drop -0.008052 | Acceptable accuracy drop: 0.003261
# Quantizing layer conv2d_19
# Global opt: (4, 0) Local opt: (5, 1) Performance diff: 0.002952
# Chosen:  (5, 1)
# After quantizing weights of layer conv2d_19 | Measured accuracy drop -0.006039 | Acceptable accuracy drop: 0.003478
# Quantizing layer conv2d_17
# Global opt: (3, 0) Local opt: (4, 0) Performance diff: 0.004697
# Chosen:  (4, 0)
# After quantizing weights of layer conv2d_17 | Measured accuracy drop -0.003489 | Acceptable accuracy drop: 0.003696
# Quantizing layer conv2d_22
# Global opt: (2, -2) Local opt: (3, -1) Performance diff: 0.004160
# Chosen:  (3, -1)
# After quantizing weights of layer conv2d_22 | Measured accuracy drop -0.004294 | Acceptable accuracy drop: 0.003913
# Quantizing layer conv2d_16
# Global opt: (3, -1) Local opt: (4, 0) Performance diff: 0.004160
# Chosen:  (4, 0)
# After quantizing weights of layer conv2d_16 | Measured accuracy drop -0.003892 | Acceptable accuracy drop: 0.004130
# Quantizing layer conv2d_20
# Global opt: (5, 1) Local opt: (6, 1) Performance diff: 0.006844
# Chosen:  (6, 1)
# After quantizing weights of layer conv2d_20 | Measured accuracy drop -0.004160 | Acceptable accuracy drop: 0.004348
# Quantizing layer conv2d_18
# Global opt: (4, 0) Local opt: (4, 1) Performance diff: 0.007381
# Chosen:  (4, 1)
# After quantizing weights of layer conv2d_18 | Measured accuracy drop -0.004697 | Acceptable accuracy drop: 0.004565
# Quantizing layer conv2d_21
# Global opt: (4, 0) Local opt: (4, 0) Performance diff: 0.000000
# Chosen:  (4, 0)
# After quantizing weights of layer conv2d_21 | Measured accuracy drop -0.004965 | Acceptable accuracy drop: 0.004783
# Quantizing layer binary
# Global opt: (3, 2) Local opt: (4, 3) Performance diff: 0.004428
# Chosen:  (4, 3)
# After quantizing weights of layer binary | Measured accuracy drop -0.003757 | Acceptable accuracy drop: 0.005000

# %%
opts.plot_scores_matrix(w_scores, 12, 2, (20, 75))

# %%
opts.quant_evaluator.quant_params
# Out:
# QuantizationParameters(weights={'conv2d_1': (9, 6), 'conv2d_5': (3, 0), 'conv2d_3': (5, 1), 'conv2d_8': (1, -3), 'conv2d_2': (4, 1), 'conv2d_6': (4, 1), 'conv2d_4': (4, 1), 'conv2d_7': (4, 1), 'conv2d_12': (3, -1), 'conv2d_10': (4, 0), 'conv2d_15': (2, -2), 'conv2d_9': (3, -1), 'conv2d_13': (3, -1), 'conv2d_11': (5, 1), 'conv2d_14': (5, 1), 'conv2d_19': (5, 1), 'conv2d_17': (4, 0), 'conv2d_22': (3, -1), 'conv2d_16': (4, 0), 'conv2d_20': (6, 1), 'conv2d_18': (4, 1), 'conv2d_21': (4, 0), 'binary': (4, 3)}, biases={}, activations={})

# %%
acc_drop_config = {
    layer_names[i - 1]: total_acc_drop for i in range(1, len(layer_names) + 1)
}

b_scores, opt_params_biases, acc_drop_b = opts.run(acc_drop_config, 'biases', start_bw = 8)
opts.plot_scores_matrix(b_scores, 12, 2, (20, 75))
# Out:
# {'conv2d_1': [8, 6], 'conv2d_5': [8, 5], 'conv2d_3': [8, 5], 'conv2d_6': [8, 5], 'conv2d_2': [8, 5], 'conv2d_4': [8, 5], 'conv2d_7': [8, 5], 'conv2d_8': [8, 5], 'conv2d_12': [8, 5], 'conv2d_10': [8, 5], 'conv2d_13': [8, 6], 'conv2d_9': [8, 5], 'conv2d_11': [8, 5], 'conv2d_14': [8, 5], 'conv2d_15': [8, 4], 'conv2d_19': [8, 5], 'conv2d_17': [8, 5], 'conv2d_20': [8, 5], 'conv2d_16': [8, 4], 'conv2d_18': [8, 5], 'conv2d_21': [8, 5], 'conv2d_22': [8, 4], 'binary': [8, 6]}
# Quantizing layer conv2d_1
# Global opt: (4, 2) Local opt: (4, 2) Performance diff: 0.000000
# Chosen:  (4, 2)
# After quantizing biases of layer conv2d_1 | Measured accuracy drop -0.002818 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_5
# Global opt: (1, -2) Local opt: (2, -2) Performance diff: 0.003623
# Chosen:  (2, -2)
# After quantizing biases of layer conv2d_5 | Measured accuracy drop -0.002550 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_3
# Global opt: (1, -2) Local opt: (2, -2) Performance diff: 0.011004
# Chosen:  (2, -2)
# After quantizing biases of layer conv2d_3 | Measured accuracy drop -0.007515 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_8
# Global opt: (1, -2) Local opt: (2, -1) Performance diff: 0.001342
# Chosen:  (1, -2)
# After quantizing biases of layer conv2d_8 | Measured accuracy drop -0.005904 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_2
# Global opt: (1, -2) Local opt: (2, -1) Performance diff: 0.007917
# Chosen:  (2, -1)
# After quantizing biases of layer conv2d_2 | Measured accuracy drop -0.005770 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_6
# Global opt: (1, -2) Local opt: (2, -2) Performance diff: 0.000537
# Chosen:  (1, -2)
# After quantizing biases of layer conv2d_6 | Measured accuracy drop -0.005904 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_4
# Global opt: (1, -2) Local opt: (2, -2) Performance diff: 0.000671
# Chosen:  (1, -2)
# After quantizing biases of layer conv2d_4 | Measured accuracy drop -0.006173 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_7
# Global opt: (1, -2) Local opt: (2, -1) Performance diff: 0.000537
# Chosen:  (1, -2)
# After quantizing biases of layer conv2d_7 | Measured accuracy drop -0.004428 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_12
# Global opt: (1, -2) Local opt: (2, -2) Performance diff: 0.002684
# Chosen:  (2, -2)
# After quantizing biases of layer conv2d_12 | Measured accuracy drop -0.004428 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_10
# Global opt: (1, -2) Local opt: (2, -1) Performance diff: 0.003489
# Chosen:  (2, -1)
# After quantizing biases of layer conv2d_10 | Measured accuracy drop -0.003355 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_15
# Global opt: (1, -3) Local opt: (1, -4) Performance diff: 0.000000
# Chosen:  (1, -4)
# After quantizing biases of layer conv2d_15 | Measured accuracy drop -0.003086 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_9
# Global opt: (1, -2) Local opt: (2, -1) Performance diff: 0.000403
# Chosen:  (1, -2)
# After quantizing biases of layer conv2d_9 | Measured accuracy drop -0.001744 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_13
# Global opt: (1, -1) Local opt: (2, 0) Performance diff: 0.000537
# Chosen:  (1, -1)
# After quantizing biases of layer conv2d_13 | Measured accuracy drop -0.001476 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_11
# Global opt: (1, -2) Local opt: (2, -2) Performance diff: 0.000403
# Chosen:  (1, -2)
# After quantizing biases of layer conv2d_11 | Measured accuracy drop -0.001610 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_14
# Global opt: (1, -2) Local opt: (2, -2) Performance diff: 0.000403
# Chosen:  (1, -2)
# After quantizing biases of layer conv2d_14 | Measured accuracy drop -0.001610 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_19
# Global opt: (1, -2) Local opt: (2, -2) Performance diff: 0.000403
# Chosen:  (1, -2)
# After quantizing biases of layer conv2d_19 | Measured accuracy drop -0.002415 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_17
# Global opt: (1, -2) Local opt: (2, -1) Performance diff: 0.001342
# Chosen:  (1, -2)
# After quantizing biases of layer conv2d_17 | Measured accuracy drop -0.000805 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_22
# Global opt: (1, -3) Local opt: (2, -2) Performance diff: 0.000134
# Chosen:  (1, -3)
# After quantizing biases of layer conv2d_22 | Measured accuracy drop -0.000939 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_16
# Global opt: (1, -3) Local opt: (2, -3) Performance diff: 0.001342
# Chosen:  (1, -3)
# After quantizing biases of layer conv2d_16 | Measured accuracy drop -0.001744 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_20
# Global opt: (1, -2) Local opt: (2, -2) Performance diff: 0.000537
# Chosen:  (1, -2)
# After quantizing biases of layer conv2d_20 | Measured accuracy drop -0.003221 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_18
# Global opt: (1, -2) Local opt: (2, -1) Performance diff: 0.001208
# Chosen:  (1, -2)
# After quantizing biases of layer conv2d_18 | Measured accuracy drop -0.002684 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_21
# Global opt: (1, -2) Local opt: (1, -3) Performance diff: 0.000000
# Chosen:  (1, -3)
# After quantizing biases of layer conv2d_21 | Measured accuracy drop -0.002684 | Acceptable accuracy drop: 0.005000
# Quantizing layer binary
# Global opt: (2, 0) Local opt: (3, 1) Performance diff: 0.003086
# Chosen:  (3, 1)
# After quantizing biases of layer binary | Measured accuracy drop -0.002147 | Acceptable accuracy drop: 0.005000

# %%
opts.quant_evaluator.quant_params
# Out:
# QuantizationParameters(weights={'conv2d_1': (9, 6), 'conv2d_5': (3, 0), 'conv2d_3': (5, 1), 'conv2d_8': (1, -3), 'conv2d_2': (4, 1), 'conv2d_6': (4, 1), 'conv2d_4': (4, 1), 'conv2d_7': (4, 1), 'conv2d_12': (3, -1), 'conv2d_10': (4, 0), 'conv2d_15': (2, -2), 'conv2d_9': (3, -1), 'conv2d_13': (3, -1), 'conv2d_11': (5, 1), 'conv2d_14': (5, 1), 'conv2d_19': (5, 1), 'conv2d_17': (4, 0), 'conv2d_22': (3, -1), 'conv2d_16': (4, 0), 'conv2d_20': (6, 1), 'conv2d_18': (4, 1), 'conv2d_21': (4, 0), 'binary': (4, 3)}, biases={'conv2d_1': (4, 2), 'conv2d_5': (2, -2), 'conv2d_3': (2, -2), 'conv2d_8': (1, -2), 'conv2d_2': (2, -1), 'conv2d_6': (1, -2), 'conv2d_4': (1, -2), 'conv2d_7': (1, -2), 'conv2d_12': (2, -2), 'conv2d_10': (2, -1), 'conv2d_15': (1, -4), 'conv2d_9': (1, -2), 'conv2d_13': (1, -1), 'conv2d_11': (1, -2), 'conv2d_14': (1, -2), 'conv2d_19': (1, -2), 'conv2d_17': (1, -2), 'conv2d_22': (1, -3), 'conv2d_16': (1, -3), 'conv2d_20': (1, -2), 'conv2d_18': (1, -2), 'conv2d_21': (1, -3), 'binary': (3, 1)}, activations={})

# %%
acc_drop_config = {
    layer_names[i - 1]: linear(i, total_acc_drop, len(layer_names), total_acc_drop) for i in range(1, len(layer_names) + 1)
}

a_scores, opt_params_act, acc_drop_a = opts.run(acc_drop_config, 'activations', start_bw = 12)
opts.plot_scores_matrix(a_scores, 12, 2, (20, 75))
# Out:
# {'conv2d_1': [12, 6], 'conv2d_5': [12, 5], 'conv2d_3': [12, 5], 'conv2d_6': [12, 2], 'conv2d_2': [12, 5], 'conv2d_4': [12, 1], 'conv2d_7': [12, 1], 'conv2d_8': [12, 5], 'conv2d_12': [12, 2], 'conv2d_10': [12, 2], 'conv2d_13': [12, 1], 'conv2d_9': [12, 2], 'conv2d_11': [12, 1], 'conv2d_14': [12, 1], 'conv2d_15': [12, 1], 'conv2d_19': [12, 2], 'conv2d_17': [12, 2], 'conv2d_20': [12, 1], 'conv2d_16': [12, 2], 'conv2d_18': [12, 1], 'conv2d_21': [12, 1], 'conv2d_22': [12, 2], 'binary': [12, 6]}
# Quantizing layer conv2d_1
# Global opt: (7, 2) Local opt: (8, 3) Performance diff: 0.003892
# Chosen:  (8, 3)
# After quantizing activations of layer conv2d_1 | Measured accuracy drop 0.000537 | Acceptable accuracy drop: 0.005217
# Quantizing layer conv2d_5
# Global opt: (5, -1) Local opt: (5, -1) Performance diff: 0.000000
# Chosen:  (5, -1)
# After quantizing activations of layer conv2d_5 | Measured accuracy drop 0.002147 | Acceptable accuracy drop: 0.005435
# Quantizing layer conv2d_3
# Global opt: (7, 0) Local opt: (8, 1) Performance diff: 0.000805
# Chosen:  (7, 0)
# After quantizing activations of layer conv2d_3 | Measured accuracy drop 0.003892 | Acceptable accuracy drop: 0.005652
# Quantizing layer conv2d_8
# Global opt: (1, -6) Local opt: (1, -7) Performance diff: 0.000000
# Chosen:  (1, -7)
# After quantizing activations of layer conv2d_8 | Measured accuracy drop 0.003892 | Acceptable accuracy drop: 0.005870
# Quantizing layer conv2d_2
# Global opt: (5, -2) Local opt: (6, -1) Performance diff: 0.002281
# Chosen:  (6, -1)
# After quantizing activations of layer conv2d_2 | Measured accuracy drop 0.003757 | Acceptable accuracy drop: 0.006087
# Quantizing layer conv2d_6
# Global opt: (5, -3) Local opt: (6, -2) Performance diff: 0.001879
# Chosen:  (6, -2)
# After quantizing activations of layer conv2d_6 | Measured accuracy drop 0.004026 | Acceptable accuracy drop: 0.006304
# Quantizing layer conv2d_4
# Global opt: (6, -3) Local opt: (7, -3) Performance diff: 0.000268
# Chosen:  (6, -3)
# After quantizing activations of layer conv2d_4 | Measured accuracy drop 0.004026 | Acceptable accuracy drop: 0.006522
# Quantizing layer conv2d_7
# Global opt: (4, -5) Local opt: (5, -4) Performance diff: 0.000671
# Chosen:  (4, -5)
# After quantizing activations of layer conv2d_7 | Measured accuracy drop 0.004965 | Acceptable accuracy drop: 0.006739
# Quantizing layer conv2d_12
# Global opt: (2, -6) Local opt: (3, -6) Performance diff: 0.001744
# Chosen:  (3, -6)
# After quantizing activations of layer conv2d_12 | Measured accuracy drop 0.003892 | Acceptable accuracy drop: 0.006957
# Quantizing layer conv2d_10
# Global opt: (5, -4) Local opt: (6, -4) Performance diff: 0.000134
# Chosen:  (5, -4)
# After quantizing activations of layer conv2d_10 | Measured accuracy drop 0.002147 | Acceptable accuracy drop: 0.007174
# Quantizing layer conv2d_15
# Global opt: (2, -5) Local opt: (2, -5) Performance diff: 0.000000
# Chosen:  (2, -5)
# After quantizing activations of layer conv2d_15 | Measured accuracy drop -0.000537 | Acceptable accuracy drop: 0.007391
# Quantizing layer conv2d_9
# Global opt: (3, -4) Local opt: (4, -4) Performance diff: 0.001074
# Chosen:  (3, -4)
# After quantizing activations of layer conv2d_9 | Measured accuracy drop 0.003623 | Acceptable accuracy drop: 0.007609
# Quantizing layer conv2d_13
# Global opt: (5, -6) Local opt: (6, -5) Performance diff: 0.000537
# Chosen:  (5, -6)
# After quantizing activations of layer conv2d_13 | Measured accuracy drop 0.004294 | Acceptable accuracy drop: 0.007826
# Quantizing layer conv2d_11
# Global opt: (6, -4) Local opt: (7, -3) Performance diff: 0.002415
# Chosen:  (7, -3)
# After quantizing activations of layer conv2d_11 | Measured accuracy drop 0.003355 | Acceptable accuracy drop: 0.008043
# Quantizing layer conv2d_14
# Global opt: (4, -6) Local opt: (5, -5) Performance diff: 0.001744
# Chosen:  (5, -5)
# After quantizing activations of layer conv2d_14 | Measured accuracy drop 0.004563 | Acceptable accuracy drop: 0.008261
# Quantizing layer conv2d_19
# Global opt: (5, -4) Local opt: (6, -3) Performance diff: 0.002281
# Chosen:  (6, -3)
# After quantizing activations of layer conv2d_19 | Measured accuracy drop 0.004831 | Acceptable accuracy drop: 0.008478
# Quantizing layer conv2d_17
# Global opt: (4, -4) Local opt: (5, -4) Performance diff: 0.000537
# Chosen:  (4, -4)
# After quantizing activations of layer conv2d_17 | Measured accuracy drop 0.004160 | Acceptable accuracy drop: 0.008696
# Quantizing layer conv2d_22
# Global opt: (2, -8) Local opt: (2, -7) Performance diff: 0.003623
# Chosen:  (2, -7)
# After quantizing activations of layer conv2d_22 | Measured accuracy drop 0.004294 | Acceptable accuracy drop: 0.008913
# Quantizing layer conv2d_16
# Global opt: (3, -6) Local opt: (4, -5) Performance diff: 0.002684
# Chosen:  (4, -5)
# After quantizing activations of layer conv2d_16 | Measured accuracy drop 0.006307 | Acceptable accuracy drop: 0.009130
# Quantizing layer conv2d_20
# Global opt: (6, -5) Local opt: (6, -5) Performance diff: 0.000000
# Chosen:  (6, -5)
# After quantizing activations of layer conv2d_20 | Measured accuracy drop 0.007515 | Acceptable accuracy drop: 0.009348
# Quantizing layer conv2d_18
# Global opt: (6, -5) Local opt: (7, -4) Performance diff: 0.000403
# Chosen:  (6, -5)
# After quantizing activations of layer conv2d_18 | Measured accuracy drop 0.009259 | Acceptable accuracy drop: 0.009565
# Quantizing layer conv2d_21
# Global opt: (10, -1) Local opt: (10, -1) Performance diff: 0.000000
# Chosen:  (10, -1)
# After quantizing activations of layer conv2d_21 | Measured accuracy drop 0.008991 | Acceptable accuracy drop: 0.009783
# Quantizing layer binary
# Global opt: (11, 6) Local opt: (11, 6) Performance diff: 0.000000
# Chosen:  (11, 6)
# After quantizing activations of layer binary | Measured accuracy drop 0.009930 | Acceptable accuracy drop: 0.010000

# %%
opts.quant_evaluator.quant_params
# Out:
# QuantizationParameters(weights={'conv2d_1': (9, 6), 'conv2d_5': (3, 0), 'conv2d_3': (5, 1), 'conv2d_8': (1, -3), 'conv2d_2': (4, 1), 'conv2d_6': (4, 1), 'conv2d_4': (4, 1), 'conv2d_7': (4, 1), 'conv2d_12': (3, -1), 'conv2d_10': (4, 0), 'conv2d_15': (2, -2), 'conv2d_9': (3, -1), 'conv2d_13': (3, -1), 'conv2d_11': (5, 1), 'conv2d_14': (5, 1), 'conv2d_19': (5, 1), 'conv2d_17': (4, 0), 'conv2d_22': (3, -1), 'conv2d_16': (4, 0), 'conv2d_20': (6, 1), 'conv2d_18': (4, 1), 'conv2d_21': (4, 0), 'binary': (4, 3)}, biases={'conv2d_1': (4, 2), 'conv2d_5': (2, -2), 'conv2d_3': (2, -2), 'conv2d_8': (1, -2), 'conv2d_2': (2, -1), 'conv2d_6': (1, -2), 'conv2d_4': (1, -2), 'conv2d_7': (1, -2), 'conv2d_12': (2, -2), 'conv2d_10': (2, -1), 'conv2d_15': (1, -4), 'conv2d_9': (1, -2), 'conv2d_13': (1, -1), 'conv2d_11': (1, -2), 'conv2d_14': (1, -2), 'conv2d_19': (1, -2), 'conv2d_17': (1, -2), 'conv2d_22': (1, -3), 'conv2d_16': (1, -3), 'conv2d_20': (1, -2), 'conv2d_18': (1, -2), 'conv2d_21': (1, -3), 'binary': (3, 1)}, activations={'conv2d_1': (8, 3), 'conv2d_5': (5, -1), 'conv2d_3': (7, 0), 'conv2d_8': (1, -7), 'conv2d_2': (6, -1), 'conv2d_6': (6, -2), 'conv2d_4': (6, -3), 'conv2d_7': (4, -5), 'conv2d_12': (3, -6), 'conv2d_10': (5, -4), 'conv2d_15': (2, -5), 'conv2d_9': (3, -4), 'conv2d_13': (5, -6), 'conv2d_11': (7, -3), 'conv2d_14': (5, -5), 'conv2d_19': (6, -3), 'conv2d_17': (4, -4), 'conv2d_22': (2, -7), 'conv2d_16': (4, -5), 'conv2d_20': (6, -5), 'conv2d_18': (6, -5), 'conv2d_21': (10, -1), 'binary': (11, 6)})

# %%
model_obj = fxp_quantize.fix_model_quantization(model_arch, name, test_data, opts.quant_evaluator.quant_params)
print(f'Floating point network accuracy: {float_model_acc * 100}%')
fxp_model_acc = model_obj.evaluate_accuracy()[1]
print(f'Fixed-point network accuracy: {fxp_model_acc * 100}%')
print(f'Accuracy loss of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f}%')

# Save results
scores = {
    'weights': w_scores,
    'biases': b_scores,
    'activations': a_scores
}
acc_drop = {
    'weights': acc_drop_w,
    'biases': acc_drop_b,
    'activations': acc_drop_a
}

save_results(scores, acc_drop, opts.quant_evaluator.quant_params._asdict(), output_path)
# Out:
# Floating point network accuracy: 74.52%
# Fixed-point network accuracy: 73.78%
# Accuracy loss of 0.993%
