# %%
import sys
sys.path.append('C:/Users/320060820/experiments/')
import fxp_quantize
import model_data
from algorithms import fixed_bitwidth
from model_gen import inception_cnn
from algorithms.optimized_search import OptimizedSearch
import evaluation_metrics

import keras
import tensorflow as tf
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import pandas as pd
import pickle

# to restart layer numbering
from keras import backend as K
K.clear_session()
# Out:
# Using TensorFlow backend.

# %%
# Functions specific to this file
def save_results(scores, acc_drop, opt_params, output_path):
    
    with open(output_path + f'opt_params.p', 'wb') as f:
        pickle.dump(opt_params, f)
    
    with open(output_path + f'acc_drop.p', 'wb') as f:
        pickle.dump(acc_drop, f)
    
    with open(output_path + f'scores.p', 'wb') as f:
        pickle.dump(scores, f)

# %%
input_shape = (96, 96, 1)
num_outputs = 10 # number of classes
path_trained_weights = 'C:/Users/320060820/experiments/test_models/fashion_df/fashion_df_w.h5'
output_path = 'C:/Users/320060820/experiments/outputs/Comp_Dependent_Optimized_Search/DF Fashion/'
name = 'fashion_df'
total_acc_drop = 0.005

from test_models.fashion_df import data
_, test_data = data.get_data()

model_arch = inception_cnn.InceptionCNN(input_shape, num_outputs, dropout=True, 
                                        pool_layer_type='max', path_trained_weights=path_trained_weights)
model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
float_model_acc = model_obj.evaluate_accuracy()[1]
print(float_model_acc)
# Out:
# 0.9106

# %%
layer_num = [1, 5, 3, 8, 2, 6, 4, 7, 12, 10, 15, 9, 13, 11, 14, 19, 17, 22, 16, 20, 18, 21]
layer_names = [f'conv2d_{i}' for i in layer_num] + ['binary']

# %%
linear = lambda x, total_acc_drop, num_layers, offset=0: total_acc_drop/num_layers * x + offset

# %%
x = np.arange(1, len(layer_names) + 1)
plt.figure(figsize=(10, 7));
plt.title('Ideal budget allocation per layer for weights and activations');
y1 = linear(x, total_acc_drop, len(layer_names))
y2 = linear(x, total_acc_drop, len(layer_names), total_acc_drop)
plt.plot(x, y1, 'o-', label='Component 1');
plt.plot(x, y2, 'o-', label='Component 2');
plt.xticks(x, layer_names, rotation='vertical')
plt.plot(x, np.ones(y2.shape) * total_acc_drop, label='(total) Component 1 budget');
plt.plot(x, np.ones(y2.shape) * total_acc_drop*2, label='(total) Component 2 budget')
plt.grid();
plt.legend();

# %%
acc_drop_config = {
    layer_names[i - 1]: linear(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(model_arch, name, test_data, float_model_acc)
w_scores, opt_params_weights, acc_drop_w = opts.run(acc_drop_config, 'weights', start_bw = 12)
# Out:
# {'conv2d_1': [12, 8], 'conv2d_5': [12, 8], 'conv2d_3': [12, 8], 'conv2d_6': [12, 8], 'conv2d_2': [12, 8], 'conv2d_4': [12, 8], 'conv2d_7': [12, 8], 'conv2d_8': [12, 8], 'conv2d_12': [12, 8], 'conv2d_10': [12, 8], 'conv2d_13': [12, 8], 'conv2d_9': [12, 8], 'conv2d_11': [12, 8], 'conv2d_14': [12, 8], 'conv2d_15': [12, 8], 'conv2d_19': [12, 8], 'conv2d_17': [12, 8], 'conv2d_20': [12, 8], 'conv2d_16': [12, 8], 'conv2d_18': [12, 8], 'conv2d_21': [12, 7], 'conv2d_22': [12, 8], 'binary': [12, 10]}
# Quantizing layer conv2d_1
# Global opt: (10, 7) Local opt: (10, 7) Performance diff: 0.000000
# Chosen:  (10, 7)
# After quantizing weights of layer conv2d_1 | Measured accuracy drop -0.001428 | Acceptable accuracy drop: 0.000217
# Quantizing layer conv2d_5
# Global opt: (6, 3) Local opt: (7, 3) Performance diff: 0.003075
# Chosen:  (7, 3)
# After quantizing weights of layer conv2d_5 | Measured accuracy drop -0.005161 | Acceptable accuracy drop: 0.000435
# Quantizing layer conv2d_3
# Global opt: (3, 0) Local opt: (4, 0) Performance diff: 0.000110
# Chosen:  (3, 0)
# After quantizing weights of layer conv2d_3 | Measured accuracy drop -0.006040 | Acceptable accuracy drop: 0.000652
# Quantizing layer conv2d_8
# Global opt: (1, -3) Local opt: (2, -2) Performance diff: 0.000988
# Chosen:  (1, -3)
# After quantizing weights of layer conv2d_8 | Measured accuracy drop -0.005381 | Acceptable accuracy drop: 0.000870
# Quantizing layer conv2d_2
# Global opt: (2, -1) Local opt: (3, 0) Performance diff: 0.005381
# Chosen:  (3, 0)
# After quantizing weights of layer conv2d_2 | Measured accuracy drop -0.006150 | Acceptable accuracy drop: 0.001087
# Quantizing layer conv2d_6
# Global opt: (3, -1) Local opt: (3, -1) Performance diff: 0.000000
# Chosen:  (3, -1)
# After quantizing weights of layer conv2d_6 | Measured accuracy drop -0.005711 | Acceptable accuracy drop: 0.001304
# Quantizing layer conv2d_4
# Global opt: (2, -1) Local opt: (3, -1) Performance diff: 0.006040
# Chosen:  (3, -1)
# After quantizing weights of layer conv2d_4 | Measured accuracy drop -0.005601 | Acceptable accuracy drop: 0.001522
# Quantizing layer conv2d_7
# Global opt: (3, -1) Local opt: (4, 0) Performance diff: 0.000659
# Chosen:  (3, -1)
# After quantizing weights of layer conv2d_7 | Measured accuracy drop -0.004832 | Acceptable accuracy drop: 0.001739
# Quantizing layer conv2d_12
# Global opt: (3, -1) Local opt: (4, 0) Performance diff: 0.002306
# Chosen:  (4, 0)
# After quantizing weights of layer conv2d_12 | Measured accuracy drop -0.006589 | Acceptable accuracy drop: 0.001957
# Quantizing layer conv2d_10
# Global opt: (2, -2) Local opt: (3, -1) Performance diff: 0.006369
# Chosen:  (3, -1)
# After quantizing weights of layer conv2d_10 | Measured accuracy drop -0.005381 | Acceptable accuracy drop: 0.002174
# Quantizing layer conv2d_15
# Global opt: (1, -3) Local opt: (2, -2) Performance diff: 0.003514
# Chosen:  (2, -2)
# After quantizing weights of layer conv2d_15 | Measured accuracy drop -0.005820 | Acceptable accuracy drop: 0.002391
# Quantizing layer conv2d_9
# Global opt: (2, -2) Local opt: (3, -1) Performance diff: 0.000549
# Chosen:  (2, -2)
# After quantizing weights of layer conv2d_9 | Measured accuracy drop -0.003185 | Acceptable accuracy drop: 0.002609
# Quantizing layer conv2d_13
# Global opt: (2, -1) Local opt: (2, -1) Performance diff: 0.000000
# Chosen:  (2, -1)
# After quantizing weights of layer conv2d_13 | Measured accuracy drop -0.005161 | Acceptable accuracy drop: 0.002826
# Quantizing layer conv2d_11
# Global opt: (2, -1) Local opt: (3, 0) Performance diff: 0.001318
# Chosen:  (2, -1)
# After quantizing weights of layer conv2d_11 | Measured accuracy drop -0.003734 | Acceptable accuracy drop: 0.003043
# Quantizing layer conv2d_14
# Global opt: (3, -1) Local opt: (4, 0) Performance diff: 0.000879
# Chosen:  (3, -1)
# After quantizing weights of layer conv2d_14 | Measured accuracy drop -0.002636 | Acceptable accuracy drop: 0.003261
# Quantizing layer conv2d_19
# Global opt: (3, 0) Local opt: (4, 0) Performance diff: 0.004393
# Chosen:  (4, 0)
# After quantizing weights of layer conv2d_19 | Measured accuracy drop -0.002855 | Acceptable accuracy drop: 0.003478
# Quantizing layer conv2d_17
# Global opt: (2, -1) Local opt: (3, 0) Performance diff: 0.004612
# Chosen:  (3, 0)
# After quantizing weights of layer conv2d_17 | Measured accuracy drop -0.001977 | Acceptable accuracy drop: 0.003696
# Quantizing layer conv2d_22
# Global opt: (1, -3) Local opt: (2, -2) Performance diff: 0.001208
# Chosen:  (1, -3)
# After quantizing weights of layer conv2d_22 | Measured accuracy drop -0.001098 | Acceptable accuracy drop: 0.003913
# Quantizing layer conv2d_16
# Global opt: (2, -2) Local opt: (2, -2) Performance diff: 0.000000
# Chosen:  (2, -2)
# After quantizing weights of layer conv2d_16 | Measured accuracy drop -0.002306 | Acceptable accuracy drop: 0.004130
# Quantizing layer conv2d_20
# Global opt: (3, -1) Local opt: (4, -1) Performance diff: 0.000329
# Chosen:  (3, -1)
# After quantizing weights of layer conv2d_20 | Measured accuracy drop -0.001208 | Acceptable accuracy drop: 0.004348
# Quantizing layer conv2d_18
# Global opt: (3, -1) Local opt: (4, 0) Performance diff: 0.002636
# Chosen:  (4, 0)
# After quantizing weights of layer conv2d_18 | Measured accuracy drop -0.000769 | Acceptable accuracy drop: 0.004565
# Quantizing layer conv2d_21
# Global opt: (3, -1) Local opt: (4, 0) Performance diff: 0.001208
# Chosen:  (3, -1)
# After quantizing weights of layer conv2d_21 | Measured accuracy drop 0.002965 | Acceptable accuracy drop: 0.004783
# Quantizing layer binary
# Global opt: (5, 3) Local opt: (6, 4) Performance diff: 0.001208
# Chosen:  (5, 3)
# After quantizing weights of layer binary | Measured accuracy drop 0.002965 | Acceptable accuracy drop: 0.005000

# %%
opts.plot_scores_matrix(w_scores, 12, 2, (20, 75))

# %%
opts.quant_evaluator.quant_params
# Out:
# QuantizationParameters(weights={'conv2d_1': (10, 7), 'conv2d_5': (7, 3), 'conv2d_3': (3, 0), 'conv2d_8': (1, -3), 'conv2d_2': (3, 0), 'conv2d_6': (3, -1), 'conv2d_4': (3, -1), 'conv2d_7': (3, -1), 'conv2d_12': (4, 0), 'conv2d_10': (3, -1), 'conv2d_15': (2, -2), 'conv2d_9': (2, -2), 'conv2d_13': (2, -1), 'conv2d_11': (2, -1), 'conv2d_14': (3, -1), 'conv2d_19': (4, 0), 'conv2d_17': (3, 0), 'conv2d_22': (1, -3), 'conv2d_16': (2, -2), 'conv2d_20': (3, -1), 'conv2d_18': (4, 0), 'conv2d_21': (3, -1), 'binary': (5, 3)}, biases={}, activations={})

# %%
acc_drop_config = {
    layer_names[i - 1]: total_acc_drop for i in range(1, len(layer_names) + 1)
}

b_scores, opt_params_biases, acc_drop_b = opts.run(acc_drop_config, 'biases', start_bw = 8)
opts.plot_scores_matrix(b_scores, 12, 2, (20, 75))
# Out:
# {'conv2d_1': [8, 6], 'conv2d_5': [8, 5], 'conv2d_3': [8, 5], 'conv2d_6': [8, 4], 'conv2d_2': [8, 5], 'conv2d_4': [8, 4], 'conv2d_7': [8, 5], 'conv2d_8': [8, 5], 'conv2d_12': [8, 4], 'conv2d_10': [8, 5], 'conv2d_13': [8, 5], 'conv2d_9': [8, 5], 'conv2d_11': [8, 5], 'conv2d_14': [8, 5], 'conv2d_15': [8, 5], 'conv2d_19': [8, 5], 'conv2d_17': [8, 5], 'conv2d_20': [8, 5], 'conv2d_16': [8, 4], 'conv2d_18': [8, 5], 'conv2d_21': [8, 5], 'conv2d_22': [8, 4], 'binary': [8, 5]}
# Quantizing layer conv2d_1
# Global opt: (4, 3) Local opt: (4, 3) Performance diff: 0.000000
# Chosen:  (4, 3)
# After quantizing biases of layer conv2d_1 | Measured accuracy drop 0.000220 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_5
# Global opt: (1, -2) Local opt: (2, -2) Performance diff: 0.001428
# Chosen:  (1, -2)
# After quantizing biases of layer conv2d_5 | Measured accuracy drop 0.001647 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_3
# Global opt: (1, -2) Local opt: (2, -2) Performance diff: 0.003734
# Chosen:  (2, -2)
# After quantizing biases of layer conv2d_3 | Measured accuracy drop 0.000220 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_8
# Global opt: (1, -2) Local opt: (2, -1) Performance diff: 0.000110
# Chosen:  (1, -2)
# After quantizing biases of layer conv2d_8 | Measured accuracy drop 0.000220 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_2
# Global opt: (1, -2) Local opt: (2, -1) Performance diff: 0.001318
# Chosen:  (1, -2)
# After quantizing biases of layer conv2d_2 | Measured accuracy drop 0.000659 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_6
# Global opt: (1, -3) Local opt: (2, -3) Performance diff: 0.000769
# Chosen:  (1, -3)
# After quantizing biases of layer conv2d_6 | Measured accuracy drop 0.001208 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_4
# Global opt: (1, -3) Local opt: (1, -4) Performance diff: 0.000000
# Chosen:  (1, -4)
# After quantizing biases of layer conv2d_4 | Measured accuracy drop 0.001098 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_7
# Global opt: (1, -2) Local opt: (2, -2) Performance diff: 0.000220
# Chosen:  (1, -2)
# After quantizing biases of layer conv2d_7 | Measured accuracy drop 0.001757 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_12
# Global opt: (1, -3) Local opt: (2, -2) Performance diff: 0.000110
# Chosen:  (1, -3)
# After quantizing biases of layer conv2d_12 | Measured accuracy drop 0.001757 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_10
# Global opt: (1, -2) Local opt: (2, -2) Performance diff: 0.001318
# Chosen:  (1, -2)
# After quantizing biases of layer conv2d_10 | Measured accuracy drop 0.002087 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_15
# Global opt: (1, -2) Local opt: (1, -3) Performance diff: 0.000000
# Chosen:  (1, -3)
# After quantizing biases of layer conv2d_15 | Measured accuracy drop 0.001977 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_9
# Global opt: (1, -2) Local opt: (2, -1) Performance diff: 0.001208
# Chosen:  (1, -2)
# After quantizing biases of layer conv2d_9 | Measured accuracy drop 0.002745 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_13
# Global opt: (1, -2) Local opt: (2, -1) Performance diff: 0.000220
# Chosen:  (1, -2)
# After quantizing biases of layer conv2d_13 | Measured accuracy drop 0.003075 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_11
# Global opt: (1, -2) Local opt: (1, -3) Performance diff: 0.000000
# Chosen:  (1, -3)
# After quantizing biases of layer conv2d_11 | Measured accuracy drop 0.002855 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_14
# Global opt: (1, -2) Local opt: (2, -2) Performance diff: 0.000329
# Chosen:  (1, -2)
# After quantizing biases of layer conv2d_14 | Measured accuracy drop 0.002965 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_19
# Global opt: (1, -2) Local opt: (1, -3) Performance diff: 0.000000
# Chosen:  (1, -3)
# After quantizing biases of layer conv2d_19 | Measured accuracy drop 0.002306 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_17
# Global opt: (1, -2) Local opt: (2, -1) Performance diff: 0.000110
# Chosen:  (1, -2)
# After quantizing biases of layer conv2d_17 | Measured accuracy drop 0.002306 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_22
# Global opt: (1, -3) Local opt: (2, -3) Performance diff: 0.000220
# Chosen:  (1, -3)
# After quantizing biases of layer conv2d_22 | Measured accuracy drop 0.001867 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_16
# Global opt: (1, -3) Local opt: (1, -4) Performance diff: 0.000000
# Chosen:  (1, -4)
# After quantizing biases of layer conv2d_16 | Measured accuracy drop 0.001757 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_20
# Global opt: (1, -2) Local opt: (1, -3) Performance diff: 0.000000
# Chosen:  (1, -3)
# After quantizing biases of layer conv2d_20 | Measured accuracy drop 0.001318 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_18
# Global opt: (1, -2) Local opt: (2, -1) Performance diff: 0.000220
# Chosen:  (1, -2)
# After quantizing biases of layer conv2d_18 | Measured accuracy drop 0.001647 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_21
# Global opt: (1, -2) Local opt: (2, -1) Performance diff: 0.000659
# Chosen:  (1, -2)
# After quantizing biases of layer conv2d_21 | Measured accuracy drop 0.002306 | Acceptable accuracy drop: 0.005000
# Quantizing layer binary
# Global opt: (2, 0) Local opt: (2, 0) Performance diff: 0.000000
# Chosen:  (2, 0)
# After quantizing biases of layer binary | Measured accuracy drop 0.001867 | Acceptable accuracy drop: 0.005000

# %%
opts.quant_evaluator.quant_params
# Out:
# QuantizationParameters(weights={'conv2d_1': (10, 7), 'conv2d_5': (7, 3), 'conv2d_3': (3, 0), 'conv2d_8': (1, -3), 'conv2d_2': (3, 0), 'conv2d_6': (3, -1), 'conv2d_4': (3, -1), 'conv2d_7': (3, -1), 'conv2d_12': (4, 0), 'conv2d_10': (3, -1), 'conv2d_15': (2, -2), 'conv2d_9': (2, -2), 'conv2d_13': (2, -1), 'conv2d_11': (2, -1), 'conv2d_14': (3, -1), 'conv2d_19': (4, 0), 'conv2d_17': (3, 0), 'conv2d_22': (1, -3), 'conv2d_16': (2, -2), 'conv2d_20': (3, -1), 'conv2d_18': (4, 0), 'conv2d_21': (3, -1), 'binary': (5, 3)}, biases={'conv2d_1': (4, 3), 'conv2d_5': (1, -2), 'conv2d_3': (2, -2), 'conv2d_8': (1, -2), 'conv2d_2': (1, -2), 'conv2d_6': (1, -3), 'conv2d_4': (1, -4), 'conv2d_7': (1, -2), 'conv2d_12': (1, -3), 'conv2d_10': (1, -2), 'conv2d_15': (1, -3), 'conv2d_9': (1, -2), 'conv2d_13': (1, -2), 'conv2d_11': (1, -3), 'conv2d_14': (1, -2), 'conv2d_19': (1, -3), 'conv2d_17': (1, -2), 'conv2d_22': (1, -3), 'conv2d_16': (1, -4), 'conv2d_20': (1, -3), 'conv2d_18': (1, -2), 'conv2d_21': (1, -2), 'binary': (2, 0)}, activations={})

# %%
acc_drop_config = {
    layer_names[i - 1]: linear(i, total_acc_drop, len(layer_names), total_acc_drop) for i in range(1, len(layer_names) + 1)
}

a_scores, opt_params_act, acc_drop_a = opts.run(acc_drop_config, 'activations', start_bw = 12)
opts.plot_scores_matrix(a_scores, 12, 2, (20, 75))
# Out:
# {'conv2d_1': [12, 8], 'conv2d_5': [12, 4], 'conv2d_3': [12, 4], 'conv2d_6': [12, 1], 'conv2d_2': [12, 4], 'conv2d_4': [12, 2], 'conv2d_7': [12, 0], 'conv2d_8': [12, 4], 'conv2d_12': [12, 3], 'conv2d_10': [12, 2], 'conv2d_13': [12, 1], 'conv2d_9': [12, 2], 'conv2d_11': [12, 1], 'conv2d_14': [12, 1], 'conv2d_15': [12, 2], 'conv2d_19': [12, 2], 'conv2d_17': [12, 2], 'conv2d_20': [12, 1], 'conv2d_16': [12, 2], 'conv2d_18': [12, 0], 'conv2d_21': [12, 1], 'conv2d_22': [12, 2], 'binary': [12, 5]}
# Quantizing layer conv2d_1
# Global opt: (6, 3) Local opt: (7, 4) Performance diff: 0.001537
# Chosen:  (7, 4)
# After quantizing activations of layer conv2d_1 | Measured accuracy drop 0.001867 | Acceptable accuracy drop: 0.005217
# Quantizing layer conv2d_5
# Global opt: (4, -2) Local opt: (5, -1) Performance diff: 0.001208
# Chosen:  (4, -2)
# After quantizing activations of layer conv2d_5 | Measured accuracy drop 0.003624 | Acceptable accuracy drop: 0.005435
# Quantizing layer conv2d_3
# Global opt: (3, -3) Local opt: (3, -3) Performance diff: 0.000000
# Chosen:  (3, -3)
# After quantizing activations of layer conv2d_3 | Measured accuracy drop 0.002965 | Acceptable accuracy drop: 0.005652
# Quantizing layer conv2d_8
# Global opt: (1, -7) Local opt: (1, -8) Performance diff: 0.000000
# Chosen:  (1, -8)
# After quantizing activations of layer conv2d_8 | Measured accuracy drop 0.002965 | Acceptable accuracy drop: 0.005870
# Quantizing layer conv2d_2
# Global opt: (3, -3) Local opt: (3, -3) Performance diff: 0.000000
# Chosen:  (3, -3)
# After quantizing activations of layer conv2d_2 | Measured accuracy drop 0.003953 | Acceptable accuracy drop: 0.006087
# Quantizing layer conv2d_6
# Global opt: (4, -5) Local opt: (5, -4) Performance diff: 0.001757
# Chosen:  (5, -4)
# After quantizing activations of layer conv2d_6 | Measured accuracy drop 0.002855 | Acceptable accuracy drop: 0.006304
# Quantizing layer conv2d_4
# Global opt: (3, -6) Local opt: (4, -5) Performance diff: 0.000988
# Chosen:  (3, -6)
# After quantizing activations of layer conv2d_4 | Measured accuracy drop 0.003953 | Acceptable accuracy drop: 0.006522
# Quantizing layer conv2d_7
# Global opt: (4, -5) Local opt: (5, -5) Performance diff: 0.000659
# Chosen:  (4, -5)
# After quantizing activations of layer conv2d_7 | Measured accuracy drop 0.005930 | Acceptable accuracy drop: 0.006739
# Quantizing layer conv2d_12
# Global opt: (4, -4) Local opt: (5, -4) Performance diff: 0.000329
# Chosen:  (4, -4)
# After quantizing activations of layer conv2d_12 | Measured accuracy drop 0.006809 | Acceptable accuracy drop: 0.006957
# Quantizing layer conv2d_10
# Global opt: (4, -4) Local opt: (5, -4) Performance diff: 0.000110
# Chosen:  (4, -4)
# After quantizing activations of layer conv2d_10 | Measured accuracy drop 0.006919 | Acceptable accuracy drop: 0.007174
# Quantizing layer conv2d_15
# Global opt: (3, -5) Local opt: (4, -4) Performance diff: 0.000220
# Chosen:  (3, -5)
# After quantizing activations of layer conv2d_15 | Measured accuracy drop 0.007028 | Acceptable accuracy drop: 0.007391
# Quantizing layer conv2d_9
# Global opt: (3, -5) Local opt: (4, -5) Performance diff: 0.000110
# Chosen:  (3, -5)
# After quantizing activations of layer conv2d_9 | Measured accuracy drop 0.006699 | Acceptable accuracy drop: 0.007609
# Quantizing layer conv2d_13
# Global opt: (4, -6) Local opt: (5, -5) Performance diff: 0.000329
# Chosen:  (4, -6)
# After quantizing activations of layer conv2d_13 | Measured accuracy drop 0.007468 | Acceptable accuracy drop: 0.007826
# Quantizing layer conv2d_11
# Global opt: (4, -6) Local opt: (4, -6) Performance diff: 0.000000
# Chosen:  (4, -6)
# After quantizing activations of layer conv2d_11 | Measured accuracy drop 0.007358 | Acceptable accuracy drop: 0.008043
# Quantizing layer conv2d_14
# Global opt: (4, -6) Local opt: (4, -6) Performance diff: 0.000000
# Chosen:  (4, -6)
# After quantizing activations of layer conv2d_14 | Measured accuracy drop 0.008127 | Acceptable accuracy drop: 0.008261
# Quantizing layer conv2d_19
# Global opt: (8, -1) Local opt: (8, -1) Performance diff: 0.000000
# Chosen:  (8, -1)
# After quantizing activations of layer conv2d_19 | Measured accuracy drop 0.007687 | Acceptable accuracy drop: 0.008478
# Quantizing layer conv2d_17
# Global opt: (3, -5) Local opt: (3, -5) Performance diff: 0.000000
# Chosen:  (3, -5)
# After quantizing activations of layer conv2d_17 | Measured accuracy drop 0.007907 | Acceptable accuracy drop: 0.008696
# Quantizing layer conv2d_22
# Global opt: (1, -9) Local opt: (1, -10) Performance diff: 0.000000
# Chosen:  (1, -10)
# After quantizing activations of layer conv2d_22 | Measured accuracy drop 0.007907 | Acceptable accuracy drop: 0.008913
# Quantizing layer conv2d_16
# Global opt: (5, -4) Local opt: (6, -4) Performance diff: 0.000439
# Chosen:  (5, -4)
# After quantizing activations of layer conv2d_16 | Measured accuracy drop 0.008566 | Acceptable accuracy drop: 0.009130
# Quantizing layer conv2d_20
# Global opt: (6, -4) Local opt: (6, -4) Performance diff: 0.000000
# Chosen:  (6, -4)
# After quantizing activations of layer conv2d_20 | Measured accuracy drop 0.008566 | Acceptable accuracy drop: 0.009348
# Quantizing layer conv2d_18
# Global opt: (5, -6) Local opt: (6, -5) Performance diff: 0.001098
# Chosen:  (5, -6)
# After quantizing activations of layer conv2d_18 | Measured accuracy drop 0.009335 | Acceptable accuracy drop: 0.009565
# Quantizing layer conv2d_21
# Global opt: (8, -3) Local opt: (9, -2) Performance diff: 0.000110
# Chosen:  (8, -3)
# After quantizing activations of layer conv2d_21 | Measured accuracy drop 0.009554 | Acceptable accuracy drop: 0.009783
# Quantizing layer binary
# Global opt: (10, 5) Local opt: (10, 5) Performance diff: 0.000000
# Chosen:  (10, 5)
# After quantizing activations of layer binary | Measured accuracy drop 0.009664 | Acceptable accuracy drop: 0.010000

# %%
opts.quant_evaluator.quant_params
# Out:
# QuantizationParameters(weights={'conv2d_1': (10, 7), 'conv2d_5': (7, 3), 'conv2d_3': (3, 0), 'conv2d_8': (1, -3), 'conv2d_2': (3, 0), 'conv2d_6': (3, -1), 'conv2d_4': (3, -1), 'conv2d_7': (3, -1), 'conv2d_12': (4, 0), 'conv2d_10': (3, -1), 'conv2d_15': (2, -2), 'conv2d_9': (2, -2), 'conv2d_13': (2, -1), 'conv2d_11': (2, -1), 'conv2d_14': (3, -1), 'conv2d_19': (4, 0), 'conv2d_17': (3, 0), 'conv2d_22': (1, -3), 'conv2d_16': (2, -2), 'conv2d_20': (3, -1), 'conv2d_18': (4, 0), 'conv2d_21': (3, -1), 'binary': (5, 3)}, biases={'conv2d_1': (4, 3), 'conv2d_5': (1, -2), 'conv2d_3': (2, -2), 'conv2d_8': (1, -2), 'conv2d_2': (1, -2), 'conv2d_6': (1, -3), 'conv2d_4': (1, -4), 'conv2d_7': (1, -2), 'conv2d_12': (1, -3), 'conv2d_10': (1, -2), 'conv2d_15': (1, -3), 'conv2d_9': (1, -2), 'conv2d_13': (1, -2), 'conv2d_11': (1, -3), 'conv2d_14': (1, -2), 'conv2d_19': (1, -3), 'conv2d_17': (1, -2), 'conv2d_22': (1, -3), 'conv2d_16': (1, -4), 'conv2d_20': (1, -3), 'conv2d_18': (1, -2), 'conv2d_21': (1, -2), 'binary': (2, 0)}, activations={'conv2d_1': (7, 4), 'conv2d_5': (4, -2), 'conv2d_3': (3, -3), 'conv2d_8': (1, -8), 'conv2d_2': (3, -3), 'conv2d_6': (5, -4), 'conv2d_4': (3, -6), 'conv2d_7': (4, -5), 'conv2d_12': (4, -4), 'conv2d_10': (4, -4), 'conv2d_15': (3, -5), 'conv2d_9': (3, -5), 'conv2d_13': (4, -6), 'conv2d_11': (4, -6), 'conv2d_14': (4, -6), 'conv2d_19': (8, -1), 'conv2d_17': (3, -5), 'conv2d_22': (1, -10), 'conv2d_16': (5, -4), 'conv2d_20': (6, -4), 'conv2d_18': (5, -6), 'conv2d_21': (8, -3), 'binary': (10, 5)})

# %%
model_obj = fxp_quantize.fix_model_quantization(model_arch, name, test_data, opts.quant_evaluator.quant_params)
print(f'Floating point network accuracy: {float_model_acc * 100}%')
fxp_model_acc = model_obj.evaluate_accuracy()[1]
print(f'Fixed-point network accuracy: {fxp_model_acc * 100}%')
print(f'Accuracy loss of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f}%')

# Save results
scores = {
    'weights': w_scores,
    'biases': b_scores,
    'activations': a_scores
}
acc_drop = {
    'weights': acc_drop_w,
    'biases': acc_drop_b,
    'activations': acc_drop_a
}

save_results(scores, acc_drop, opts.quant_evaluator.quant_params._asdict(), output_path)
# Out:
# Floating point network accuracy: 91.06%
# Fixed-point network accuracy: 90.18%
# Accuracy loss of 0.966%
