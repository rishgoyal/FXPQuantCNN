# %%
import sys
sys.path.append('C:/Users/320060820/experiments/')
import fxp_quantize
import model_data
from algorithms import fixed_bitwidth
from model_gen import inception_cnn
from algorithms.optimized_search import OptimizedSearch
import evaluation_metrics

import keras
import tensorflow as tf
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import pandas as pd
import pickle

# to restart layer numbering
from keras import backend as K
K.clear_session()
# Out:
# Using TensorFlow backend.

# %%
# Functions specific to this file
def save_results(scores, acc_drop, opt_params, output_path):
    
    with open(output_path + f'opt_params.p', 'wb') as f:
        pickle.dump(opt_params, f)
    
    with open(output_path + f'acc_drop.p', 'wb') as f:
        pickle.dump(acc_drop, f)
    
    with open(output_path + f'scores.p', 'wb') as f:
        pickle.dump(scores, f)

# %%
input_shape = (96, 96, 1)
num_outputs = 10 # number of classes
path_trained_weights = 'C:/Users/320060820/experiments/test_models/mnist_df/inception_v3_model_batchnorm_w.h5'
output_path = 'C:/Users/320060820/experiments/outputs/Comp_Dependent_Optimized_Search/DF MNIST/'
name = 'mnist_df'
total_acc_drop = 0.005

from test_models.mnist_df import data
_, test_data = data.get_data()

model_arch = inception_cnn.InceptionCNN(input_shape, num_outputs, dropout=False, 
                                        pool_layer_type='average', path_trained_weights=path_trained_weights)
model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
float_model_acc = model_obj.evaluate_accuracy()[1]
print(float_model_acc)
# Out:
# WARNING:tensorflow:From C:\Users\320060820\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 0.9808

# %%
layer_num = [1, 5, 3, 8, 2, 6, 4, 7, 12, 10, 15, 9, 13, 11, 14, 19, 17, 22, 16, 20, 18, 21]
layer_names = [f'conv2d_{i}' for i in layer_num] + ['binary']

# %%
linear = lambda x, total_acc_drop, num_layers, offset=0: total_acc_drop/num_layers * x + offset

# %%
x = np.arange(1, len(layer_names) + 1)
plt.figure(figsize=(10, 7));
plt.title('Ideal budget allocation per layer for weights and activations');
y1 = linear(x, total_acc_drop, len(layer_names))
y2 = linear(x, total_acc_drop, len(layer_names), total_acc_drop)
plt.plot(x, y1, 'o-', label='Component 1');
plt.plot(x, y2, 'o-', label='Component 2');
plt.xticks(x, layer_names, rotation='vertical')
plt.plot(x, np.ones(y2.shape) * total_acc_drop, label='(total) Component 1 budget');
plt.plot(x, np.ones(y2.shape) * total_acc_drop*2, label='(total) Component 2 budget')
plt.grid();
plt.legend();

# %%
acc_drop_config = {
    layer_names[i - 1]: linear(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(model_arch, name, test_data, float_model_acc)
w_scores, opt_params_weights, acc_drop_w = opts.run(acc_drop_config, 'weights', start_bw = 12)
opts.plot_scores_matrix(w_scores, 5, 3, (20, 30))
# Out:
# {'conv2d_1': [12, 11], 'conv2d_5': [12, 10], 'conv2d_3': [12, 10], 'conv2d_6': [12, 11], 'conv2d_2': [12, 10], 'conv2d_4': [12, 11], 'conv2d_7': [12, 11], 'conv2d_8': [12, 11], 'conv2d_12': [12, 10], 'conv2d_10': [12, 11], 'conv2d_13': [12, 11], 'conv2d_9': [12, 11], 'conv2d_11': [12, 11], 'conv2d_14': [12, 11], 'conv2d_15': [12, 11], 'conv2d_19': [12, 10], 'conv2d_17': [12, 10], 'conv2d_20': [12, 10], 'conv2d_16': [12, 11], 'conv2d_18': [12, 10], 'conv2d_21': [12, 10], 'conv2d_22': [12, 11], 'binary': [12, 10]}
# Quantizing layer conv2d_1
# Global opt: (5, 4) Local opt: (5, 5) Performance diff: 0.000204
# Chosen:  (5, 5)
# After quantizing weights of layer conv2d_1 | Measured accuracy drop -0.000612 | Acceptable accuracy drop: 0.000217
# Quantizing layer conv2d_5
# Global opt: (3, 2) Local opt: (4, 3) Performance diff: 0.000204
# Chosen:  (3, 2)
# After quantizing weights of layer conv2d_5 | Measured accuracy drop -0.000612 | Acceptable accuracy drop: 0.000435
# Quantizing layer conv2d_3
# Global opt: (3, 2) Local opt: (4, 2) Performance diff: 0.000510
# Chosen:  (3, 2)
# After quantizing weights of layer conv2d_3 | Measured accuracy drop -0.000306 | Acceptable accuracy drop: 0.000652
# Quantizing layer conv2d_8
# Global opt: (2, 1) Local opt: (3, 2) Performance diff: 0.000918
# Chosen:  (2, 1)
# After quantizing weights of layer conv2d_8 | Measured accuracy drop 0.000816 | Acceptable accuracy drop: 0.000870
# Quantizing layer conv2d_2
# Global opt: (4, 3) Local opt: (5, 3) Performance diff: 0.000102
# Chosen:  (4, 3)
# After quantizing weights of layer conv2d_2 | Measured accuracy drop 0.000918 | Acceptable accuracy drop: 0.001087
# Quantizing layer conv2d_6
# Global opt: (4, 3) Local opt: (5, 4) Performance diff: 0.000510
# Chosen:  (4, 3)
# After quantizing weights of layer conv2d_6 | Measured accuracy drop 0.001223 | Acceptable accuracy drop: 0.001304
# Quantizing layer conv2d_4
# Global opt: (2, 1) Local opt: (2, 1) Performance diff: 0.000000
# Chosen:  (2, 1)
# After quantizing weights of layer conv2d_4 | Measured accuracy drop 0.000510 | Acceptable accuracy drop: 0.001522
# Quantizing layer conv2d_7
# Global opt: (3, 2) Local opt: (3, 2) Performance diff: 0.000000
# Chosen:  (3, 2)
# After quantizing weights of layer conv2d_7 | Measured accuracy drop 0.000510 | Acceptable accuracy drop: 0.001739
# Quantizing layer conv2d_12
# Global opt: (2, 1) Local opt: (2, 1) Performance diff: 0.000000
# Chosen:  (2, 1)
# After quantizing weights of layer conv2d_12 | Measured accuracy drop 0.001529 | Acceptable accuracy drop: 0.001957
# Quantizing layer conv2d_10
# Global opt: (2, 1) Local opt: (2, 1) Performance diff: 0.000000
# Chosen:  (2, 1)
# After quantizing weights of layer conv2d_10 | Measured accuracy drop 0.001937 | Acceptable accuracy drop: 0.002174
# Quantizing layer conv2d_15
# Global opt: (2, 1) Local opt: (3, 2) Performance diff: 0.000306
# Chosen:  (2, 1)
# After quantizing weights of layer conv2d_15 | Measured accuracy drop 0.002141 | Acceptable accuracy drop: 0.002391
# Quantizing layer conv2d_9
# Global opt: (3, 2) Local opt: (3, 2) Performance diff: 0.000000
# Chosen:  (3, 2)
# After quantizing weights of layer conv2d_9 | Measured accuracy drop 0.002447 | Acceptable accuracy drop: 0.002609
# Quantizing layer conv2d_13
# Global opt: (4, 3) Local opt: (5, 4) Performance diff: 0.000102
# Chosen:  (4, 3)
# After quantizing weights of layer conv2d_13 | Measured accuracy drop 0.002345 | Acceptable accuracy drop: 0.002826
# Quantizing layer conv2d_11
# Global opt: (3, 2) Local opt: (4, 3) Performance diff: 0.000408
# Chosen:  (3, 2)
# After quantizing weights of layer conv2d_11 | Measured accuracy drop 0.002549 | Acceptable accuracy drop: 0.003043
# Quantizing layer conv2d_14
# Global opt: (4, 3) Local opt: (5, 3) Performance diff: 0.000204
# Chosen:  (4, 3)
# After quantizing weights of layer conv2d_14 | Measured accuracy drop 0.002855 | Acceptable accuracy drop: 0.003261
# Quantizing layer conv2d_19
# Global opt: (3, 1) Local opt: (3, 2) Performance diff: 0.001631
# Chosen:  (3, 2)
# After quantizing weights of layer conv2d_19 | Measured accuracy drop 0.001325 | Acceptable accuracy drop: 0.003478
# Quantizing layer conv2d_17
# Global opt: (3, 2) Local opt: (4, 3) Performance diff: 0.000510
# Chosen:  (3, 2)
# After quantizing weights of layer conv2d_17 | Measured accuracy drop 0.002039 | Acceptable accuracy drop: 0.003696
# Quantizing layer conv2d_22
# Global opt: (2, 1) Local opt: (3, 2) Performance diff: 0.000102
# Chosen:  (2, 1)
# After quantizing weights of layer conv2d_22 | Measured accuracy drop 0.001937 | Acceptable accuracy drop: 0.003913
# Quantizing layer conv2d_16
# Global opt: (2, 1) Local opt: (3, 2) Performance diff: 0.000510
# Chosen:  (2, 1)
# After quantizing weights of layer conv2d_16 | Measured accuracy drop 0.002141 | Acceptable accuracy drop: 0.004130
# Quantizing layer conv2d_20
# Global opt: (2, 1) Local opt: (2, 1) Performance diff: 0.000000
# Chosen:  (2, 1)
# After quantizing weights of layer conv2d_20 | Measured accuracy drop 0.003161 | Acceptable accuracy drop: 0.004348
# Quantizing layer conv2d_18
# Global opt: (2, 1) Local opt: (2, 1) Performance diff: 0.000000
# Chosen:  (2, 1)
# After quantizing weights of layer conv2d_18 | Measured accuracy drop 0.002651 | Acceptable accuracy drop: 0.004565
# Quantizing layer conv2d_21
# Global opt: (2, 1) Local opt: (2, 1) Performance diff: 0.000000
# Chosen:  (2, 1)
# After quantizing weights of layer conv2d_21 | Measured accuracy drop 0.002855 | Acceptable accuracy drop: 0.004783
# Quantizing layer binary
# Global opt: (4, 2) Local opt: (4, 3) Performance diff: 0.000714
# Chosen:  (4, 3)
# After quantizing weights of layer binary | Measured accuracy drop 0.003467 | Acceptable accuracy drop: 0.005000
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-6885a1747124> in <module>
#       5 opts = OptimizedSearch(model_arch, name, test_data, float_model_acc)
#       6 w_scores, opt_params_weights, acc_drop_w = opts.run(acc_drop_config, 'weights', start_bw = 12)
# ----> 7 opts.plot_scores_matrix(w_scores, 5, 3, (20, 30))
#
# C:/Users/320060820/experiments\algorithms\optimized_search.py in plot_scores_matrix(scores_dict, rows, columns, figsize)
#     407
#     408         for df, i in zip(layer_dfs, np.arange(len(layer_dfs))):
# --> 409             sns.heatmap(df, annot=True, fmt='.3f', ax=ax[i])
#     410             ax[i].set_xlabel('Fractional offset')
#     411             ax[i].set_ylabel('Bitwidth')
#
# IndexError: index 15 is out of bounds for size 15

# %%
opts.quant_evaluator.quant_params
# Out:
# QuantizationParameters(weights={'conv2d_1': (5, 5), 'conv2d_5': (3, 2), 'conv2d_3': (3, 2), 'conv2d_8': (2, 1), 'conv2d_2': (4, 3), 'conv2d_6': (4, 3), 'conv2d_4': (2, 1), 'conv2d_7': (3, 2), 'conv2d_12': (2, 1), 'conv2d_10': (2, 1), 'conv2d_15': (2, 1), 'conv2d_9': (3, 2), 'conv2d_13': (4, 3), 'conv2d_11': (3, 2), 'conv2d_14': (4, 3), 'conv2d_19': (3, 2), 'conv2d_17': (3, 2), 'conv2d_22': (2, 1), 'conv2d_16': (2, 1), 'conv2d_20': (2, 1), 'conv2d_18': (2, 1), 'conv2d_21': (2, 1), 'binary': (4, 3)}, biases={}, activations={})

# %%
acc_drop_config = {
    layer_names[i - 1]: total_acc_drop for i in range(1, len(layer_names) + 1)
}

b_scores, opt_params_biases, acc_drop_b = opts.run(acc_drop_config, 'biases', start_bw = 8)
opts.plot_scores_matrix(b_scores, 5, 3, (20, 30))
# Out:
# {'conv2d_1': [8, 9], 'conv2d_5': [8, 7], 'conv2d_3': [8, 7], 'conv2d_6': [8, 8], 'conv2d_2': [8, 8], 'conv2d_4': [8, 8], 'conv2d_7': [8, 8], 'conv2d_8': [8, 7], 'conv2d_12': [8, 7], 'conv2d_10': [8, 7], 'conv2d_13': [8, 7], 'conv2d_9': [8, 7], 'conv2d_11': [8, 8], 'conv2d_14': [8, 8], 'conv2d_15': [8, 7], 'conv2d_19': [8, 7], 'conv2d_17': [8, 7], 'conv2d_20': [8, 7], 'conv2d_16': [8, 8], 'conv2d_18': [8, 7], 'conv2d_21': [8, 7], 'conv2d_22': [8, 7], 'binary': [8, 9]}
# Quantizing layer conv2d_1
# Global opt: (5, 7) Local opt: (5, 7) Performance diff: 0.000000
# Chosen:  (5, 7)
# After quantizing biases of layer conv2d_1 | Measured accuracy drop 0.003161 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_5
# Global opt: (2, 1) Local opt: (3, 2) Performance diff: 0.000714
# Chosen:  (2, 1)
# After quantizing biases of layer conv2d_5 | Measured accuracy drop 0.002651 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_3
# Global opt: (2, 2) Local opt: (3, 3) Performance diff: 0.000408
# Chosen:  (2, 2)
# After quantizing biases of layer conv2d_3 | Measured accuracy drop 0.002753 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_8
# Global opt: (2, 1) Local opt: (2, 1) Performance diff: 0.000000
# Chosen:  (2, 1)
# After quantizing biases of layer conv2d_8 | Measured accuracy drop 0.003059 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_2
# Global opt: (1, 1) Local opt: (2, 2) Performance diff: 0.000510
# Chosen:  (1, 1)
# After quantizing biases of layer conv2d_2 | Measured accuracy drop 0.004384 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_6
# Global opt: (1, 1) Local opt: (1, 0) Performance diff: 0.000000
# Chosen:  (1, 0)
# After quantizing biases of layer conv2d_6 | Measured accuracy drop 0.004486 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_4
# Global opt: (1, 1) Local opt: (2, 1) Performance diff: 0.000204
# Chosen:  (1, 1)
# After quantizing biases of layer conv2d_4 | Measured accuracy drop 0.004588 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_7
# Global opt: (1, 1) Local opt: (1, 0) Performance diff: 0.000000
# Chosen:  (1, 0)
# After quantizing biases of layer conv2d_7 | Measured accuracy drop 0.004588 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_12
# Global opt: (1, 0) Local opt: (2, 0) Performance diff: 0.000408
# Chosen:  (1, 0)
# After quantizing biases of layer conv2d_12 | Measured accuracy drop 0.004792 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_10
# Global opt: (1, 0) Local opt: (2, 1) Performance diff: 0.000306
# Chosen:  (1, 0)
# After quantizing biases of layer conv2d_10 | Measured accuracy drop 0.004894 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_15
# Global opt: (1, 0) Local opt: (1, -1) Performance diff: 0.000000
# Chosen:  (1, -1)
# After quantizing biases of layer conv2d_15 | Measured accuracy drop 0.004588 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_9
# Global opt: (2, 1) Local opt: (2, 1) Performance diff: 0.000000
# Chosen:  (2, 1)
# After quantizing biases of layer conv2d_9 | Measured accuracy drop 0.004384 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_13
# Global opt: (1, 0) Local opt: (2, 1) Performance diff: 0.000510
# Chosen:  (1, 0)
# After quantizing biases of layer conv2d_13 | Measured accuracy drop 0.004588 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_11
# Global opt: (1, 1) Local opt: (1, 0) Performance diff: 0.000000
# Chosen:  (1, 0)
# After quantizing biases of layer conv2d_11 | Measured accuracy drop 0.004078 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_14
# Global opt: (1, 1) Local opt: (1, 0) Performance diff: 0.000000
# Chosen:  (1, 0)
# After quantizing biases of layer conv2d_14 | Measured accuracy drop 0.003365 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_19
# Global opt: (1, 0) Local opt: (1, -1) Performance diff: 0.000000
# Chosen:  (1, -1)
# After quantizing biases of layer conv2d_19 | Measured accuracy drop 0.003365 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_17
# Global opt: (1, 0) Local opt: (1, -1) Performance diff: 0.000000
# Chosen:  (1, -1)
# After quantizing biases of layer conv2d_17 | Measured accuracy drop 0.002957 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_22
# Global opt: (1, 0) Local opt: (2, 0) Performance diff: 0.000102
# Chosen:  (1, 0)
# After quantizing biases of layer conv2d_22 | Measured accuracy drop 0.002753 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_16
# Global opt: (1, 1) Local opt: (1, 0) Performance diff: 0.000000
# Chosen:  (1, 0)
# After quantizing biases of layer conv2d_16 | Measured accuracy drop 0.002855 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_20
# Global opt: (1, 0) Local opt: (1, -1) Performance diff: 0.000000
# Chosen:  (1, -1)
# After quantizing biases of layer conv2d_20 | Measured accuracy drop 0.002651 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_18
# Global opt: (1, 0) Local opt: (1, -1) Performance diff: 0.000000
# Chosen:  (1, -1)
# After quantizing biases of layer conv2d_18 | Measured accuracy drop 0.002549 | Acceptable accuracy drop: 0.005000
# Quantizing layer conv2d_21
# Global opt: (1, 0) Local opt: (2, 0) Performance diff: 0.000510
# Chosen:  (1, 0)
# After quantizing biases of layer conv2d_21 | Measured accuracy drop 0.002855 | Acceptable accuracy drop: 0.005000
# Quantizing layer binary
# Global opt: (1, 2) Local opt: (2, 2) Performance diff: 0.000816
# Chosen:  (1, 2)
# After quantizing biases of layer binary | Measured accuracy drop 0.003467 | Acceptable accuracy drop: 0.005000
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-6879c9310bad> in <module>
#       4
#       5 b_scores, opt_params_biases, acc_drop_b = opts.run(acc_drop_config, 'biases', start_bw = 8)
# ----> 6 opts.plot_scores_matrix(b_scores, 5, 3, (20, 30))
#
# C:/Users/320060820/experiments\algorithms\optimized_search.py in plot_scores_matrix(scores_dict, rows, columns, figsize)
#     407
#     408         for df, i in zip(layer_dfs, np.arange(len(layer_dfs))):
# --> 409             sns.heatmap(df, annot=True, fmt='.3f', ax=ax[i])
#     410             ax[i].set_xlabel('Fractional offset')
#     411             ax[i].set_ylabel('Bitwidth')
#
# IndexError: index 15 is out of bounds for size 15

# %%
opts.quant_evaluator.quant_params

# %%
acc_drop_config = {
    layer_names[i - 1]: linear(i, total_acc_drop, len(layer_names), total_acc_drop) for i in range(1, len(layer_names) + 1)
}

a_scores, opt_params_act, acc_drop_a = opts.run(acc_drop_config, 'activations', start_bw = 12)
opts.plot_scores_matrix(a_scores, 5, 3, (20, 30))
# Out:
# {'conv2d_1': [12, 10], 'conv2d_5': [12, 7], 'conv2d_3': [12, 7], 'conv2d_6': [12, 5], 'conv2d_2': [12, 7], 'conv2d_4': [12, 5], 'conv2d_7': [12, 5], 'conv2d_8': [12, 7], 'conv2d_12': [12, 6], 'conv2d_10': [12, 6], 'conv2d_13': [12, 4], 'conv2d_9': [12, 6], 'conv2d_11': [12, 4], 'conv2d_14': [12, 4], 'conv2d_15': [12, 6], 'conv2d_19': [12, 5], 'conv2d_17': [12, 5], 'conv2d_20': [12, 4], 'conv2d_16': [12, 5], 'conv2d_18': [12, 4], 'conv2d_21': [12, 4], 'conv2d_22': [12, 6], 'binary': [12, 5]}
# Quantizing layer conv2d_1
# Global opt: (8, 7) Local opt: (8, 7) Performance diff: 0.000000
# Chosen:  (8, 7)
# After quantizing activations of layer conv2d_1 | Measured accuracy drop 0.003365 | Acceptable accuracy drop: 0.005217
# Quantizing layer conv2d_5
# Global opt: (3, -1) Local opt: (4, -1) Performance diff: 0.000102
# Chosen:  (3, -1)
# After quantizing activations of layer conv2d_5 | Measured accuracy drop 0.004078 | Acceptable accuracy drop: 0.005435
# Quantizing layer conv2d_3
# Global opt: (3, 1) Local opt: (4, 1) Performance diff: 0.001529
# Chosen:  (4, 1)
# After quantizing activations of layer conv2d_3 | Measured accuracy drop 0.003161 | Acceptable accuracy drop: 0.005652
# Quantizing layer conv2d_8
# Global opt: (3, 0) Local opt: (4, 1) Performance diff: 0.000204
# Chosen:  (3, 0)
# After quantizing activations of layer conv2d_8 | Measured accuracy drop 0.005098 | Acceptable accuracy drop: 0.005870
# Quantizing layer conv2d_2
# Global opt: (7, 3) Local opt: (8, 3) Performance diff: 0.000612
# Chosen:  (7, 3)
# After quantizing activations of layer conv2d_2 | Measured accuracy drop 0.005914 | Acceptable accuracy drop: 0.006087
# Quantizing layer conv2d_6
# Global opt: (5, -1) Local opt: (6, -1) Performance diff: 0.000204
# Chosen:  (5, -1)
# After quantizing activations of layer conv2d_6 | Measured accuracy drop 0.004792 | Acceptable accuracy drop: 0.006304
# Quantizing layer conv2d_4
# Global opt: (4, -1) Local opt: (5, -1) Performance diff: 0.000306
# Chosen:  (4, -1)
# After quantizing activations of layer conv2d_4 | Measured accuracy drop 0.004690 | Acceptable accuracy drop: 0.006522
# Quantizing layer conv2d_7
# Global opt: (4, -2) Local opt: (4, -2) Performance diff: 0.000000
# Chosen:  (4, -2)
# After quantizing activations of layer conv2d_7 | Measured accuracy drop 0.005608 | Acceptable accuracy drop: 0.006739
# Quantizing layer conv2d_12
# Global opt: (2, -3) Local opt: (3, -3) Performance diff: 0.001325
# Chosen:  (2, -3)
# After quantizing activations of layer conv2d_12 | Measured accuracy drop 0.006321 | Acceptable accuracy drop: 0.006957
# Quantizing layer conv2d_10
# Global opt: (3, -2) Local opt: (4, -2) Performance diff: 0.000102
# Chosen:  (3, -2)
# After quantizing activations of layer conv2d_10 | Measured accuracy drop 0.005506 | Acceptable accuracy drop: 0.007174
# Quantizing layer conv2d_15
# Global opt: (2, -1) Local opt: (3, -1) Performance diff: 0.001835
# Chosen:  (3, -1)
# After quantizing activations of layer conv2d_15 | Measured accuracy drop 0.005404 | Acceptable accuracy drop: 0.007391
# Quantizing layer conv2d_9
# Global opt: (3, -3) Local opt: (2, -2) Performance diff: 0.002753
# Chosen:  (2, -2)
# After quantizing activations of layer conv2d_9 | Measured accuracy drop 0.004078 | Acceptable accuracy drop: 0.007609
# Quantizing layer conv2d_13
# Global opt: (4, -2) Local opt: (5, -1) Performance diff: 0.001733
# Chosen:  (5, -1)
# After quantizing activations of layer conv2d_13 | Measured accuracy drop 0.003569 | Acceptable accuracy drop: 0.007826
# Quantizing layer conv2d_11
# Global opt: (3, -3) Local opt: (4, -3) Performance diff: 0.001122
# Chosen:  (3, -3)
# After quantizing activations of layer conv2d_11 | Measured accuracy drop 0.005710 | Acceptable accuracy drop: 0.008043
# Quantizing layer conv2d_14
# Global opt: (3, -3) Local opt: (4, -2) Performance diff: 0.000306
# Chosen:  (3, -3)
# After quantizing activations of layer conv2d_14 | Measured accuracy drop 0.006321 | Acceptable accuracy drop: 0.008261
# Quantizing layer conv2d_19
# Global opt: (4, -2) Local opt: (5, -1) Performance diff: 0.000612
# Chosen:  (4, -2)
# After quantizing activations of layer conv2d_19 | Measured accuracy drop 0.007443 | Acceptable accuracy drop: 0.008478
# Quantizing layer conv2d_17
# Global opt: (3, -2) Local opt: (4, -1) Performance diff: 0.000306
# Chosen:  (3, -2)
# After quantizing activations of layer conv2d_17 | Measured accuracy drop 0.008055 | Acceptable accuracy drop: 0.008696
# Quantizing layer conv2d_22
# Global opt: (2, -2) Local opt: (2, -2) Performance diff: 0.000000
# Chosen:  (2, -2)
# After quantizing activations of layer conv2d_22 | Measured accuracy drop 0.007035 | Acceptable accuracy drop: 0.008913
# Quantizing layer conv2d_16
# Global opt: (2, -3) Local opt: (3, -2) Performance diff: 0.001835
# Chosen:  (3, -2)
# After quantizing activations of layer conv2d_16 | Measured accuracy drop 0.007239 | Acceptable accuracy drop: 0.009130
# Quantizing layer conv2d_20
# Global opt: (4, -3) Local opt: (5, -2) Performance diff: 0.001325
# Chosen:  (4, -3)
# After quantizing activations of layer conv2d_20 | Measured accuracy drop 0.009074 | Acceptable accuracy drop: 0.009348
# Quantizing layer conv2d_18
# Global opt: (3, -3) Local opt: (4, -3) Performance diff: 0.000102
# Chosen:  (3, -3)
# After quantizing activations of layer conv2d_18 | Measured accuracy drop 0.009482 | Acceptable accuracy drop: 0.009565
# Quantizing layer conv2d_21
# Global opt: (5, -1) Local opt: (5, -1) Performance diff: 0.000000
# Chosen:  (5, -1)
# After quantizing activations of layer conv2d_21 | Measured accuracy drop 0.009074 | Acceptable accuracy drop: 0.009783
# Quantizing layer binary
# Global opt: (7, 2) Local opt: (8, 3) Performance diff: 0.000510
# Chosen:  (7, 2)
# After quantizing activations of layer binary | Measured accuracy drop 0.009890 | Acceptable accuracy drop: 0.010000
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-5cbd7fa8f3be> in <module>
#       4
#       5 a_scores, opt_params_act, acc_drop_a = opts.run(acc_drop_config, 'activations', start_bw = 12)
# ----> 6 opts.plot_scores_matrix(a_scores, 5, 3, (20, 30))
#
# C:/Users/320060820/experiments\algorithms\optimized_search.py in plot_scores_matrix(scores_dict, rows, columns, figsize)
#     407
#     408         for df, i in zip(layer_dfs, np.arange(len(layer_dfs))):
# --> 409             sns.heatmap(df, annot=True, fmt='.3f', ax=ax[i])
#     410             ax[i].set_xlabel('Fractional offset')
#     411             ax[i].set_ylabel('Bitwidth')
#
# IndexError: index 15 is out of bounds for size 15

# %%
opts.quant_evaluator.quant_params
# Out:
# QuantizationParameters(weights={'conv2d_1': (5, 5), 'conv2d_5': (3, 2), 'conv2d_3': (3, 2), 'conv2d_8': (2, 1), 'conv2d_2': (4, 3), 'conv2d_6': (4, 3), 'conv2d_4': (2, 1), 'conv2d_7': (3, 2), 'conv2d_12': (2, 1), 'conv2d_10': (2, 1), 'conv2d_15': (2, 1), 'conv2d_9': (3, 2), 'conv2d_13': (4, 3), 'conv2d_11': (3, 2), 'conv2d_14': (4, 3), 'conv2d_19': (3, 2), 'conv2d_17': (3, 2), 'conv2d_22': (2, 1), 'conv2d_16': (2, 1), 'conv2d_20': (2, 1), 'conv2d_18': (2, 1), 'conv2d_21': (2, 1), 'binary': (4, 3)}, biases={'conv2d_1': (5, 7), 'conv2d_5': (2, 1), 'conv2d_3': (2, 2), 'conv2d_8': (2, 1), 'conv2d_2': (1, 1), 'conv2d_6': (1, 0), 'conv2d_4': (1, 1), 'conv2d_7': (1, 0), 'conv2d_12': (1, 0), 'conv2d_10': (1, 0), 'conv2d_15': (1, -1), 'conv2d_9': (2, 1), 'conv2d_13': (1, 0), 'conv2d_11': (1, 0), 'conv2d_14': (1, 0), 'conv2d_19': (1, -1), 'conv2d_17': (1, -1), 'conv2d_22': (1, 0), 'conv2d_16': (1, 0), 'conv2d_20': (1, -1), 'conv2d_18': (1, -1), 'conv2d_21': (1, 0), 'binary': (1, 2)}, activations={'conv2d_1': (8, 7), 'conv2d_5': (3, -1), 'conv2d_3': (4, 1), 'conv2d_8': (3, 0), 'conv2d_2': (7, 3), 'conv2d_6': (5, -1), 'conv2d_4': (4, -1), 'conv2d_7': (4, -2), 'conv2d_12': (2, -3), 'conv2d_10': (3, -2), 'conv2d_15': (3, -1), 'conv2d_9': (2, -2), 'conv2d_13': (5, -1), 'conv2d_11': (3, -3), 'conv2d_14': (3, -3), 'conv2d_19': (4, -2), 'conv2d_17': (3, -2), 'conv2d_22': (2, -2), 'conv2d_16': (3, -2), 'conv2d_20': (4, -3), 'conv2d_18': (3, -3), 'conv2d_21': (5, -1), 'binary': (7, 2)})

# %%
model_obj = fxp_quantize.fix_model_quantization(model_arch, name, test_data, opts.quant_evaluator.quant_params)
print(f'Floating point network accuracy: {float_model_acc * 100}%')
fxp_model_acc = model_obj.evaluate_accuracy()[1]
print(f'Fixed-point network accuracy: {fxp_model_acc * 100}%')
print(f'Accuracy loss of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f}%')

# Save results
scores = {
    'weights': w_scores,
    'biases': b_scores,
    'activations': a_scores
}
acc_drop = {
    'weights': acc_drop_w,
    'biases': acc_drop_b,
    'activations': acc_drop_a
}

save_results(scores, acc_drop, opts.quant_evaluator.quant_params._asdict(), output_path)
# Out:
# Floating point network accuracy: 98.08%
# Fixed-point network accuracy: 97.11%
# Accuracy loss of 0.989%
