# %%
import sys
sys.path.append('C:/Users/320060820/experiments/')
import fxp_quantize
import model_data
from algorithms import fixed_bitwidth
from model_gen import keras_cnn
from algorithms.optimized_search import OptimizedSearch

import keras
import tensorflow as tf
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import pandas as pd
import pickle

# to restart layer numbering
from keras import backend as K
K.clear_session()

# %% [markdown]
# ## Dependent Optimized Search quantization

# %%
input_shape = (32, 32, 3)
num_outputs = 10
num_kernels = 32
num_stages = 7
path_trained_weights = 'C:/Users/320060820/experiments/test_models/cifar_keras/cifar_seq_large_w.h5'
output_path = 'C:/Users/320060820/experiments/outputs/Dependent_Optimized_Search/F Sequential L CIFAR10/'
name = 'cifar_seq_large'

from test_models.cifar_keras import data
_, test_data = data.get_data()

model_arch = keras_cnn.KerasCNNLarge(input_shape, num_outputs, num_kernels, num_stages, pool_layer_interval = 2, 
                                     path_trained_weights = path_trained_weights)
model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
float_model_acc = model_obj.evaluate_accuracy()[1]
# Out:
# WARNING:tensorflow:From C:\Users\320060820\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\320060820\Anaconda3\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
layer_names = [layer.name for layer in model_obj.model.layers if layer.name.startswith('conv2d') or \
               layer.name.startswith('dense')]
print(layer_names)
# Out:
# ['conv2d_1', 'conv2d_2', 'conv2d_3', 'conv2d_4', 'conv2d_5', 'conv2d_6', 'conv2d_7', 'conv2d_8', 'conv2d_9', 'conv2d_10', 'conv2d_11', 'conv2d_12', 'conv2d_13', 'conv2d_14', 'dense_1']

# %% [markdown]
# ### Function design for allocating accuracy drops per layer

# %%
total_acc_drop = 0.005
# Functions
# x: layer index
# n: total accuracy drop
# s: scale/number of layers
linear = lambda x, n, s: n/s * x
quadratic = lambda x, n, s: n/s**2 * x**2
cubic = lambda x, n, s: n/s**3 * x**3
exponential = lambda x, n, s: n/2**s * 2**x
log = lambda x, n, s: n/np.log(s) * np.log(x)
alloc_types = ['constant', 'linear', 'quadratic', 'cubic', 'exponential', 'log']

# %%
x = np.arange(1, len(layer_names) + 1, 1)
num_layers = len(x)
n = 0.005 # loss of 0.5%
y1 = np.ones(x.shape) * n # constant
y2 = linear(x, n, num_layers)
y3 = quadratic(x, n, num_layers) # Quadratic
y4 = cubic(x, n, num_layers) # Cubic
y5 = exponential(x, n, num_layers) # Exponential
y6 = log(x, n, num_layers) # log

plt.figure(figsize=(10, 7))
plt.plot(x, y1, 'o-', label='constant');
plt.plot(x, y2, 'o-', label='linear');
plt.plot(x, y3, 'o-', label='quadratic');
plt.plot(x, y4, 'o-', label='cubic');
plt.plot(x, y5, 'o-', label='exponential');
plt.plot(x, y6, 'o-', label='log');
plt.grid();
plt.legend();

# %%
start_bw = 11
w_scores = {}
opt_params_weights = {}
acc_drop_w = {}

# %% [markdown]
# #### Constant

# %%
alloc_type = 'constant'
acc_drop_config = {
    layer: total_acc_drop for layer in layer_names
}
opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
w_scores[alloc_type], opt_params_weights[alloc_type], acc_drop_w[alloc_type] = opts.run('weights', start_bw = start_bw)
# Out:
# {'conv2d_1': [11, 12], 'conv2d_2': [11, 12], 'conv2d_3': [11, 12], 'conv2d_4': [11, 12], 'conv2d_5': [11, 12], 'conv2d_6': [11, 12], 'conv2d_7': [11, 12], 'conv2d_8': [11, 12], 'conv2d_9': [11, 12], 'conv2d_10': [11, 12], 'conv2d_11': [11, 12], 'conv2d_12': [11, 12], 'conv2d_13': [11, 12], 'conv2d_14': [11, 12], 'dense_1': [11, 10]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (6, 7) (6, 7) 0.0
# Chosen:  (6, 7)
# After quantizing layer conv2d_1 | Measured accuracy drop 0.003396821545553833 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_2
# (4, 5) (5, 6) 0.0014557806623801757
# Chosen:  (4, 5)
# After quantizing layer conv2d_2 | Measured accuracy drop 0.00388208176634718 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_3
# (5, 6) (5, 6) 0.0
# Chosen:  (5, 6)
# After quantizing layer conv2d_3 | Measured accuracy drop 0.002790246269562149 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_4
# (6, 7) (7, 8) 0.0019410408831736577
# Chosen:  (7, 8)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.0026689312143636777 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_5
# (5, 6) (5, 6) 0.0
# Chosen:  (5, 6)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.002911561324760486 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_6
# (4, 5) (5, 6) 0.0018197258279751857
# Chosen:  (5, 6)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.003032876379958823 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_7
# (4, 6) (5, 6) 0.0004852602207933469
# Chosen:  (4, 6)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.0024263011039670043 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_8
# (4, 5) (4, 6) 0.0001213150551983371
# Chosen:  (4, 6)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.002911561324760486 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_9
# (4, 6) (5, 6) 0.00024263011039667333
# Chosen:  (4, 6)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.0026689312143636777 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_10
# (3, 5) (3, 5) 0.0
# Chosen:  (3, 5)
# After quantizing layer conv2d_10 | Measured accuracy drop -0.00036394516559501026 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_11
# (3, 5) (4, 6) 0.0010918354967851653
# Chosen:  (3, 5)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.0018197258279753206 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_12
# (2, 4) (3, 4) 0.00024263011039667333
# Chosen:  (2, 4)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.004609972097537335 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_13
# (5, 6) (6, 7) 0.0006065752759916833
# Chosen:  (5, 6)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.004973917263132345 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_14
# (6, 7) (5, 6) 0.00012131505519833666
# Chosen:  (5, 6)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.004609972097537335 | Acceptable accuracy drop: 0.005
# Quantizing layer dense_1
# (7, 7) (8, 7) 0.00012131505519833666
# Chosen:  (7, 7)
# After quantizing layer dense_1 | Measured accuracy drop 0.004488657042338999 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_weights[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
    model_obj = fxp_quantize.fix_weights_quantization(model_obj, opt_params_weights[alloc_type])
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(w_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 82.430 %
# Quantized model accuracy: 82.060 %
# Accuracy drop of 0.449 %

# %% [markdown]
# #### Linear

# %%
alloc_type = 'linear'

acc_drop_config = {
    layer_names[i - 1]: linear(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
w_scores[alloc_type], opt_params_weights[alloc_type], acc_drop_w[alloc_type] = opts.run('weights', start_bw = start_bw)
# Out:
# {'conv2d_1': [11, 12], 'conv2d_2': [11, 12], 'conv2d_3': [11, 12], 'conv2d_4': [11, 12], 'conv2d_5': [11, 12], 'conv2d_6': [11, 12], 'conv2d_7': [11, 12], 'conv2d_8': [11, 12], 'conv2d_9': [11, 12], 'conv2d_10': [11, 12], 'conv2d_11': [11, 12], 'conv2d_12': [11, 12], 'conv2d_13': [11, 12], 'conv2d_14': [11, 12], 'dense_1': [11, 10]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (10, 11) (10, 11) 0.0
# Chosen:  (10, 11)
# After quantizing layer conv2d_1 | Measured accuracy drop -0.00012131505519833675 | Acceptable accuracy drop: 0.0003333333333333333
# Quantizing layer conv2d_2
# (5, 7) (6, 7) 0.0007278903311900205
# Chosen:  (5, 7)
# After quantizing layer conv2d_2 | Measured accuracy drop 0.00012131505519833675 | Acceptable accuracy drop: 0.0006666666666666666
# Quantizing layer conv2d_3
# (6, 7) (6, 7) 0.0
# Chosen:  (6, 7)
# After quantizing layer conv2d_3 | Measured accuracy drop -0.00012131505519833675 | Acceptable accuracy drop: 0.001
# Quantizing layer conv2d_4
# (5, 6) (6, 6) 0.00012131505519833677
# Chosen:  (5, 6)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.000849205386388492 | Acceptable accuracy drop: 0.0013333333333333333
# Quantizing layer conv2d_5
# (7, 8) (7, 8) 0.0
# Chosen:  (7, 8)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.0007278903311901552 | Acceptable accuracy drop: 0.0016666666666666666
# Quantizing layer conv2d_6
# (7, 8) (7, 8) 0.0
# Chosen:  (7, 8)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.0009705204415868287 | Acceptable accuracy drop: 0.002
# Quantizing layer conv2d_7
# (4, 6) (5, 6) 0.0004852602207933471
# Chosen:  (4, 6)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.002183670993570331 | Acceptable accuracy drop: 0.002333333333333333
# Quantizing layer conv2d_8
# (4, 6) (5, 6) 0.00012131505519833666
# Chosen:  (4, 6)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.0018197258279753206 | Acceptable accuracy drop: 0.0026666666666666666
# Quantizing layer conv2d_9
# (4, 6) (4, 6) 0.0
# Chosen:  (4, 6)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.0004852602207934817 | Acceptable accuracy drop: 0.003
# Quantizing layer conv2d_10
# (3, 5) (3, 5) 0.0
# Chosen:  (3, 5)
# After quantizing layer conv2d_10 | Measured accuracy drop -0.0006065752759916838 | Acceptable accuracy drop: 0.003333333333333333
# Quantizing layer conv2d_11
# (4, 5) (4, 6) 0.0024263011039670043
# Chosen:  (4, 6)
# After quantizing layer conv2d_11 | Measured accuracy drop -0.00012131505519833675 | Acceptable accuracy drop: 0.0036666666666666666
# Quantizing layer conv2d_12
# (2, 4) (3, 5) 0.0024263011039670043
# Chosen:  (3, 5)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.000849205386388492 | Acceptable accuracy drop: 0.004
# Quantizing layer conv2d_13
# (2, 4) (3, 5) 0.0006065752759918183
# Chosen:  (2, 4)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.001577095717578647 | Acceptable accuracy drop: 0.004333333333333333
# Quantizing layer conv2d_14
# (3, 4) (4, 5) 0.0014557806623801755
# Chosen:  (3, 4)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.003396821545553833 | Acceptable accuracy drop: 0.004666666666666666
# Quantizing layer dense_1
# (4, 3) (4, 3) 0.0
# Chosen:  (4, 3)
# After quantizing layer dense_1 | Measured accuracy drop 0.0037607667111488434 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_weights[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
    model_obj = fxp_quantize.fix_weights_quantization(model_obj, opt_params_weights[alloc_type])
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(w_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 82.430 %
# Quantized model accuracy: 82.120 %
# Accuracy drop of 0.376 %

# %% [markdown]
# #### Quadratic

# %%
alloc_type = 'quadratic'

acc_drop_config = {
    layer_names[i - 1]: quadratic(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
w_scores[alloc_type], opt_params_weights[alloc_type], acc_drop_w[alloc_type] = opts.run('weights', start_bw = start_bw)
# Out:
# {'conv2d_1': [11, 12], 'conv2d_2': [11, 12], 'conv2d_3': [11, 12], 'conv2d_4': [11, 12], 'conv2d_5': [11, 12], 'conv2d_6': [11, 12], 'conv2d_7': [11, 12], 'conv2d_8': [11, 12], 'conv2d_9': [11, 12], 'conv2d_10': [11, 12], 'conv2d_11': [11, 12], 'conv2d_12': [11, 12], 'conv2d_13': [11, 12], 'conv2d_14': [11, 12], 'dense_1': [11, 10]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (10, 11) (10, 11) 0.0
# Chosen:  (10, 11)
# After quantizing layer conv2d_1 | Measured accuracy drop -0.00012131505519833675 | Acceptable accuracy drop: 2.2222222222222223e-05
# Quantizing layer conv2d_2
# (9, 11) (9, 11) 0.0
# Chosen:  (9, 11)
# After quantizing layer conv2d_2 | Measured accuracy drop -0.000970520441586694 | Acceptable accuracy drop: 8.888888888888889e-05
# Quantizing layer conv2d_3
# (7, 8) (7, 8) 0.0
# Chosen:  (7, 8)
# After quantizing layer conv2d_3 | Measured accuracy drop -0.000970520441586694 | Acceptable accuracy drop: 0.0002
# Quantizing layer conv2d_4
# (6, 7) (6, 7) 0.0
# Chosen:  (6, 7)
# After quantizing layer conv2d_4 | Measured accuracy drop -0.0006065752759916838 | Acceptable accuracy drop: 0.00035555555555555557
# Quantizing layer conv2d_5
# (6, 7) (6, 7) 0.0
# Chosen:  (6, 7)
# After quantizing layer conv2d_5 | Measured accuracy drop -0.00036394516559501026 | Acceptable accuracy drop: 0.0005555555555555556
# Quantizing layer conv2d_6
# (5, 6) (5, 6) 0.0
# Chosen:  (5, 6)
# After quantizing layer conv2d_6 | Measured accuracy drop -0.0002426301103966735 | Acceptable accuracy drop: 0.0008
# Quantizing layer conv2d_7
# (4, 6) (5, 6) 0.00012131505519833677
# Chosen:  (4, 6)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.000849205386388492 | Acceptable accuracy drop: 0.001088888888888889
# Quantizing layer conv2d_8
# (5, 7) (6, 7) 0.00048526022079334704
# Chosen:  (5, 7)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.000849205386388492 | Acceptable accuracy drop: 0.0014222222222222223
# Quantizing layer conv2d_9
# (4, 6) (4, 6) 0.0
# Chosen:  (4, 6)
# After quantizing layer conv2d_9 | Measured accuracy drop -0.00036394516559501026 | Acceptable accuracy drop: 0.0018000000000000002
# Quantizing layer conv2d_10
# (3, 5) (3, 5) 0.0
# Chosen:  (3, 5)
# After quantizing layer conv2d_10 | Measured accuracy drop -0.0024263011039670043 | Acceptable accuracy drop: 0.0022222222222222222
# Quantizing layer conv2d_11
# (3, 5) (4, 6) 0.0006065752759918184
# Chosen:  (3, 5)
# After quantizing layer conv2d_11 | Measured accuracy drop -0.0006065752759916838 | Acceptable accuracy drop: 0.002688888888888889
# Quantizing layer conv2d_12
# (2, 4) (3, 5) 0.0036394516559505067
# Chosen:  (3, 5)
# After quantizing layer conv2d_12 | Measured accuracy drop -0.0037607667111488434 | Acceptable accuracy drop: 0.0032
# Quantizing layer conv2d_13
# (2, 4) (3, 4) 0.0037607667111488434
# Chosen:  (3, 4)
# After quantizing layer conv2d_13 | Measured accuracy drop -0.0023049860487686677 | Acceptable accuracy drop: 0.003755555555555556
# Quantizing layer conv2d_14
# (2, 3) (3, 4) 0.006308382870314185
# Chosen:  (3, 4)
# After quantizing layer conv2d_14 | Measured accuracy drop -0.0037607667111488434 | Acceptable accuracy drop: 0.004355555555555556
# Quantizing layer dense_1
# (3, 2) (4, 3) 0.0026689312143636777
# Chosen:  (4, 3)
# After quantizing layer dense_1 | Measured accuracy drop 0.000849205386388492 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_weights[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
    model_obj = fxp_quantize.fix_weights_quantization(model_obj, opt_params_weights[alloc_type])
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(w_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 82.430 %
# Quantized model accuracy: 82.360 %
# Accuracy drop of 0.085 %

# %% [markdown]
# ### Cubic

# %%
alloc_type = 'cubic'

acc_drop_config = {
    layer_names[i - 1]: cubic(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
w_scores[alloc_type], opt_params_weights[alloc_type], acc_drop_w[alloc_type] = opts.run('weights', start_bw = start_bw)
# Out:
# {'conv2d_1': [11, 12], 'conv2d_2': [11, 12], 'conv2d_3': [11, 12], 'conv2d_4': [11, 12], 'conv2d_5': [11, 12], 'conv2d_6': [11, 12], 'conv2d_7': [11, 12], 'conv2d_8': [11, 12], 'conv2d_9': [11, 12], 'conv2d_10': [11, 12], 'conv2d_11': [11, 12], 'conv2d_12': [11, 12], 'conv2d_13': [11, 12], 'conv2d_14': [11, 12], 'dense_1': [11, 10]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (10, 11) (10, 11) 0.0
# Chosen:  (10, 11)
# After quantizing layer conv2d_1 | Measured accuracy drop -0.00012131505519833675 | Acceptable accuracy drop: 1.4814814814814815e-06
# Quantizing layer conv2d_2
# (9, 11) (9, 11) 0.0
# Chosen:  (9, 11)
# After quantizing layer conv2d_2 | Measured accuracy drop -0.000970520441586694 | Acceptable accuracy drop: 1.1851851851851852e-05
# Quantizing layer conv2d_3
# (7, 8) (7, 8) 0.0
# Chosen:  (7, 8)
# After quantizing layer conv2d_3 | Measured accuracy drop -0.000970520441586694 | Acceptable accuracy drop: 3.9999999999999996e-05
# Quantizing layer conv2d_4
# (6, 7) (6, 7) 0.0
# Chosen:  (6, 7)
# After quantizing layer conv2d_4 | Measured accuracy drop -0.0006065752759916838 | Acceptable accuracy drop: 9.481481481481481e-05
# Quantizing layer conv2d_5
# (6, 7) (6, 7) 0.0
# Chosen:  (6, 7)
# After quantizing layer conv2d_5 | Measured accuracy drop -0.00036394516559501026 | Acceptable accuracy drop: 0.00018518518518518518
# Quantizing layer conv2d_6
# (5, 6) (5, 6) 0.0
# Chosen:  (5, 6)
# After quantizing layer conv2d_6 | Measured accuracy drop -0.0002426301103966735 | Acceptable accuracy drop: 0.00031999999999999997
# Quantizing layer conv2d_7
# (6, 8) (7, 8) 0.000485260220793347
# Chosen:  (6, 8)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 0.0005081481481481481
# Quantizing layer conv2d_8
# (4, 6) (5, 7) 0.001334465607181839
# Chosen:  (4, 6)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.0007278903311901552 | Acceptable accuracy drop: 0.0007585185185185185
# Quantizing layer conv2d_9
# (7, 9) (8, 9) 0.0003639451655950103
# Chosen:  (7, 9)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.0009705204415868287 | Acceptable accuracy drop: 0.00108
# Quantizing layer conv2d_10
# (7, 9) (6, 8) 0.0007278903311900204
# Chosen:  (6, 8)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.0006065752759918184 | Acceptable accuracy drop: 0.0014814814814814814
# Quantizing layer conv2d_11
# (4, 6) (5, 7) 0.0013344656071818388
# Chosen:  (4, 6)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.0018197258279753206 | Acceptable accuracy drop: 0.001971851851851852
# Quantizing layer conv2d_12
# (5, 7) (5, 7) 0.0
# Chosen:  (5, 7)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.001577095717578647 | Acceptable accuracy drop: 0.0025599999999999998
# Quantizing layer conv2d_13
# (3, 5) (4, 6) 0.0007278903311900204
# Chosen:  (3, 5)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.0024263011039670043 | Acceptable accuracy drop: 0.0032548148148148145
# Quantizing layer conv2d_14
# (2, 4) (3, 4) 0.00012131505519833666
# Chosen:  (2, 4)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.002547616159165341 | Acceptable accuracy drop: 0.004065185185185185
# Quantizing layer dense_1
# (4, 4) (5, 5) 0.0024263011039670048
# Chosen:  (5, 5)
# After quantizing layer dense_1 | Measured accuracy drop 0.002062355938371994 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_weights[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
    model_obj = fxp_quantize.fix_weights_quantization(model_obj, opt_params_weights[alloc_type])
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(w_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 82.430 %
# Quantized model accuracy: 82.260 %
# Accuracy drop of 0.206 %

# %% [markdown]
# ### Exponential

# %%
alloc_type = 'exponential'

acc_drop_config = {
    layer_names[i - 1]: exponential(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
w_scores[alloc_type], opt_params_weights[alloc_type], acc_drop_w[alloc_type] = opts.run('weights', start_bw = start_bw)
# Out:
# {'conv2d_1': [11, 12], 'conv2d_2': [11, 12], 'conv2d_3': [11, 12], 'conv2d_4': [11, 12], 'conv2d_5': [11, 12], 'conv2d_6': [11, 12], 'conv2d_7': [11, 12], 'conv2d_8': [11, 12], 'conv2d_9': [11, 12], 'conv2d_10': [11, 12], 'conv2d_11': [11, 12], 'conv2d_12': [11, 12], 'conv2d_13': [11, 12], 'conv2d_14': [11, 12], 'dense_1': [11, 10]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (10, 11) (10, 11) 0.0
# Chosen:  (10, 11)
# After quantizing layer conv2d_1 | Measured accuracy drop -0.00012131505519833675 | Acceptable accuracy drop: 3.0517578125e-07
# Quantizing layer conv2d_2
# (9, 11) (9, 11) 0.0
# Chosen:  (9, 11)
# After quantizing layer conv2d_2 | Measured accuracy drop -0.000970520441586694 | Acceptable accuracy drop: 6.103515625e-07
# Quantizing layer conv2d_3
# (7, 8) (7, 8) 0.0
# Chosen:  (7, 8)
# After quantizing layer conv2d_3 | Measured accuracy drop -0.000970520441586694 | Acceptable accuracy drop: 1.220703125e-06
# Quantizing layer conv2d_4
# (6, 7) (6, 7) 0.0
# Chosen:  (6, 7)
# After quantizing layer conv2d_4 | Measured accuracy drop -0.0006065752759916838 | Acceptable accuracy drop: 2.44140625e-06
# Quantizing layer conv2d_5
# (6, 7) (6, 7) 0.0
# Chosen:  (6, 7)
# After quantizing layer conv2d_5 | Measured accuracy drop -0.00036394516559501026 | Acceptable accuracy drop: 4.8828125e-06
# Quantizing layer conv2d_6
# (8, 9) (8, 9) 0.0
# Chosen:  (8, 9)
# After quantizing layer conv2d_6 | Measured accuracy drop -0.000485260220793347 | Acceptable accuracy drop: 9.765625e-06
# Quantizing layer conv2d_7
# (4, 6) (5, 6) 0.00012131505519833675
# Chosen:  (4, 6)
# After quantizing layer conv2d_7 | Measured accuracy drop -0.00012131505519833675 | Acceptable accuracy drop: 1.953125e-05
# Quantizing layer conv2d_8
# (9, 11) (9, 10) 0.000485260220793347
# Chosen:  (9, 10)
# After quantizing layer conv2d_8 | Measured accuracy drop -0.000485260220793347 | Acceptable accuracy drop: 3.90625e-05
# Quantizing layer conv2d_9
# (10, 11) (11, 12) 0.0003639451655950102
# Chosen:  (10, 11)
# After quantizing layer conv2d_9 | Measured accuracy drop -0.00012131505519833675 | Acceptable accuracy drop: 7.8125e-05
# Quantizing layer conv2d_10
# (8, 9) (8, 10) 0.00012131505519833675
# Chosen:  (8, 10)
# After quantizing layer conv2d_10 | Measured accuracy drop -0.00012131505519833675 | Acceptable accuracy drop: 0.00015625
# Quantizing layer conv2d_11
# (8, 10) (8, 10) 0.0
# Chosen:  (8, 10)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.0002426301103966735 | Acceptable accuracy drop: 0.0003125
# Quantizing layer conv2d_12
# (7, 8) (7, 8) 0.0
# Chosen:  (7, 8)
# After quantizing layer conv2d_12 | Measured accuracy drop -0.00012131505519833675 | Acceptable accuracy drop: 0.000625
# Quantizing layer conv2d_13
# (4, 6) (4, 6) 0.0
# Chosen:  (4, 6)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.0003639451655951449 | Acceptable accuracy drop: 0.00125
# Quantizing layer conv2d_14
# (2, 4) (3, 4) 0.0002426301103968082
# Chosen:  (2, 4)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.0004852602207934817 | Acceptable accuracy drop: 0.0025
# Quantizing layer dense_1
# (4, 3) (5, 4) 0.00424602693194219
# Chosen:  (5, 4)
# After quantizing layer dense_1 | Measured accuracy drop 0.0007278903311901552 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_weights[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
    model_obj = fxp_quantize.fix_weights_quantization(model_obj, opt_params_weights[alloc_type])
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(w_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 82.430 %
# Quantized model accuracy: 82.370 %
# Accuracy drop of 0.073 %

# %% [markdown]
# ### Log

# %%
alloc_type = 'log'

acc_drop_config = {
    layer_names[i - 1]: log(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
w_scores[alloc_type], opt_params_weights[alloc_type], acc_drop_w[alloc_type] = opts.run('weights', start_bw = start_bw)
# Out:
# {'conv2d_1': [11, 12], 'conv2d_2': [11, 12], 'conv2d_3': [11, 12], 'conv2d_4': [11, 12], 'conv2d_5': [11, 12], 'conv2d_6': [11, 12], 'conv2d_7': [11, 12], 'conv2d_8': [11, 12], 'conv2d_9': [11, 12], 'conv2d_10': [11, 12], 'conv2d_11': [11, 12], 'conv2d_12': [11, 12], 'conv2d_13': [11, 12], 'conv2d_14': [11, 12], 'dense_1': [11, 10]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (10, 11) (10, 11) 0.0
# Chosen:  (10, 11)
# After quantizing layer conv2d_1 | Measured accuracy drop -0.00012131505519833675 | Acceptable accuracy drop: 0.0
# Quantizing layer conv2d_2
# (5, 6) (6, 7) 0.0015770957175785124
# Chosen:  (6, 7)
# After quantizing layer conv2d_2 | Measured accuracy drop -0.0006065752759916838 | Acceptable accuracy drop: 0.0012797901240490775
# Quantizing layer conv2d_3
# (5, 6) (6, 7) 0.0006065752759916836
# Chosen:  (5, 6)
# After quantizing layer conv2d_3 | Measured accuracy drop 0.0013344656071818388 | Acceptable accuracy drop: 0.002028419355411065
# Quantizing layer conv2d_4
# (6, 7) (7, 8) 0.0006065752759916838
# Chosen:  (6, 7)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.0014557806623801757 | Acceptable accuracy drop: 0.002559580248098155
# Quantizing layer conv2d_5
# (5, 6) (5, 6) 0.0
# Chosen:  (5, 6)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.0006065752759918184 | Acceptable accuracy drop: 0.0029715806445889353
# Quantizing layer conv2d_6
# (4, 5) (5, 6) 0.0006065752759916838
# Chosen:  (4, 5)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.0014557806623801757 | Acceptable accuracy drop: 0.003308209479460142
# Quantizing layer conv2d_7
# (4, 6) (5, 7) 0.000363945165595145
# Chosen:  (4, 6)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.0004852602207934817 | Acceptable accuracy drop: 0.0035928251039498895
# Quantizing layer conv2d_8
# (4, 5) (5, 6) 0.0014557806623801757
# Chosen:  (4, 5)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.0018197258279753206 | Acceptable accuracy drop: 0.0038393703721472322
# Quantizing layer conv2d_9
# (4, 6) (4, 6) 0.0
# Chosen:  (4, 6)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.0014557806623801757 | Acceptable accuracy drop: 0.00405683871082213
# Quantizing layer conv2d_10
# (3, 5) (4, 5) 0.0006065752759918185
# Chosen:  (3, 5)
# After quantizing layer conv2d_10 | Measured accuracy drop -0.0008492053863883572 | Acceptable accuracy drop: 0.0042513707686380135
# Quantizing layer conv2d_11
# (3, 5) (3, 5) 0.0
# Chosen:  (3, 5)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 0.004427346420355128
# Quantizing layer conv2d_12
# (3, 4) (3, 5) 0.003032876379958688
# Chosen:  (3, 5)
# After quantizing layer conv2d_12 | Measured accuracy drop -0.0006065752759916838 | Acceptable accuracy drop: 0.00458799960350922
# Quantizing layer conv2d_13
# (3, 4) (4, 5) 0.0029115613247603514
# Chosen:  (4, 5)
# After quantizing layer conv2d_13 | Measured accuracy drop -0.000970520441586694 | Acceptable accuracy drop: 0.004735786205915922
# Quantizing layer conv2d_14
# (2, 4) (3, 5) 0.004246026931942325
# Chosen:  (3, 5)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.0002426301103966735 | Acceptable accuracy drop: 0.004872615227998966
# Quantizing layer dense_1
# (2, 2) (2, 2) 0.0
# Chosen:  (2, 2)
# After quantizing layer dense_1 | Measured accuracy drop 0.004367341987140662 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_weights[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
    model_obj = fxp_quantize.fix_weights_quantization(model_obj, opt_params_weights[alloc_type])
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(w_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 82.430 %
# Quantized model accuracy: 82.070 %
# Accuracy drop of 0.437 %

# %%
with open(output_path + 'fixed/w_scores.p', 'wb') as f:
    pickle.dump(w_scores, f, protocol=pickle.HIGHEST_PROTOCOL)

with open(output_path + 'fixed/opt_params_w.p', 'wb') as f:
    pickle.dump(opt_params_weights, f, protocol=pickle.HIGHEST_PROTOCOL)

with open(output_path + 'fixed/acc_drop_w.p', 'wb') as f:
    pickle.dump(acc_drop_w, f, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Observing results for the types of allocations

# %%
## Bitwidths
x = np.arange(1, len(layer_names) + 1, 1)

plt.figure(figsize=(10, 7))
for k in opt_params_weights:
    bw = [opt_params_weights[k][layer][0] for layer in opt_params_weights[k]]
    plt.plot(x, bw, 'o-', label=k)
plt.xticks(x, layer_names, rotation='vertical')
plt.title('Bitwidths')
plt.xlabel('Layers');
plt.ylabel('Bitwidth');
plt.grid()
plt.legend();

# %%
plt.figure(figsize=(20, 7))
width = 0.35
x = np.arange(1, 3*len(layer_names) + 1, 3)
for j, k in enumerate(opt_params_weights.keys()):
    bw = [opt_params_weights[k][layer][0] for layer in opt_params_weights[k]]
    plt.bar([i + j*width for i in x], bw, width, label=k)
plt.xticks(x, layer_names, rotation='vertical')
plt.title('Bitwidths')
plt.xlabel('Layers');
plt.ylabel('Bitwidth');
plt.grid()
plt.legend();

# %%
## Accuracy drop
x = np.arange(1, len(layer_names) + 1, 1)

plt.figure(figsize=(10, 7))
for k in acc_drop_w:
    plt.plot(x, acc_drop_w[k].values(), 'o-', label=k)
plt.title('Accuracy drop');
plt.xlabel('Layers');
plt.ylabel('Accuracy drop');
plt.xticks(x, layer_names, rotation='vertical');
plt.grid()
plt.legend();

# %%
x = np.arange(1, 16, 1)
num_layers = len(x)
n = 0.005 # loss of 0.5%
y1 = np.ones(x.shape) * n # constant
y2 = n/num_layers * x
y3 = n/num_layers**2 * x**2 # Quadratic
y4 = n/num_layers**3 * x**3 # Cubic
y5 = n/2**num_layers * 2**x # Exponential
y6 = n/np.log(num_layers) * np.log(x) # log

fig, axes = plt.subplots(3, 2, figsize=(20, 27))
ax = axes.flatten()
ax[0].plot(x, y1, 'o-', label='ideal');
ax[0].plot(x, acc_drop_w['constant'].values(), 'o-', label='measured');

ax[1].plot(x, y2, 'o-', label='ideal');
ax[1].plot(x, acc_drop_w['linear'].values(), 'o-', label='measured');

ax[2].plot(x, y3, 'o-', label='ideal');
ax[2].plot(x, acc_drop_w['quadratic'].values(), 'o-', label='measured');

ax[3].plot(x, y4, 'o-', label='ideal');
ax[3].plot(x, acc_drop_w['cubic'].values(), 'o-', label='measured');

ax[4].plot(x, y5, 'o-', label='ideal');
ax[4].plot(x, acc_drop_w['exponential'].values(), 'o-', label='measured');

ax[5].plot(x, y6, 'o-', label='ideal');
ax[5].plot(x, acc_drop_w['log'].values(), 'o-', label='measured');

for i in range(6):
    ax[i].set_xticks(x)
    ax[i].set_xticklabels(layer_names, rotation=90)
    # plt.title('Accuracy drop');
    ax[i].set_xlabel('Layers');
    ax[i].set_ylabel('Accuracy drop');
    ax[i].grid();
    ax[i].legend();

# %%
model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())

# %%
num_params = []
for layer in model_obj.model.layers:
    if layer.weights and layer.name.startswith('conv2d') or layer.name.startswith('dense'):
        w = layer.get_weights()[0]
        num_weights = len(w.flatten())
        print(layer.name, num_weights)
        num_params.append(num_weights)
# Out:
# conv2d_1 864
# conv2d_2 9216
# conv2d_3 9216
# conv2d_4 9216
# conv2d_5 9216
# conv2d_6 9216
# conv2d_7 18432
# conv2d_8 36864
# conv2d_9 36864
# conv2d_10 36864
# conv2d_11 36864
# conv2d_12 36864
# conv2d_13 36864
# conv2d_14 36864
# dense_1 640

# %%
total_memory = {}
for k in opt_params_weights:
    bw = [opt_params_weights[k][layer][0] for layer in opt_params_weights[k]]
    total_memory[k] = sum([bw[i] * num_params[i] for i in range(len(layer_names))])

memory_consumption = [total_memory[k] for k in total_memory]
memory_consumption_MB = [i/(8*1024**2) for i in memory_consumption]

# %%
plt.figure(figsize=(10, 7))
plt.bar(np.arange(1, len(memory_consumption_MB) + 1, 1), memory_consumption_MB);
plt.xticks(np.arange(1, len(memory_consumption_MB) + 1, 1), total_memory.keys(), rotation='horizontal');
plt.ylabel('Memory consumption (MB)');

# %% [markdown]
# # Activations

# %%
start_bw = 12
a_scores = {}
opt_params_act = {}
acc_drop_a = {}

# %%
alloc_type = 'constant'

acc_drop_config = {
    layer: 0.005 for layer in layer_names
}
opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
a_scores[alloc_type], opt_params_act[alloc_type], acc_drop_a[alloc_type] = opts.run('activations', start_bw = start_bw)
# Out:
# {'conv2d_1': [12, 11], 'conv2d_2': [12, 8], 'conv2d_3': [12, 7], 'conv2d_4': [12, 7], 'conv2d_5': [12, 6], 'conv2d_6': [12, 7], 'conv2d_7': [12, 7], 'conv2d_8': [12, 7], 'conv2d_9': [12, 6], 'conv2d_10': [12, 7], 'conv2d_11': [12, 7], 'conv2d_12': [12, 6], 'conv2d_13': [12, 6], 'conv2d_14': [12, 6], 'dense_1': [12, 6]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (6, 6) (7, 7) 0.002304986048768668
# Chosen:  (7, 7)
# After quantizing layer conv2d_1 | Measured accuracy drop 0.0013344656071818388 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_2
# (5, 2) (6, 3) 0.0014557806623803102
# Chosen:  (5, 2)
# After quantizing layer conv2d_2 | Measured accuracy drop 0.004124711876743988 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_3
# (6, 2) (7, 3) 0.0014557806623801762
# Chosen:  (6, 2)
# After quantizing layer conv2d_3 | Measured accuracy drop 0.004246026931942325 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_4
# (4, 0) (4, 0) 0.0
# Chosen:  (4, 0)
# After quantizing layer conv2d_4 | Measured accuracy drop -0.0015770957175785124 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_5
# (4, -1) (5, 0) 0.0033968215455538325
# Chosen:  (5, 0)
# After quantizing layer conv2d_5 | Measured accuracy drop -0.0013344656071818388 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_6
# (4, 0) (5, 1) 0.001819725827975186
# Chosen:  (5, 1)
# After quantizing layer conv2d_6 | Measured accuracy drop -0.0016984107727768493 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_7
# (3, 0) (4, 1) 0.004246026931942325
# Chosen:  (4, 1)
# After quantizing layer conv2d_7 | Measured accuracy drop -0.0010918354967851655 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_8
# (4, 0) (5, 1) 0.0027902462695620148
# Chosen:  (5, 1)
# After quantizing layer conv2d_8 | Measured accuracy drop -0.0015770957175785124 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_9
# (4, -1) (5, 0) 0.003396821545553833
# Chosen:  (5, 0)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.00012131505519833675 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_10
# (4, 0) (5, 1) 0.002062355938371994
# Chosen:  (5, 1)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_11
# (3, 0) (4, 0) 0.001334465607181839
# Chosen:  (3, 0)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.001698410772776984 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_12
# (4, 0) (5, 1) 0.00024263011039667333
# Chosen:  (4, 0)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.00388208176634718 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_13
# (3, -1) (4, 0) 0.002668931214363678
# Chosen:  (4, 0)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.002062355938371994 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_14
# (4, 1) (5, 1) 0.0006065752759918186
# Chosen:  (4, 1)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.0019410408831736575 | Acceptable accuracy drop: 0.005
# Quantizing layer dense_1
# (4, 0) (5, 1) 0.0029115613247603514
# Chosen:  (5, 1)
# After quantizing layer dense_1 | Measured accuracy drop 0.001577095717578647 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_act[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_fxp_model(opt_params_act[alloc_type]))
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(a_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 82.430 %
# Quantized model accuracy: 82.300 %
# Accuracy drop of 0.158 %

# %% [markdown]
# #### Linear

# %%
alloc_type = 'linear'

acc_drop_config = {
    layer_names[i - 1]: linear(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
a_scores[alloc_type], opt_params_act[alloc_type], acc_drop_a[alloc_type] = opts.run('activations', start_bw = start_bw)
# Out:
# {'conv2d_1': [12, 11], 'conv2d_2': [12, 8], 'conv2d_3': [12, 7], 'conv2d_4': [12, 7], 'conv2d_5': [12, 6], 'conv2d_6': [12, 7], 'conv2d_7': [12, 7], 'conv2d_8': [12, 7], 'conv2d_9': [12, 6], 'conv2d_10': [12, 7], 'conv2d_11': [12, 7], 'conv2d_12': [12, 6], 'conv2d_13': [12, 6], 'conv2d_14': [12, 6], 'dense_1': [12, 6]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (10, 10) (11, 10) 0.0002426301103966735
# Chosen:  (10, 10)
# After quantizing layer conv2d_1 | Measured accuracy drop 0.0002426301103966735 | Acceptable accuracy drop: 0.0003333333333333333
# Quantizing layer conv2d_2
# (8, 5) (7, 4) 0.0002426301103966735
# Chosen:  (7, 4)
# After quantizing layer conv2d_2 | Measured accuracy drop 0.0003639451655951449 | Acceptable accuracy drop: 0.0006666666666666666
# Quantizing layer conv2d_3
# (9, 5) (9, 5) 0.0
# Chosen:  (9, 5)
# After quantizing layer conv2d_3 | Measured accuracy drop 0.0002426301103966735 | Acceptable accuracy drop: 0.001
# Quantizing layer conv2d_4
# (5, 1) (4, 0) 0.002911561324760351
# Chosen:  (4, 0)
# After quantizing layer conv2d_4 | Measured accuracy drop -0.0026689312143636777 | Acceptable accuracy drop: 0.0013333333333333333
# Quantizing layer conv2d_5
# (4, -1) (5, 0) 0.0012131505519835022
# Chosen:  (4, -1)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 0.0016666666666666666
# Quantizing layer conv2d_6
# (5, 1) (5, 1) 0.0
# Chosen:  (5, 1)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.0002426301103966735 | Acceptable accuracy drop: 0.002
# Quantizing layer conv2d_7
# (4, 1) (5, 2) 0.0008492053863883573
# Chosen:  (4, 1)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.0012131505519835022 | Acceptable accuracy drop: 0.002333333333333333
# Quantizing layer conv2d_8
# (5, 1) (6, 1) 0.0002426301103966735
# Chosen:  (5, 1)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.00012131505519833675 | Acceptable accuracy drop: 0.0026666666666666666
# Quantizing layer conv2d_9
# (4, -1) (5, 0) 0.002911561324760486
# Chosen:  (5, 0)
# After quantizing layer conv2d_9 | Measured accuracy drop -0.00012131505519833675 | Acceptable accuracy drop: 0.003
# Quantizing layer conv2d_10
# (4, 0) (5, 1) 0.0010918354967851655
# Chosen:  (4, 0)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.0024263011039670043 | Acceptable accuracy drop: 0.003333333333333333
# Quantizing layer conv2d_11
# (5, 2) (6, 2) 0.0014557806623801757
# Chosen:  (5, 2)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.0031541914351571596 | Acceptable accuracy drop: 0.0036666666666666666
# Quantizing layer conv2d_12
# (5, 2) (5, 2) 0.0
# Chosen:  (5, 2)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.0032755064903554963 | Acceptable accuracy drop: 0.004
# Quantizing layer conv2d_13
# (5, 1) (6, 2) 0.0006065752759918182
# Chosen:  (5, 1)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.004003396821545651 | Acceptable accuracy drop: 0.004333333333333333
# Quantizing layer conv2d_14
# (4, 1) (4, 1) 0.0
# Chosen:  (4, 1)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.002911561324760486 | Acceptable accuracy drop: 0.004666666666666666
# Quantizing layer dense_1
# (5, 1) (6, 2) 0.0003639451655951453
# Chosen:  (5, 1)
# After quantizing layer dense_1 | Measured accuracy drop 0.004246026931942325 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_act[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_fxp_model(opt_params_act[alloc_type]))
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(a_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 82.430 %
# Quantized model accuracy: 82.080 %
# Accuracy drop of 0.425 %

# %% [markdown]
# #### Quadratic

# %%
alloc_type = 'quadratic'

acc_drop_config = {
    layer_names[i - 1]: quadratic(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
a_scores[alloc_type], opt_params_act[alloc_type], acc_drop_a[alloc_type] = opts.run('activations', start_bw = 16)
# Out:
# {'conv2d_1': [16, 15], 'conv2d_2': [16, 12], 'conv2d_3': [16, 11], 'conv2d_4': [16, 11], 'conv2d_5': [16, 10], 'conv2d_6': [16, 11], 'conv2d_7': [16, 11], 'conv2d_8': [16, 11], 'conv2d_9': [16, 10], 'conv2d_10': [16, 11], 'conv2d_11': [16, 11], 'conv2d_12': [16, 10], 'conv2d_13': [16, 10], 'conv2d_14': [16, 10], 'dense_1': [16, 10]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (14, 14) (14, 14) 0.0
# Chosen:  (14, 14)
# After quantizing layer conv2d_1 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 2.2222222222222223e-05
# Quantizing layer conv2d_2
# (14, 10) (14, 10) 0.0
# Chosen:  (14, 10)
# After quantizing layer conv2d_2 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 8.888888888888889e-05
# Quantizing layer conv2d_3
# (10, 6) (10, 6) 0.0
# Chosen:  (10, 6)
# After quantizing layer conv2d_3 | Measured accuracy drop -0.0002426301103966735 | Acceptable accuracy drop: 0.0002
# Quantizing layer conv2d_4
# (10, 6) (11, 6) 0.0002426301103966735
# Chosen:  (10, 6)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.0002426301103966735 | Acceptable accuracy drop: 0.00035555555555555557
# Quantizing layer conv2d_5
# (13, 9) (12, 8) 0.0
# Chosen:  (12, 8)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.00012131505519833675 | Acceptable accuracy drop: 0.0005555555555555556
# Quantizing layer conv2d_6
# (8, 4) (8, 4) 0.0
# Chosen:  (8, 4)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.0002426301103966735 | Acceptable accuracy drop: 0.0008
# Quantizing layer conv2d_7
# (5, 2) (6, 2) 0.0006065752759918184
# Chosen:  (5, 2)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.000849205386388492 | Acceptable accuracy drop: 0.001088888888888889
# Quantizing layer conv2d_8
# (7, 2) (7, 3) 0.00012131505519833666
# Chosen:  (7, 3)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.0012131505519835022 | Acceptable accuracy drop: 0.0014222222222222223
# Quantizing layer conv2d_9
# (6, 2) (7, 2) 0.000970520441586694
# Chosen:  (6, 2)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.0014557806623801757 | Acceptable accuracy drop: 0.0018000000000000002
# Quantizing layer conv2d_10
# (7, 3) (8, 4) 0.0006065752759918182
# Chosen:  (7, 3)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.002062355938371994 | Acceptable accuracy drop: 0.0022222222222222222
# Quantizing layer conv2d_11
# (4, 1) (4, 1) 0.0
# Chosen:  (4, 1)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.0004852602207934817 | Acceptable accuracy drop: 0.002688888888888889
# Quantizing layer conv2d_12
# (4, 0) (5, 1) 0.0014557806623801757
# Chosen:  (4, 0)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.0031541914351571596 | Acceptable accuracy drop: 0.0032
# Quantizing layer conv2d_13
# (3, -1) (4, -1) 0.0012131505519835022
# Chosen:  (3, -1)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.0031541914351571596 | Acceptable accuracy drop: 0.003755555555555556
# Quantizing layer conv2d_14
# (4, 0) (5, 1) 0.0007278903311901549
# Chosen:  (4, 0)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.004003396821545651 | Acceptable accuracy drop: 0.004355555555555556
# Quantizing layer dense_1
# (6, 2) (7, 3) 0.00024263011039667376
# Chosen:  (6, 2)
# After quantizing layer dense_1 | Measured accuracy drop 0.0037607667111488434 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_act[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_fxp_model(opt_params_act[alloc_type]))
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(a_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 82.430 %
# Quantized model accuracy: 82.120 %
# Accuracy drop of 0.376 %

# %% [markdown]
# ### Cubic

# %%
alloc_type = 'cubic'
acc_drop_config = {
    layer_names[i - 1]: cubic(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
a_scores[alloc_type], opt_params_act[alloc_type], acc_drop_a[alloc_type] = opts.run('activations', start_bw = 16)
# Out:
# {'conv2d_1': [16, 15], 'conv2d_2': [16, 12], 'conv2d_3': [16, 11], 'conv2d_4': [16, 11], 'conv2d_5': [16, 10], 'conv2d_6': [16, 11], 'conv2d_7': [16, 11], 'conv2d_8': [16, 11], 'conv2d_9': [16, 10], 'conv2d_10': [16, 11], 'conv2d_11': [16, 11], 'conv2d_12': [16, 10], 'conv2d_13': [16, 10], 'conv2d_14': [16, 10], 'dense_1': [16, 10]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (14, 14) (14, 14) 0.0
# Chosen:  (14, 14)
# After quantizing layer conv2d_1 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 1.4814814814814815e-06
# Quantizing layer conv2d_2
# (14, 10) (14, 10) 0.0
# Chosen:  (14, 10)
# After quantizing layer conv2d_2 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 1.1851851851851852e-05
# Quantizing layer conv2d_3
# (10, 6) (10, 6) 0.0
# Chosen:  (10, 6)
# After quantizing layer conv2d_3 | Measured accuracy drop -0.0002426301103966735 | Acceptable accuracy drop: 3.9999999999999996e-05
# Quantizing layer conv2d_4
# (11, 6) (12, 7) 0.00012131505519833675
# Chosen:  (11, 6)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 9.481481481481481e-05
# Quantizing layer conv2d_5
# (13, 9) (12, 8) 0.0
# Chosen:  (12, 8)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.00012131505519833675 | Acceptable accuracy drop: 0.00018518518518518518
# Quantizing layer conv2d_6
# (10, 6) (11, 6) 0.00012131505519833675
# Chosen:  (10, 6)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.0002426301103966735 | Acceptable accuracy drop: 0.00031999999999999997
# Quantizing layer conv2d_7
# (8, 4) (8, 4) 0.0
# Chosen:  (8, 4)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.0002426301103966735 | Acceptable accuracy drop: 0.0005081481481481481
# Quantizing layer conv2d_8
# (7, 3) (7, 3) 0.0
# Chosen:  (7, 3)
# After quantizing layer conv2d_8 | Measured accuracy drop -0.00036394516559501026 | Acceptable accuracy drop: 0.0007585185185185185
# Quantizing layer conv2d_9
# (7, 2) (8, 3) 0.000849205386388492
# Chosen:  (7, 2)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.000849205386388492 | Acceptable accuracy drop: 0.00108
# Quantizing layer conv2d_10
# (6, 2) (6, 2) 0.0
# Chosen:  (6, 2)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.0012131505519835022 | Acceptable accuracy drop: 0.0014814814814814814
# Quantizing layer conv2d_11
# (5, 2) (5, 2) 0.0
# Chosen:  (5, 2)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.001577095717578647 | Acceptable accuracy drop: 0.001971851851851852
# Quantizing layer conv2d_12
# (6, 2) (6, 2) 0.0
# Chosen:  (6, 2)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.0018197258279753206 | Acceptable accuracy drop: 0.0025599999999999998
# Quantizing layer conv2d_13
# (5, 0) (5, 1) 0.0013344656071818388
# Chosen:  (5, 1)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.001577095717578647 | Acceptable accuracy drop: 0.0032548148148148145
# Quantizing layer conv2d_14
# (3, 0) (4, 0) 0.0007278903311900204
# Chosen:  (3, 0)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.002547616159165341 | Acceptable accuracy drop: 0.004065185185185185
# Quantizing layer dense_1
# (4, 0) (4, 0) 0.0
# Chosen:  (4, 0)
# After quantizing layer dense_1 | Measured accuracy drop 0.0019410408831736575 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_act[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_fxp_model(opt_params_act[alloc_type]))
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(a_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 82.430 %
# Quantized model accuracy: 82.270 %
# Accuracy drop of 0.194 %

# %% [markdown]
# ### Exponential

# %%
alloc_type = 'exponential'

acc_drop_config = {
    layer_names[i - 1]: exponential(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
a_scores[alloc_type], opt_params_act[alloc_type], acc_drop_a[alloc_type] = opts.run('activations', start_bw = 16)
# Out:
# {'conv2d_1': [16, 15], 'conv2d_2': [16, 12], 'conv2d_3': [16, 11], 'conv2d_4': [16, 11], 'conv2d_5': [16, 10], 'conv2d_6': [16, 11], 'conv2d_7': [16, 11], 'conv2d_8': [16, 11], 'conv2d_9': [16, 10], 'conv2d_10': [16, 11], 'conv2d_11': [16, 11], 'conv2d_12': [16, 10], 'conv2d_13': [16, 10], 'conv2d_14': [16, 10], 'dense_1': [16, 10]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (14, 14) (14, 14) 0.0
# Chosen:  (14, 14)
# After quantizing layer conv2d_1 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 3.0517578125e-07
# Quantizing layer conv2d_2
# (14, 10) (14, 10) 0.0
# Chosen:  (14, 10)
# After quantizing layer conv2d_2 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 6.103515625e-07
# Quantizing layer conv2d_3
# (10, 6) (10, 6) 0.0
# Chosen:  (10, 6)
# After quantizing layer conv2d_3 | Measured accuracy drop -0.0002426301103966735 | Acceptable accuracy drop: 1.220703125e-06
# Quantizing layer conv2d_4
# (11, 6) (12, 7) 0.00012131505519833675
# Chosen:  (11, 6)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 2.44140625e-06
# Quantizing layer conv2d_5
# No suitable points found. Try a larger starting bitwidth or increasethe max_acc_drop threshold for layer conv2d_5
# max_acc_drop: 4.8828125e-06 | collected values: [0.00012132 0.00012132]| bitwidths: [15 16], fractional_offsets: [ 9 10]

# %%
if not isinstance(opt_params_act[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_fxp_model(opt_params_act[alloc_type]))
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(a_scores[alloc_type], 5, 3, (20, 30))

# %% [markdown]
# ### Log

# %%
alloc_type = 'log'

acc_drop_config = {
    layer_names[i - 1]: log(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
a_scores[alloc_type], opt_params_act[alloc_type], acc_drop_a[alloc_type] = opts.run('activations', start_bw = start_bw)
# Out:
# {'conv2d_1': [12, 11], 'conv2d_2': [12, 8], 'conv2d_3': [12, 7], 'conv2d_4': [12, 7], 'conv2d_5': [12, 6], 'conv2d_6': [12, 7], 'conv2d_7': [12, 7], 'conv2d_8': [12, 7], 'conv2d_9': [12, 6], 'conv2d_10': [12, 7], 'conv2d_11': [12, 7], 'conv2d_12': [12, 6], 'conv2d_13': [12, 6], 'conv2d_14': [12, 6], 'dense_1': [12, 6]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (11, 10) (11, 10) 0.0
# Chosen:  (11, 10)
# After quantizing layer conv2d_1 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 0.0
# Quantizing layer conv2d_2
# (6, 3) (6, 3) 0.0
# Chosen:  (6, 3)
# After quantizing layer conv2d_2 | Measured accuracy drop 0.00012131505519833675 | Acceptable accuracy drop: 0.0012797901240490775
# Quantizing layer conv2d_3
# (7, 3) (8, 4) 0.000485260220793347
# Chosen:  (7, 3)
# After quantizing layer conv2d_3 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 0.002028419355411065
# Quantizing layer conv2d_4
# (4, 0) (5, 0) 0.0004852602207933471
# Chosen:  (4, 0)
# After quantizing layer conv2d_4 | Measured accuracy drop -0.0024263011039670043 | Acceptable accuracy drop: 0.002559580248098155
# Quantizing layer conv2d_5
# (5, 0) (6, 1) 0.0015770957175786473
# Chosen:  (6, 1)
# After quantizing layer conv2d_5 | Measured accuracy drop -0.0010918354967851655 | Acceptable accuracy drop: 0.0029715806445889353
# Quantizing layer conv2d_6
# (4, 0) (5, 1) 0.0032755064903554963
# Chosen:  (5, 1)
# After quantizing layer conv2d_6 | Measured accuracy drop -0.0016984107727768493 | Acceptable accuracy drop: 0.003308209479460142
# Quantizing layer conv2d_7
# (4, 0) (5, 1) 0.00388208176634718
# Chosen:  (5, 1)
# After quantizing layer conv2d_7 | Measured accuracy drop -0.0013344656071818388 | Acceptable accuracy drop: 0.0035928251039498895
# Quantizing layer conv2d_8
# (4, 0) (5, 1) 0.001819725827975186
# Chosen:  (5, 1)
# After quantizing layer conv2d_8 | Measured accuracy drop -0.0015770957175785124 | Acceptable accuracy drop: 0.0038393703721472322
# Quantizing layer conv2d_9
# (4, -1) (5, 0) 0.0010918354967851653
# Chosen:  (4, -1)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.002790246269562149 | Acceptable accuracy drop: 0.00405683871082213
# Quantizing layer conv2d_10
# (4, 1) (5, 1) 0.0009705204415868286
# Chosen:  (4, 1)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.0031541914351571596 | Acceptable accuracy drop: 0.0042513707686380135
# Quantizing layer conv2d_11
# (5, 1) (5, 1) 0.0
# Chosen:  (5, 1)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.0026689312143636777 | Acceptable accuracy drop: 0.004427346420355128
# Quantizing layer conv2d_12
# (4, 0) (4, 0) 0.0
# Chosen:  (4, 0)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.0037607667111488434 | Acceptable accuracy drop: 0.00458799960350922
# Quantizing layer conv2d_13
# (4, 0) (5, 0) 0.0006065752759916838
# Chosen:  (4, 0)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.0035181366007521696 | Acceptable accuracy drop: 0.004735786205915922
# Quantizing layer conv2d_14
# (5, 2) (6, 3) 0.001334465607181839
# Chosen:  (5, 2)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.004488657042338999 | Acceptable accuracy drop: 0.004872615227998966
# Quantizing layer dense_1
# (6, 2) (6, 2) 0.0
# Chosen:  (6, 2)
# After quantizing layer dense_1 | Measured accuracy drop 0.004003396821545651 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_act[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_fxp_model(opt_params_act[alloc_type]))
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(a_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 82.430 %
# Quantized model accuracy: 82.100 %
# Accuracy drop of 0.400 %

# %%
with open(output_path + 'fixed/a_scores.p', 'wb') as f:
    pickle.dump(a_scores, f, protocol=pickle.HIGHEST_PROTOCOL)

with open(output_path + 'fixed/opt_params_a.p', 'wb') as f:
    pickle.dump(opt_params_act, f, protocol=pickle.HIGHEST_PROTOCOL)

with open(output_path + 'fixed/acc_drop_a.p', 'wb') as f:
    pickle.dump(acc_drop_a, f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
## Accuracy drop
x = np.arange(1, len(layer_names) + 1, 1)

plt.figure(figsize=(10, 7))
for k in acc_drop_w:
    if isinstance(acc_drop_a[k], int):
        continue
    plt.plot(x, acc_drop_a[k].values(), 'o-', label=k)
plt.title('Accuracy drop');
plt.xlabel('Layers');
plt.ylabel('Accuracy drop');
plt.xticks(x, layer_names, rotation='vertical')
plt.grid()
plt.legend();

# %%
x = np.arange(1, 16, 1)
num_layers = len(x)
n = 0.005 # loss of 0.5%
y1 = np.ones(x.shape) * n # constant
y2 = n/num_layers * x
y3 = n/num_layers**2 * x**2 # Quadratic
y4 = n/num_layers**3 * x**3 # Cubic
y5 = n/2**num_layers * 2**x # Exponential
y6 = n/np.log(num_layers) * np.log(x) # log

fig, axes = plt.subplots(3, 2, figsize=(20, 27))
ax = axes.flatten()
ax[0].plot(x, y1, 'o-', label='ideal');
ax[0].plot(x, acc_drop_a['constant'].values(), 'o-', label='measured');

ax[1].plot(x, y2, 'o-', label='ideal');
ax[1].plot(x, acc_drop_a['linear'].values(), 'o-', label='measured');

ax[2].plot(x, y3, 'o-', label='ideal');
ax[2].plot(x, acc_drop_a['quadratic'].values(), 'o-', label='measured');

ax[3].plot(x, y4, 'o-', label='ideal');
ax[3].plot(x, acc_drop_a['cubic'].values(), 'o-', label='measured');

ax[4].plot(x, y5, 'o-', label='ideal');
ax[4].plot(x, acc_drop_a['exponential'].values(), 'o-', label='measured');

ax[5].plot(x, y6, 'o-', label='ideal');
ax[5].plot(x, acc_drop_a['log'].values(), 'o-', label='measured');

for i in range(6):
    ax[i].set_xticks(x)
    ax[i].set_xticklabels(layer_names, rotation=90)
    # plt.title('Accuracy drop');
    ax[i].set_xlabel('Layers');
    ax[i].set_ylabel('Accuracy drop');
    ax[i].grid();
    ax[i].legend();

# %%
## Bitwidths
x = np.arange(1, len(layer_names) + 1, 1)

plt.figure(figsize=(10, 7))
for k in opt_params_act:
    if isinstance(opt_params_act[k], int):
        continue
    bw = [opt_params_act[k][layer][0] for layer in opt_params_act[k]]
    plt.plot(x, bw, 'o-', label=k)
plt.xticks(x, layer_names, rotation='vertical')
plt.title('Bitwidths')
plt.xlabel('Layers');
plt.ylabel('Bitwidth');
plt.grid()
plt.legend();

# %%
plt.figure(figsize=(20, 7))
width = 0.35
x = np.arange(1, 3*len(layer_names) + 1, 3)
for j, k in enumerate(opt_params_act.keys()):
    if isinstance(opt_params_act[k], int):
        continue
    bw = [opt_params_act[k][layer][0] for layer in opt_params_act[k]]
    plt.bar([i + j*width for i in x], bw, width, label=k)
plt.xticks(x, layer_names, rotation='horizontal')
plt.title('Bitwidths')
plt.xlabel('Layers');
plt.ylabel('Bitwidth');
plt.grid()
plt.legend();

# %%
# for layer in model_obj.model.layers:
#     if layer.weights and layer.name.startswith('conv2d') or layer.name.startswith('dense'):
#         print(layer.input_shape[1:], layer.output_shape[1:])
