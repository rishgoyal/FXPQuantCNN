# %%
import sys
sys.path.append('C:/Users/320060820/experiments/')
import fxp_quantize
import model_data
from algorithms import fixed_bitwidth
from model_gen import keras_cnn
from algorithms.optimized_search import OptimizedSearch

import keras
import tensorflow as tf
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import pandas as pd
import pickle

# to restart layer numbering
from keras import backend as K
K.clear_session()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Dependent Optimized Search quantization

# %%
input_shape = (28, 28, 1)
num_outputs = 10
num_kernels = 32
num_stages = 7
path_trained_weights = 'C:/Users/320060820/experiments/test_models/fashion_keras/fashion_seq_large_w.h5'
output_path = 'C:/Users/320060820/experiments/outputs/Dependent_Optimized_Search/F Sequential L Fashion/'
name = 'fashion_seq_large'

from test_models.fashion_keras import data
_, test_data = data.get_data()

model_arch = keras_cnn.KerasCNNLarge(input_shape, num_outputs, num_kernels, num_stages, pool_layer_interval = 2, 
                                     path_trained_weights = path_trained_weights)
model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
float_model_acc = model_obj.evaluate_accuracy()[1]
print(float_model_acc)
# Out:
# WARNING:tensorflow:From C:\Users\320060820\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\320060820\Anaconda3\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 0.9247

# %%
layer_names = [layer.name for layer in model_obj.model.layers if layer.name.startswith('conv2d') or \
               layer.name.startswith('dense')]
print(layer_names)
# Out:
# ['conv2d_1', 'conv2d_2', 'conv2d_3', 'conv2d_4', 'conv2d_5', 'conv2d_6', 'conv2d_7', 'conv2d_8', 'conv2d_9', 'conv2d_10', 'conv2d_11', 'conv2d_12', 'conv2d_13', 'conv2d_14', 'dense_1']

# %% [markdown]
# ### Function design for allocating accuracy drops per layer

# %%
total_acc_drop = 0.005
# Functions
# x: layer index
# n: total accuracy drop
# s: scale/number of layers
linear = lambda x, n, s: n/s * x
quadratic = lambda x, n, s: n/s**2 * x**2
cubic = lambda x, n, s: n/s**3 * x**3
exponential = lambda x, n, s: n/2**s * 2**x
log = lambda x, n, s: n/np.log(s) * np.log(x)
alloc_types = ['constant', 'linear', 'quadratic', 'cubic', 'exponential', 'log']

# %%
x = np.arange(1, len(layer_names) + 1, 1)
num_layers = len(x)
n = 0.005 # loss of 0.5%
y1 = np.ones(x.shape) * n # constant
y2 = linear(x, n, num_layers)
y3 = quadratic(x, n, num_layers) # Quadratic
y4 = cubic(x, n, num_layers) # Cubic
y5 = exponential(x, n, num_layers) # Exponential
y6 = log(x, n, num_layers) # log

plt.figure(figsize=(10, 7))
plt.plot(x, y1, 'o-', label='constant');
plt.plot(x, y2, 'o-', label='linear');
plt.plot(x, y3, 'o-', label='quadratic');
plt.plot(x, y4, 'o-', label='cubic');
plt.plot(x, y5, 'o-', label='exponential');
plt.plot(x, y6, 'o-', label='log');
plt.grid();
plt.legend();

# %%
start_bw = 11
w_scores = {}
opt_params_weights = {}
acc_drop_w = {}

# %% [markdown]
# #### Constant

# %%
alloc_type = 'constant'
acc_drop_config = {
    layer: total_acc_drop for layer in layer_names
}
opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
w_scores[alloc_type], opt_params_weights[alloc_type], acc_drop_w[alloc_type] = opts.run('weights', start_bw = start_bw)
# Out:
# {'conv2d_1': [11, 11], 'conv2d_2': [11, 12], 'conv2d_3': [11, 12], 'conv2d_4': [11, 12], 'conv2d_5': [11, 12], 'conv2d_6': [11, 12], 'conv2d_7': [11, 12], 'conv2d_8': [11, 13], 'conv2d_9': [11, 12], 'conv2d_10': [11, 12], 'conv2d_11': [11, 13], 'conv2d_12': [11, 12], 'conv2d_13': [11, 12], 'conv2d_14': [11, 12], 'dense_1': [11, 11]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (6, 7) (6, 7) 0.0
# Chosen:  (6, 7)
# After quantizing layer conv2d_1 | Measured accuracy drop 0.00010814318157238995 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_2
# (4, 5) (5, 6) 0.0017302909051584792
# Chosen:  (5, 6)
# After quantizing layer conv2d_2 | Measured accuracy drop 0.0014058613604411895 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_3
# (3, 4) (3, 4) 0.0
# Chosen:  (3, 4)
# After quantizing layer conv2d_3 | Measured accuracy drop 0.003568724991889229 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_4
# (4, 6) (5, 6) 0.0007570022710068499
# Chosen:  (4, 6)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.0036768681734616186 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_5
# (4, 5) (5, 6) 0.0002162863631447803
# Chosen:  (4, 5)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.004866443170758028 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_6
# (5, 7) (6, 8) 0.00043257272628967943
# Chosen:  (5, 7)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.004542013626040858 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_7
# (6, 8) (6, 8) 0.0
# Chosen:  (6, 8)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.004217584081323688 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_8
# (3, 5) (4, 5) 0.00010814318157238972
# Chosen:  (3, 5)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.004974586352330418 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_9
# No suitable points found. Try a larger starting bitwidth or increasethe max_acc_drop threshold for layer conv2d_9
# max_acc_drop: 0.005 | collected values: [0.00508273 0.00508273]| bitwidths: [10 11], fractional_offsets: [11 12]

# %%
if not isinstance(opt_params_weights[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')
    model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
    model_obj = fxp_quantize.fix_weights_quantization(model_obj, opt_params_weights[alloc_type])
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(w_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 92.470 %

# %% [markdown]
# #### Log

# %%
alloc_type = 'log'

acc_drop_config = {
    layer_names[i - 1]: log(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
w_scores[alloc_type], opt_params_weights[alloc_type], acc_drop_w[alloc_type] = opts.run('weights', start_bw = start_bw)
# Out:
# {'conv2d_1': [11, 11], 'conv2d_2': [11, 12], 'conv2d_3': [11, 12], 'conv2d_4': [11, 12], 'conv2d_5': [11, 12], 'conv2d_6': [11, 12], 'conv2d_7': [11, 12], 'conv2d_8': [11, 13], 'conv2d_9': [11, 12], 'conv2d_10': [11, 12], 'conv2d_11': [11, 13], 'conv2d_12': [11, 12], 'conv2d_13': [11, 12], 'conv2d_14': [11, 12], 'dense_1': [11, 11]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (9, 10) (9, 10) 0.0
# Chosen:  (9, 10)
# After quantizing layer conv2d_1 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 0.0
# Quantizing layer conv2d_2
# (4, 6) (4, 6) 0.0
# Chosen:  (4, 6)
# After quantizing layer conv2d_2 | Measured accuracy drop -0.0005407159078620698 | Acceptable accuracy drop: 0.0012797901240490775
# Quantizing layer conv2d_3
# (3, 4) (4, 5) 0.00010814318157238993
# Chosen:  (3, 4)
# After quantizing layer conv2d_3 | Measured accuracy drop 0.0014058613604411895 | Acceptable accuracy drop: 0.002028419355411065
# Quantizing layer conv2d_4
# (4, 5) (4, 5) 0.0
# Chosen:  (4, 5)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.0023791499945928192 | Acceptable accuracy drop: 0.002559580248098155
# Quantizing layer conv2d_5
# (6, 7) (7, 8) 0.0003244295447171696
# Chosen:  (6, 7)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.002703579539309989 | Acceptable accuracy drop: 0.0029715806445889353
# Quantizing layer conv2d_6
# (5, 7) (5, 7) 0.0
# Chosen:  (5, 7)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.0011895749972964096 | Acceptable accuracy drop: 0.003308209479460142
# Quantizing layer conv2d_7
# (3, 4) (3, 4) 0.0
# Chosen:  (3, 4)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.003244295447172059 | Acceptable accuracy drop: 0.0035928251039498895
# Quantizing layer conv2d_8
# (4, 6) (4, 6) 0.0
# Chosen:  (4, 6)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.003244295447172059 | Acceptable accuracy drop: 0.0038393703721472322
# Quantizing layer conv2d_9
# (4, 6) (4, 6) 0.0
# Chosen:  (4, 6)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.002703579539309989 | Acceptable accuracy drop: 0.00405683871082213
# Quantizing layer conv2d_10
# (3, 5) (4, 6) 0.0011895749972964096
# Chosen:  (3, 5)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.0037850113550340087 | Acceptable accuracy drop: 0.0042513707686380135
# Quantizing layer conv2d_11
# (4, 6) (5, 7) 0.00032442954471717
# Chosen:  (4, 6)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.004109440899751179 | Acceptable accuracy drop: 0.004427346420355128
# Quantizing layer conv2d_12
# (4, 6) (4, 6) 0.0
# Chosen:  (4, 6)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.0034605818103168387 | Acceptable accuracy drop: 0.00458799960350922
# Quantizing layer conv2d_13
# (3, 5) (4, 6) 0.0014058613604411895
# Chosen:  (3, 5)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.004542013626040858 | Acceptable accuracy drop: 0.004735786205915922
# Quantizing layer conv2d_14
# (4, 6) (5, 6) 0.0003244295447172906
# Chosen:  (4, 6)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.004325727262896079 | Acceptable accuracy drop: 0.004872615227998966
# Quantizing layer dense_1
# (3, 4) (4, 4) 0.0002162863631447803
# Chosen:  (3, 4)
# After quantizing layer dense_1 | Measured accuracy drop 0.0044338704444684685 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_weights[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
    model_obj = fxp_quantize.fix_weights_quantization(model_obj, opt_params_weights[alloc_type])
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(w_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 92.470 %
# Quantized model accuracy: 92.060 %
# Accuracy drop of 0.443 %

# %% [markdown]
# #### Linear

# %%
alloc_type = 'linear'

acc_drop_config = {
    layer_names[i - 1]: linear(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
w_scores[alloc_type], opt_params_weights[alloc_type], acc_drop_w[alloc_type] = opts.run('weights', start_bw = start_bw)
# Out:
# {'conv2d_1': [11, 11], 'conv2d_2': [11, 12], 'conv2d_3': [11, 12], 'conv2d_4': [11, 12], 'conv2d_5': [11, 12], 'conv2d_6': [11, 12], 'conv2d_7': [11, 12], 'conv2d_8': [11, 13], 'conv2d_9': [11, 12], 'conv2d_10': [11, 12], 'conv2d_11': [11, 13], 'conv2d_12': [11, 12], 'conv2d_13': [11, 12], 'conv2d_14': [11, 12], 'dense_1': [11, 11]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (9, 10) (9, 10) 0.0
# Chosen:  (9, 10)
# After quantizing layer conv2d_1 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 0.0003333333333333333
# Quantizing layer conv2d_2
# (4, 6) (4, 6) 0.0
# Chosen:  (4, 6)
# After quantizing layer conv2d_2 | Measured accuracy drop -0.0005407159078620698 | Acceptable accuracy drop: 0.0006666666666666666
# Quantizing layer conv2d_3
# (5, 6) (6, 7) 0.0018384340867307492
# Chosen:  (6, 7)
# After quantizing layer conv2d_3 | Measured accuracy drop -0.0010814318157240197 | Acceptable accuracy drop: 0.001
# Quantizing layer conv2d_4
# (4, 5) (4, 6) 0.0007570022710068498
# Chosen:  (4, 6)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.0005407159078619498 | Acceptable accuracy drop: 0.0013333333333333333
# Quantizing layer conv2d_5
# (4, 5) (4, 5) 0.0
# Chosen:  (4, 5)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.00032442954471716986 | Acceptable accuracy drop: 0.0016666666666666666
# Quantizing layer conv2d_6
# (4, 6) (4, 6) 0.0
# Chosen:  (4, 6)
# After quantizing layer conv2d_6 | Measured accuracy drop -0.0010814318157240197 | Acceptable accuracy drop: 0.002
# Quantizing layer conv2d_7
# (2, 4) (3, 4) 0.0020547204498756492
# Chosen:  (3, 4)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 0.002333333333333333
# Quantizing layer conv2d_8
# (2, 4) (3, 4) 0.0014058613604411895
# Chosen:  (2, 4)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.002595436357737599 | Acceptable accuracy drop: 0.0026666666666666666
# Quantizing layer conv2d_9
# (4, 6) (5, 6) 0.00010814318157238993
# Chosen:  (4, 6)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.0018384340867307492 | Acceptable accuracy drop: 0.003
# Quantizing layer conv2d_10
# (4, 6) (5, 6) 0.00010814318157238993
# Chosen:  (4, 6)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.0008651454525791196 | Acceptable accuracy drop: 0.003333333333333333
# Quantizing layer conv2d_11
# (3, 5) (4, 6) 0.001946577268303259
# Chosen:  (4, 6)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.0005407159078619498 | Acceptable accuracy drop: 0.0036666666666666666
# Quantizing layer conv2d_12
# (3, 5) (4, 6) 0.00129771817886892
# Chosen:  (3, 5)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.0021628636314480394 | Acceptable accuracy drop: 0.004
# Quantizing layer conv2d_13
# (2, 4) (3, 5) 0.00043257272628955973
# Chosen:  (2, 4)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.002595436357737599 | Acceptable accuracy drop: 0.004333333333333333
# Quantizing layer conv2d_14
# (2, 4) (2, 4) 0.0
# Chosen:  (2, 4)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.002487293176165209 | Acceptable accuracy drop: 0.004666666666666666
# Quantizing layer dense_1
# (3, 4) (4, 5) 0.002271006813020429
# Chosen:  (4, 5)
# After quantizing layer dense_1 | Measured accuracy drop 0.002595436357737599 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_weights[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
    model_obj = fxp_quantize.fix_weights_quantization(model_obj, opt_params_weights[alloc_type])
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(w_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 92.470 %
# Quantized model accuracy: 92.230 %
# Accuracy drop of 0.260 %

# %% [markdown]
# #### Quadratic

# %%
alloc_type = 'quadratic'

acc_drop_config = {
    layer_names[i - 1]: quadratic(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
w_scores[alloc_type], opt_params_weights[alloc_type], acc_drop_w[alloc_type] = opts.run('weights', start_bw = start_bw)
# Out:
# {'conv2d_1': [11, 11], 'conv2d_2': [11, 12], 'conv2d_3': [11, 12], 'conv2d_4': [11, 12], 'conv2d_5': [11, 12], 'conv2d_6': [11, 12], 'conv2d_7': [11, 12], 'conv2d_8': [11, 13], 'conv2d_9': [11, 12], 'conv2d_10': [11, 12], 'conv2d_11': [11, 13], 'conv2d_12': [11, 12], 'conv2d_13': [11, 12], 'conv2d_14': [11, 12], 'dense_1': [11, 11]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (9, 10) (9, 10) 0.0
# Chosen:  (9, 10)
# After quantizing layer conv2d_1 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 2.2222222222222223e-05
# Quantizing layer conv2d_2
# (10, 11) (11, 12) 0.00010814318157238995
# Chosen:  (10, 11)
# After quantizing layer conv2d_2 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 8.888888888888889e-05
# Quantizing layer conv2d_3
# (7, 8) (7, 8) 0.0
# Chosen:  (7, 8)
# After quantizing layer conv2d_3 | Measured accuracy drop -0.00021628636314489997 | Acceptable accuracy drop: 0.0002
# Quantizing layer conv2d_4
# (5, 7) (5, 7) 0.0
# Chosen:  (5, 7)
# After quantizing layer conv2d_4 | Measured accuracy drop -0.00032442954471728993 | Acceptable accuracy drop: 0.00035555555555555557
# Quantizing layer conv2d_5
# (5, 6) (6, 7) 0.0008651454525792397
# Chosen:  (5, 6)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.0005407159078619498 | Acceptable accuracy drop: 0.0005555555555555556
# Quantizing layer conv2d_6
# (4, 6) (5, 6) 0.00010814318157238995
# Chosen:  (4, 6)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.00010814318157238995 | Acceptable accuracy drop: 0.0008
# Quantizing layer conv2d_7
# (3, 4) (3, 4) 0.0
# Chosen:  (3, 4)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.0006488590894343397 | Acceptable accuracy drop: 0.001088888888888889
# Quantizing layer conv2d_8
# (4, 6) (4, 6) 0.0
# Chosen:  (4, 6)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.0006488590894343397 | Acceptable accuracy drop: 0.0014222222222222223
# Quantizing layer conv2d_9
# (5, 7) (6, 8) 0.0007570022710068499
# Chosen:  (5, 7)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.0011895749972964096 | Acceptable accuracy drop: 0.0018000000000000002
# Quantizing layer conv2d_10
# (4, 5) (4, 6) 0.0014058613604413096
# Chosen:  (4, 6)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.0007570022710067296 | Acceptable accuracy drop: 0.0022222222222222222
# Quantizing layer conv2d_11
# (3, 5) (4, 6) 0.0017302909051584796
# Chosen:  (4, 6)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.0006488590894343397 | Acceptable accuracy drop: 0.002688888888888889
# Quantizing layer conv2d_12
# (3, 5) (4, 5) 0.00021628636314477987
# Chosen:  (3, 5)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.0012977181788687996 | Acceptable accuracy drop: 0.0032
# Quantizing layer conv2d_13
# (2, 4) (3, 5) 0.00021628636314477987
# Chosen:  (2, 4)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.0017302909051583593 | Acceptable accuracy drop: 0.003755555555555556
# Quantizing layer conv2d_14
# (2, 4) (2, 4) 0.0
# Chosen:  (2, 4)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 0.004355555555555556
# Quantizing layer dense_1
# (2, 2) (2, 2) 0.0
# Chosen:  (2, 2)
# After quantizing layer dense_1 | Measured accuracy drop 0.0012977181788687996 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_weights[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
    model_obj = fxp_quantize.fix_weights_quantization(model_obj, opt_params_weights[alloc_type])
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(w_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 92.470 %
# Quantized model accuracy: 92.350 %
# Accuracy drop of 0.130 %

# %% [markdown]
# #### Cubic

# %%
alloc_type = 'cubic'

acc_drop_config = {
    layer_names[i - 1]: cubic(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
w_scores[alloc_type], opt_params_weights[alloc_type], acc_drop_w[alloc_type] = opts.run('weights', start_bw = 12)
# Out:
# {'conv2d_1': [12, 12], 'conv2d_2': [12, 13], 'conv2d_3': [12, 13], 'conv2d_4': [12, 13], 'conv2d_5': [12, 13], 'conv2d_6': [12, 13], 'conv2d_7': [12, 13], 'conv2d_8': [12, 14], 'conv2d_9': [12, 13], 'conv2d_10': [12, 13], 'conv2d_11': [12, 14], 'conv2d_12': [12, 13], 'conv2d_13': [12, 13], 'conv2d_14': [12, 13], 'dense_1': [12, 12]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (9, 10) (9, 10) 0.0
# Chosen:  (9, 10)
# After quantizing layer conv2d_1 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 1.4814814814814815e-06
# Quantizing layer conv2d_2
# (11, 12) (11, 12) 0.0
# Chosen:  (11, 12)
# After quantizing layer conv2d_2 | Measured accuracy drop -0.00010814318157238995 | Acceptable accuracy drop: 1.1851851851851852e-05
# Quantizing layer conv2d_3
# (7, 8) (7, 8) 0.0
# Chosen:  (7, 8)
# After quantizing layer conv2d_3 | Measured accuracy drop -0.00010814318157238995 | Acceptable accuracy drop: 3.9999999999999996e-05
# Quantizing layer conv2d_4
# (9, 10) (9, 10) 0.0
# Chosen:  (9, 10)
# After quantizing layer conv2d_4 | Measured accuracy drop -0.00021628636314489997 | Acceptable accuracy drop: 9.481481481481481e-05
# Quantizing layer conv2d_5
# (6, 7) (7, 8) 0.00021628636314489997
# Chosen:  (6, 7)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 0.00018518518518518518
# Quantizing layer conv2d_6
# (8, 10) (7, 9) 0.0
# Chosen:  (7, 9)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 0.00031999999999999997
# Quantizing layer conv2d_7
# (5, 7) (6, 8) 0.00032442954471728993
# Chosen:  (5, 7)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 0.0005081481481481481
# Quantizing layer conv2d_8
# (5, 7) (5, 7) 0.0
# Chosen:  (5, 7)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.0002162863631447799 | Acceptable accuracy drop: 0.0007585185185185185
# Quantizing layer conv2d_9
# (3, 5) (3, 5) 0.0
# Chosen:  (3, 5)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.0008651454525791196 | Acceptable accuracy drop: 0.00108
# Quantizing layer conv2d_10
# (3, 5) (4, 6) 0.00043257272628955984
# Chosen:  (3, 5)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.0014058613604411895 | Acceptable accuracy drop: 0.0014814814814814814
# Quantizing layer conv2d_11
# (4, 6) (4, 6) 0.0
# Chosen:  (4, 6)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.0007570022710067296 | Acceptable accuracy drop: 0.001971851851851852
# Quantizing layer conv2d_12
# (4, 6) (4, 6) 0.0
# Chosen:  (4, 6)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.0006488590894343397 | Acceptable accuracy drop: 0.0025599999999999998
# Quantizing layer conv2d_13
# (2, 4) (2, 4) 0.0
# Chosen:  (2, 4)
# After quantizing layer conv2d_13 | Measured accuracy drop -0.00010814318157238995 | Acceptable accuracy drop: 0.0032548148148148145
# Quantizing layer conv2d_14
# (2, 4) (2, 4) 0.0
# Chosen:  (2, 4)
# After quantizing layer conv2d_14 | Measured accuracy drop -0.00010814318157238995 | Acceptable accuracy drop: 0.004065185185185185
# Quantizing layer dense_1
# (2, 2) (3, 2) 0.00043257272628955995
# Chosen:  (2, 2)
# After quantizing layer dense_1 | Measured accuracy drop -0.0006488590894344597 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_weights[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
    model_obj = fxp_quantize.fix_weights_quantization(model_obj, opt_params_weights[alloc_type])
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(w_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 92.470 %
# Quantized model accuracy: 92.530 %
# Accuracy drop of -0.065 %

# %% [markdown]
# #### Exponential

# %%
alloc_type = 'exponential'

acc_drop_config = {
    layer_names[i - 1]: exponential(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
w_scores[alloc_type], opt_params_weights[alloc_type], acc_drop_w[alloc_type] = opts.run('weights', start_bw = 12)
# Out:
# {'conv2d_1': [12, 12], 'conv2d_2': [12, 13], 'conv2d_3': [12, 13], 'conv2d_4': [12, 13], 'conv2d_5': [12, 13], 'conv2d_6': [12, 13], 'conv2d_7': [12, 13], 'conv2d_8': [12, 14], 'conv2d_9': [12, 13], 'conv2d_10': [12, 13], 'conv2d_11': [12, 14], 'conv2d_12': [12, 13], 'conv2d_13': [12, 13], 'conv2d_14': [12, 13], 'dense_1': [12, 12]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (9, 10) (9, 10) 0.0
# Chosen:  (9, 10)
# After quantizing layer conv2d_1 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 3.0517578125e-07
# Quantizing layer conv2d_2
# (11, 12) (11, 12) 0.0
# Chosen:  (11, 12)
# After quantizing layer conv2d_2 | Measured accuracy drop -0.00010814318157238995 | Acceptable accuracy drop: 6.103515625e-07
# Quantizing layer conv2d_3
# (7, 8) (7, 8) 0.0
# Chosen:  (7, 8)
# After quantizing layer conv2d_3 | Measured accuracy drop -0.00010814318157238995 | Acceptable accuracy drop: 1.220703125e-06
# Quantizing layer conv2d_4
# (9, 10) (9, 10) 0.0
# Chosen:  (9, 10)
# After quantizing layer conv2d_4 | Measured accuracy drop -0.00021628636314489997 | Acceptable accuracy drop: 2.44140625e-06
# Quantizing layer conv2d_5
# (7, 8) (7, 8) 0.0
# Chosen:  (7, 8)
# After quantizing layer conv2d_5 | Measured accuracy drop -0.00021628636314489997 | Acceptable accuracy drop: 4.8828125e-06
# Quantizing layer conv2d_6
# (5, 7) (5, 6) 0.0006488590894344598
# Chosen:  (5, 6)
# After quantizing layer conv2d_6 | Measured accuracy drop -0.0007570022710068498 | Acceptable accuracy drop: 9.765625e-06
# Quantizing layer conv2d_7
# (4, 6) (5, 6) 0.00010814318157238995
# Chosen:  (4, 6)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 1.953125e-05
# Quantizing layer conv2d_8
# (8, 11) (9, 12) 0.00010814318157238993
# Chosen:  (8, 11)
# After quantizing layer conv2d_8 | Measured accuracy drop -0.0018384340867308693 | Acceptable accuracy drop: 3.90625e-05
# Quantizing layer conv2d_9
# (3, 5) (4, 6) 0.0011895749972964096
# Chosen:  (3, 5)
# After quantizing layer conv2d_9 | Measured accuracy drop -0.00021628636314489997 | Acceptable accuracy drop: 7.8125e-05
# Quantizing layer conv2d_10
# (4, 6) (4, 6) 0.0
# Chosen:  (4, 6)
# After quantizing layer conv2d_10 | Measured accuracy drop -0.0012977181788687996 | Acceptable accuracy drop: 0.00015625
# Quantizing layer conv2d_11
# (3, 5) (4, 5) 0.00021628636314477987
# Chosen:  (3, 5)
# After quantizing layer conv2d_11 | Measured accuracy drop -0.0015140045420136995 | Acceptable accuracy drop: 0.0003125
# Quantizing layer conv2d_12
# (3, 5) (4, 6) 0.0016221477235859694
# Chosen:  (4, 6)
# After quantizing layer conv2d_12 | Measured accuracy drop -0.0018384340867308693 | Acceptable accuracy drop: 0.000625
# Quantizing layer conv2d_13
# (2, 4) (2, 4) 0.0
# Chosen:  (2, 4)
# After quantizing layer conv2d_13 | Measured accuracy drop -0.0020547204498756492 | Acceptable accuracy drop: 0.00125
# Quantizing layer conv2d_14
# (2, 4) (3, 4) 0.0009732886341516298
# Chosen:  (2, 4)
# After quantizing layer conv2d_14 | Measured accuracy drop -0.0006488590894344597 | Acceptable accuracy drop: 0.0025
# Quantizing layer dense_1
# (2, 2) (2, 3) 0.0018384340867308693
# Chosen:  (2, 3)
# After quantizing layer dense_1 | Measured accuracy drop -0.0007570022710068498 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_weights[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
    model_obj = fxp_quantize.fix_weights_quantization(model_obj, opt_params_weights[alloc_type])
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(w_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 92.470 %
# Quantized model accuracy: 92.540 %
# Accuracy drop of -0.076 %

# %%
with open(output_path + 'fixed/w_scores.p', 'wb') as f:
    pickle.dump(w_scores, f, protocol=pickle.HIGHEST_PROTOCOL)

with open(output_path + 'fixed/opt_params_w.p', 'wb') as f:
    pickle.dump(opt_params_weights, f, protocol=pickle.HIGHEST_PROTOCOL)

with open(output_path + 'fixed/acc_drop_w.p', 'wb') as f:
    pickle.dump(acc_drop_w, f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open(output_path + 'w_scores.p', 'wb') as f:
    pickle.dump(w_scores, f, protocol=pickle.HIGHEST_PROTOCOL)

with open(output_path + 'opt_params_w.p', 'wb') as f:
    pickle.dump(opt_params_weights, f, protocol=pickle.HIGHEST_PROTOCOL)

with open(output_path + 'acc_drop_w.p', 'wb') as f:
    pickle.dump(acc_drop_w, f, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Observing results for the types of allocations

# %%
## Bitwidths
x = np.arange(1, len(layer_names) + 1, 1)

plt.figure(figsize=(10, 7))
for k in opt_params_weights:
    if isinstance(opt_params_weights[k], int):
        continue
    bw = [opt_params_weights[k][layer][0] for layer in opt_params_weights[k]]
    plt.plot(x, bw, 'o-', label=k)
plt.xticks(x, layer_names, rotation='vertical')
plt.title('Bitwidths')
plt.xlabel('Layers');
plt.ylabel('Bitwidth');
plt.grid()
plt.legend();

# %%
plt.figure(figsize=(20, 7))
width = 0.35
x = np.arange(1, 3*len(layer_names) + 1, 3)
for j, k in enumerate(opt_params_weights.keys()):
    if isinstance(opt_params_weights[k], int):
        continue
    bw = [opt_params_weights[k][layer][0] for layer in opt_params_weights[k]]
    plt.bar([i + j*width for i in x], bw, width, label=k)
plt.xticks(x, layer_names, rotation='vertical')
plt.title('Bitwidths')
plt.xlabel('Layers');
plt.ylabel('Bitwidth');
plt.grid()
plt.legend();

# %%
## Accuracy drop
x = np.arange(1, len(layer_names) + 1, 1)

plt.figure(figsize=(10, 7))
for k in acc_drop_w:
    if isinstance(acc_drop_w[k], int):
        continue
    plt.plot(x, acc_drop_w[k].values(), 'o-', label=k)
plt.title('Accuracy drop');
plt.xlabel('Layers');
plt.ylabel('Accuracy drop');
plt.xticks(x, layer_names, rotation='vertical');
plt.grid()
plt.legend();

# %%
x = np.arange(1, 16, 1)
num_layers = len(x)
n = 0.005 # loss of 0.5%
y1 = np.ones(x.shape) * n # constant
y2 = n/num_layers * x
y3 = n/num_layers**2 * x**2 # Quadratic
y4 = n/num_layers**3 * x**3 # Cubic
y5 = n/2**num_layers * 2**x # Exponential
y6 = n/np.log(num_layers) * np.log(x) # log

fig, axes = plt.subplots(3, 2, figsize=(20, 27))
ax = axes.flatten()
# ax[0].plot(x, y1, 'o-', label='ideal');
# ax[0].plot(x, acc_drop_w['constant'].values(), 'o-', label='measured');

ax[1].plot(x, y2, 'o-', label='ideal');
ax[1].plot(x, acc_drop_w['linear'].values(), 'o-', label='measured');

ax[2].plot(x, y3, 'o-', label='ideal');
ax[2].plot(x, acc_drop_w['quadratic'].values(), 'o-', label='measured');

ax[3].plot(x, y4, 'o-', label='ideal');
ax[3].plot(x, acc_drop_w['cubic'].values(), 'o-', label='measured');

ax[4].plot(x, y5, 'o-', label='ideal');
ax[4].plot(x, acc_drop_w['exponential'].values(), 'o-', label='measured');

ax[5].plot(x, y6, 'o-', label='ideal');
ax[5].plot(x, acc_drop_w['log'].values(), 'o-', label='measured');

for i in range(6):
    ax[i].set_xticks(x)
    ax[i].set_xticklabels(layer_names, rotation=90)
    # plt.title('Accuracy drop');
    ax[i].set_xlabel('Layers');
    ax[i].set_ylabel('Accuracy drop');
    ax[i].grid();
    ax[i].legend();
# Out:
# No handles with labels found to put in legend.

# %%
model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())

# %%
num_params = []
for layer in model_obj.model.layers:
    if layer.weights and layer.name.startswith('conv2d') or layer.name.startswith('dense'):
        w = layer.get_weights()[0]
        num_weights = len(w.flatten())
        print(layer.name, num_weights)
        num_params.append(num_weights)
# Out:
# conv2d_1 288
# conv2d_2 9216
# conv2d_3 9216
# conv2d_4 9216
# conv2d_5 9216
# conv2d_6 9216
# conv2d_7 18432
# conv2d_8 36864
# conv2d_9 36864
# conv2d_10 36864
# conv2d_11 36864
# conv2d_12 36864
# conv2d_13 36864
# conv2d_14 36864
# dense_1 640

# %%
total_memory = {}
for k in opt_params_weights:
    if isinstance(opt_params_weights[k], int):
        continue
    bw = [opt_params_weights[k][layer][0] for layer in opt_params_weights[k]]
    total_memory[k] = sum([bw[i] * num_params[i] for i in range(len(layer_names))])

memory_consumption = [total_memory[k] for k in total_memory]
memory_consumption_MB = [i/(8*1024**2) for i in memory_consumption]

# %%
plt.figure(figsize=(10, 7))
plt.bar(np.arange(1, len(memory_consumption_MB) + 1, 1), memory_consumption_MB);
plt.xticks(np.arange(1, len(memory_consumption_MB) + 1, 1), total_memory.keys(), rotation='horizontal');
plt.ylabel('Memory consumption (MB)');

# %% [markdown]
# # Activations

# %%
start_bw = 12
a_scores = {}
opt_params_act = {}
acc_drop_a = {}

# %%
alloc_type = 'constant'

acc_drop_config = {
    layer: 0.005 for layer in layer_names
}
opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
a_scores[alloc_type], opt_params_act[alloc_type], acc_drop_a[alloc_type] = opts.run('activations', start_bw = start_bw)
# Out:
# {'conv2d_1': [12, 11], 'conv2d_2': [12, 8], 'conv2d_3': [12, 7], 'conv2d_4': [12, 8], 'conv2d_5': [12, 7], 'conv2d_6': [12, 7], 'conv2d_7': [12, 8], 'conv2d_8': [12, 7], 'conv2d_9': [12, 7], 'conv2d_10': [12, 7], 'conv2d_11': [12, 7], 'conv2d_12': [12, 6], 'conv2d_13': [12, 6], 'conv2d_14': [12, 6], 'dense_1': [12, 6]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (6, 6) (7, 7) 0.0016221477235859694
# Chosen:  (7, 7)
# After quantizing layer conv2d_1 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_2
# (4, 2) (5, 3) 0.0030280090840272785
# Chosen:  (5, 3)
# After quantizing layer conv2d_2 | Measured accuracy drop 0.0016221477235859694 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_3
# (4, 1) (5, 2) 0.002487293176165209
# Chosen:  (5, 2)
# After quantizing layer conv2d_3 | Measured accuracy drop 0.0020547204498756492 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_4
# (3, 0) (4, 1) 0.001946577268303139
# Chosen:  (4, 1)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.0020547204498756492 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_5
# (4, 0) (4, 0) 0.0
# Chosen:  (4, 0)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.0021628636314480394 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_6
# (3, 0) (3, 0) 0.0
# Chosen:  (3, 0)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.0033524386287444486 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_7
# (4, 1) (4, 1) 0.0
# Chosen:  (4, 1)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.0031361522655996687 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_8
# (3, 0) (4, 1) 0.0015140045420135792
# Chosen:  (4, 1)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.0031361522655996687 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_9
# (3, -1) (4, 0) 0.0004325727262896803
# Chosen:  (3, -1)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.0044338704444684685 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_10
# (5, 1) (6, 2) 0.00010814318157239058
# Chosen:  (5, 1)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.0047582999891856385 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_11
# (4, 1) (4, 1) 0.0
# Chosen:  (4, 1)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.004866443170758028 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_12
# (6, 3) (7, 3) 0.00032442954471717
# Chosen:  (6, 3)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.004866443170758028 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_13
# (4, 1) (4, 1) 0.0
# Chosen:  (4, 1)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.004109440899751179 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_14
# (4, 2) (5, 2) 0.0007570022710068503
# Chosen:  (4, 2)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.0047582999891856385 | Acceptable accuracy drop: 0.005
# Quantizing layer dense_1
# (9, 5) (9, 5) 0.0
# Chosen:  (9, 5)
# After quantizing layer dense_1 | Measured accuracy drop 0.004650156807613248 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_act[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_fxp_model(opt_params_act[alloc_type]))
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(a_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 92.470 %
# Quantized model accuracy: 92.040 %
# Accuracy drop of 0.465 %

# %% [markdown]
# ### Log

# %%
alloc_type = 'log'

acc_drop_config = {
    layer_names[i - 1]: log(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
a_scores[alloc_type], opt_params_act[alloc_type], acc_drop_a[alloc_type] = opts.run('activations', start_bw = start_bw)
# Out:
# {'conv2d_1': [12, 11], 'conv2d_2': [12, 8], 'conv2d_3': [12, 7], 'conv2d_4': [12, 8], 'conv2d_5': [12, 7], 'conv2d_6': [12, 7], 'conv2d_7': [12, 8], 'conv2d_8': [12, 7], 'conv2d_9': [12, 7], 'conv2d_10': [12, 7], 'conv2d_11': [12, 7], 'conv2d_12': [12, 6], 'conv2d_13': [12, 6], 'conv2d_14': [12, 6], 'dense_1': [12, 6]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (10, 10) (11, 11) 0.00021628636314477998
# Chosen:  (10, 10)
# After quantizing layer conv2d_1 | Measured accuracy drop -0.0008651454525792397 | Acceptable accuracy drop: 0.0
# Quantizing layer conv2d_2
# (6, 3) (6, 3) 0.0
# Chosen:  (6, 3)
# After quantizing layer conv2d_2 | Measured accuracy drop 0.00032442954471716986 | Acceptable accuracy drop: 0.0012797901240490775
# Quantizing layer conv2d_3
# (6, 2) (7, 3) 0.0003244295447171699
# Chosen:  (6, 2)
# After quantizing layer conv2d_3 | Measured accuracy drop 0.0005407159078619498 | Acceptable accuracy drop: 0.002028419355411065
# Quantizing layer conv2d_4
# (3, 0) (3, 0) 0.0
# Chosen:  (3, 0)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.0010814318157240197 | Acceptable accuracy drop: 0.002559580248098155
# Quantizing layer conv2d_5
# (5, 1) (5, 1) 0.0
# Chosen:  (5, 1)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.0010814318157240197 | Acceptable accuracy drop: 0.0029715806445889353
# Quantizing layer conv2d_6
# (4, 1) (5, 2) 0.0003244295447171696
# Chosen:  (4, 1)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.002487293176165209 | Acceptable accuracy drop: 0.003308209479460142
# Quantizing layer conv2d_7
# (4, 1) (4, 1) 0.0
# Chosen:  (4, 1)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.002595436357737599 | Acceptable accuracy drop: 0.0035928251039498895
# Quantizing layer conv2d_8
# (3, 0) (3, 0) 0.0
# Chosen:  (3, 0)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.0023791499945928192 | Acceptable accuracy drop: 0.0038393703721472322
# Quantizing layer conv2d_9
# (4, 0) (4, 0) 0.0
# Chosen:  (4, 0)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.0029198659024547687 | Acceptable accuracy drop: 0.00405683871082213
# Quantizing layer conv2d_10
# (4, 0) (4, 0) 0.0
# Chosen:  (4, 0)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.0023791499945928192 | Acceptable accuracy drop: 0.0042513707686380135
# Quantizing layer conv2d_11
# (3, 0) (3, 0) 0.0
# Chosen:  (3, 0)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.0016221477235859694 | Acceptable accuracy drop: 0.004427346420355128
# Quantizing layer conv2d_12
# (3, 0) (4, 1) 0.0006488590894343396
# Chosen:  (3, 0)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.003028009084027159 | Acceptable accuracy drop: 0.00458799960350922
# Quantizing layer conv2d_13
# (3, 0) (4, 0) 0.00054071590786207
# Chosen:  (3, 0)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.004542013626040858 | Acceptable accuracy drop: 0.004735786205915922
# Quantizing layer conv2d_14
# (4, 2) (5, 2) 0.00010814318157238972
# Chosen:  (4, 2)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.004650156807613248 | Acceptable accuracy drop: 0.004872615227998966
# Quantizing layer dense_1
# (7, 3) (8, 4) 0.00032442954471716915
# Chosen:  (7, 3)
# After quantizing layer dense_1 | Measured accuracy drop 0.004650156807613248 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_act[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_fxp_model(opt_params_act[alloc_type]))
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(a_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 92.470 %
# Quantized model accuracy: 92.040 %
# Accuracy drop of 0.465 %

# %% [markdown]
# #### Linear

# %%
alloc_type = 'linear'

acc_drop_config = {
    layer_names[i - 1]: linear(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
a_scores[alloc_type], opt_params_act[alloc_type], acc_drop_a[alloc_type] = opts.run('activations', start_bw = start_bw)
# Out:
# {'conv2d_1': [12, 11], 'conv2d_2': [12, 8], 'conv2d_3': [12, 7], 'conv2d_4': [12, 8], 'conv2d_5': [12, 7], 'conv2d_6': [12, 7], 'conv2d_7': [12, 8], 'conv2d_8': [12, 7], 'conv2d_9': [12, 7], 'conv2d_10': [12, 7], 'conv2d_11': [12, 7], 'conv2d_12': [12, 6], 'conv2d_13': [12, 6], 'conv2d_14': [12, 6], 'dense_1': [12, 6]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (8, 8) (8, 8) 0.0
# Chosen:  (8, 8)
# After quantizing layer conv2d_1 | Measured accuracy drop -0.0008651454525792397 | Acceptable accuracy drop: 0.0003333333333333333
# Quantizing layer conv2d_2
# (5, 3) (6, 3) 0.0012977181788687993
# Chosen:  (5, 3)
# After quantizing layer conv2d_2 | Measured accuracy drop 0.0006488590894343397 | Acceptable accuracy drop: 0.0006666666666666666
# Quantizing layer conv2d_3
# (7, 3) (7, 4) 0.0006488590894343397
# Chosen:  (7, 4)
# After quantizing layer conv2d_3 | Measured accuracy drop 0.0002162863631447799 | Acceptable accuracy drop: 0.001
# Quantizing layer conv2d_4
# (5, 2) (6, 2) 0.00032442954471716986
# Chosen:  (5, 2)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.0007570022710067296 | Acceptable accuracy drop: 0.0013333333333333333
# Quantizing layer conv2d_5
# (5, 1) (6, 2) 0.0006488590894344598
# Chosen:  (5, 1)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.0012977181788687996 | Acceptable accuracy drop: 0.0016666666666666666
# Quantizing layer conv2d_6
# (4, 1) (5, 1) 0.0005407159078619497
# Chosen:  (4, 1)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.0016221477235859694 | Acceptable accuracy drop: 0.002
# Quantizing layer conv2d_7
# (4, 1) (4, 1) 0.0
# Chosen:  (4, 1)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.0021628636314480394 | Acceptable accuracy drop: 0.002333333333333333
# Quantizing layer conv2d_8
# (4, 1) (5, 1) 0.00032442954471728993
# Chosen:  (4, 1)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.002271006813020429 | Acceptable accuracy drop: 0.0026666666666666666
# Quantizing layer conv2d_9
# (4, 0) (5, 1) 0.0010814318157240195
# Chosen:  (4, 0)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.002703579539309989 | Acceptable accuracy drop: 0.003
# Quantizing layer conv2d_10
# (5, 1) (5, 1) 0.0
# Chosen:  (5, 1)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.0029198659024547687 | Acceptable accuracy drop: 0.003333333333333333
# Quantizing layer conv2d_11
# (5, 2) (6, 3) 0.00021628636314477987
# Chosen:  (5, 2)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.0033524386287444486 | Acceptable accuracy drop: 0.0036666666666666666
# Quantizing layer conv2d_12
# (5, 2) (6, 3) 0.0006488590894343396
# Chosen:  (5, 2)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.0038931545366063984 | Acceptable accuracy drop: 0.004
# Quantizing layer conv2d_13
# (4, 0) (4, 1) 0.0003244295447171696
# Chosen:  (4, 1)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.0036768681734616186 | Acceptable accuracy drop: 0.004333333333333333
# Quantizing layer conv2d_14
# (3, 1) (4, 1) 0.00054071590786207
# Chosen:  (3, 1)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.003244295447172059 | Acceptable accuracy drop: 0.004666666666666666
# Quantizing layer dense_1
# (5, 1) (5, 1) 0.0
# Chosen:  (5, 1)
# After quantizing layer dense_1 | Measured accuracy drop 0.0036768681734616186 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_act[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_fxp_model(opt_params_act[alloc_type]))
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(a_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 92.470 %
# Quantized model accuracy: 92.130 %
# Accuracy drop of 0.368 %

# %% [markdown]
# #### Quadratic

# %%
alloc_type = 'quadratic'

acc_drop_config = {
    layer_names[i - 1]: quadratic(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
a_scores[alloc_type], opt_params_act[alloc_type], acc_drop_a[alloc_type] = opts.run('activations', start_bw = 16)
# Out:
# {'conv2d_1': [16, 15], 'conv2d_2': [16, 12], 'conv2d_3': [16, 11], 'conv2d_4': [16, 12], 'conv2d_5': [16, 11], 'conv2d_6': [16, 11], 'conv2d_7': [16, 12], 'conv2d_8': [16, 11], 'conv2d_9': [16, 11], 'conv2d_10': [16, 11], 'conv2d_11': [16, 11], 'conv2d_12': [16, 10], 'conv2d_13': [16, 10], 'conv2d_14': [16, 10], 'dense_1': [16, 10]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (13, 13) (12, 12) 0.00010814318157239004
# Chosen:  (12, 12)
# After quantizing layer conv2d_1 | Measured accuracy drop -0.0010814318157240197 | Acceptable accuracy drop: 2.2222222222222223e-05
# Quantizing layer conv2d_2
# (6, 3) (7, 4) 0.00010814318157238996
# Chosen:  (6, 3)
# After quantizing layer conv2d_2 | Measured accuracy drop -0.00021628636314489997 | Acceptable accuracy drop: 8.888888888888889e-05
# Quantizing layer conv2d_3
# (9, 5) (10, 6) 0.00010814318157238996
# Chosen:  (9, 5)
# After quantizing layer conv2d_3 | Measured accuracy drop -0.00021628636314489997 | Acceptable accuracy drop: 0.0002
# Quantizing layer conv2d_4
# (5, 2) (6, 2) 0.00032442954471716986
# Chosen:  (5, 2)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.00032442954471716986 | Acceptable accuracy drop: 0.00035555555555555557
# Quantizing layer conv2d_5
# (7, 3) (7, 3) 0.0
# Chosen:  (7, 3)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.0004325727262895598 | Acceptable accuracy drop: 0.0005555555555555556
# Quantizing layer conv2d_6
# (7, 4) (8, 4) 0.00021628636314477992
# Chosen:  (7, 4)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.0005407159078619498 | Acceptable accuracy drop: 0.0008
# Quantizing layer conv2d_7
# (5, 2) (5, 2) 0.0
# Chosen:  (5, 2)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.0006488590894343397 | Acceptable accuracy drop: 0.001088888888888889
# Quantizing layer conv2d_8
# (3, 0) (3, 0) 0.0
# Chosen:  (3, 0)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.0002162863631447799 | Acceptable accuracy drop: 0.0014222222222222223
# Quantizing layer conv2d_9
# (4, 0) (5, 0) 0.00010814318157238999
# Chosen:  (4, 0)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.0005407159078619498 | Acceptable accuracy drop: 0.0018000000000000002
# Quantizing layer conv2d_10
# (4, 1) (5, 2) 0.0006488590894343397
# Chosen:  (4, 1)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.0008651454525791196 | Acceptable accuracy drop: 0.0022222222222222222
# Quantizing layer conv2d_11
# (3, 0) (3, 0) 0.0
# Chosen:  (3, 0)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.0014058613604411895 | Acceptable accuracy drop: 0.002688888888888889
# Quantizing layer conv2d_12
# (3, 0) (4, 0) 0.00010814318157239015
# Chosen:  (3, 0)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.0023791499945928192 | Acceptable accuracy drop: 0.0032
# Quantizing layer conv2d_13
# (4, 1) (3, 0) 0.0012977181788687993
# Chosen:  (3, 0)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.0023791499945928192 | Acceptable accuracy drop: 0.003755555555555556
# Quantizing layer conv2d_14
# (3, 0) (4, 1) 0.0016221477235859694
# Chosen:  (4, 1)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.002271006813020429 | Acceptable accuracy drop: 0.004355555555555556
# Quantizing layer dense_1
# (4, 0) (5, 1) 0.00140586136044119
# Chosen:  (4, 0)
# After quantizing layer dense_1 | Measured accuracy drop 0.0047582999891856385 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_act[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_fxp_model(opt_params_act[alloc_type]))
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(a_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 92.470 %
# Quantized model accuracy: 92.030 %
# Accuracy drop of 0.476 %

# %% [markdown]
# ### Cubic

# %%
alloc_type = 'cubic'
acc_drop_config = {
    layer_names[i - 1]: cubic(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
a_scores[alloc_type], opt_params_act[alloc_type], acc_drop_a[alloc_type] = opts.run('activations', start_bw = 16)
# Out:
# {'conv2d_1': [16, 15], 'conv2d_2': [16, 12], 'conv2d_3': [16, 11], 'conv2d_4': [16, 12], 'conv2d_5': [16, 11], 'conv2d_6': [16, 11], 'conv2d_7': [16, 12], 'conv2d_8': [16, 11], 'conv2d_9': [16, 11], 'conv2d_10': [16, 11], 'conv2d_11': [16, 11], 'conv2d_12': [16, 10], 'conv2d_13': [16, 10], 'conv2d_14': [16, 10], 'dense_1': [16, 10]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (13, 13) (12, 12) 0.00010814318157239004
# Chosen:  (12, 12)
# After quantizing layer conv2d_1 | Measured accuracy drop -0.0010814318157240197 | Acceptable accuracy drop: 1.4814814814814815e-06
# Quantizing layer conv2d_2
# (6, 3) (7, 4) 0.00010814318157238996
# Chosen:  (6, 3)
# After quantizing layer conv2d_2 | Measured accuracy drop -0.00021628636314489997 | Acceptable accuracy drop: 1.1851851851851852e-05
# Quantizing layer conv2d_3
# (9, 5) (10, 6) 0.00010814318157238996
# Chosen:  (9, 5)
# After quantizing layer conv2d_3 | Measured accuracy drop -0.00021628636314489997 | Acceptable accuracy drop: 3.9999999999999996e-05
# Quantizing layer conv2d_4
# (10, 6) (11, 7) 0.00021628636314489997
# Chosen:  (10, 6)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 9.481481481481481e-05
# Quantizing layer conv2d_5
# (7, 3) (8, 3) 0.00032442954471728993
# Chosen:  (7, 3)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 0.00018518518518518518
# Quantizing layer conv2d_6
# (9, 5) (9, 5) 0.0
# Chosen:  (9, 5)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 0.00031999999999999997
# Quantizing layer conv2d_7
# (7, 4) (7, 4) 0.0
# Chosen:  (7, 4)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.00010814318157238995 | Acceptable accuracy drop: 0.0005081481481481481
# Quantizing layer conv2d_8
# (5, 2) (6, 2) 0.0003244295447171698
# Chosen:  (5, 2)
# After quantizing layer conv2d_8 | Measured accuracy drop -0.00021628636314489997 | Acceptable accuracy drop: 0.0007585185185185185
# Quantizing layer conv2d_9
# (4, 1) (5, 1) 0.0010814318157240197
# Chosen:  (4, 1)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.0009732886341516296 | Acceptable accuracy drop: 0.00108
# Quantizing layer conv2d_10
# (4, 0) (4, 0) 0.0
# Chosen:  (4, 0)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.0010814318157240197 | Acceptable accuracy drop: 0.0014814814814814814
# Quantizing layer conv2d_11
# (5, 2) (6, 2) 0.0006488590894344598
# Chosen:  (5, 2)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.0014058613604411895 | Acceptable accuracy drop: 0.001971851851851852
# Quantizing layer conv2d_12
# (5, 2) (6, 3) 0.00021628636314477987
# Chosen:  (5, 2)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.0017302909051583593 | Acceptable accuracy drop: 0.0025599999999999998
# Quantizing layer conv2d_13
# (3, 0) (4, 1) 0.0005407159078620698
# Chosen:  (3, 0)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.002487293176165209 | Acceptable accuracy drop: 0.0032548148148148145
# Quantizing layer conv2d_14
# (3, 1) (4, 1) 0.0006488590894343396
# Chosen:  (3, 1)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.002811722720882379 | Acceptable accuracy drop: 0.004065185185185185
# Quantizing layer dense_1
# (5, 1) (5, 2) 0.00064885908943446
# Chosen:  (5, 2)
# After quantizing layer dense_1 | Measured accuracy drop 0.0019465772683031392 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_act[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_fxp_model(opt_params_act[alloc_type]))
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(a_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 92.470 %
# Quantized model accuracy: 92.290 %
# Accuracy drop of 0.195 %

# %% [markdown]
# ### Exponential

# %%
alloc_type = 'exponential'

acc_drop_config = {
    layer_names[i - 1]: exponential(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
a_scores[alloc_type], opt_params_act[alloc_type], acc_drop_a[alloc_type] = opts.run('activations', start_bw = 16)
# Out:
# {'conv2d_1': [16, 15], 'conv2d_2': [16, 12], 'conv2d_3': [16, 11], 'conv2d_4': [16, 12], 'conv2d_5': [16, 11], 'conv2d_6': [16, 11], 'conv2d_7': [16, 12], 'conv2d_8': [16, 11], 'conv2d_9': [16, 11], 'conv2d_10': [16, 11], 'conv2d_11': [16, 11], 'conv2d_12': [16, 10], 'conv2d_13': [16, 10], 'conv2d_14': [16, 10], 'dense_1': [16, 10]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (13, 13) (12, 12) 0.00010814318157239004
# Chosen:  (12, 12)
# After quantizing layer conv2d_1 | Measured accuracy drop -0.0010814318157240197 | Acceptable accuracy drop: 3.0517578125e-07
# Quantizing layer conv2d_2
# (6, 3) (7, 4) 0.00010814318157238996
# Chosen:  (6, 3)
# After quantizing layer conv2d_2 | Measured accuracy drop -0.00021628636314489997 | Acceptable accuracy drop: 6.103515625e-07
# Quantizing layer conv2d_3
# (9, 5) (10, 6) 0.00010814318157238996
# Chosen:  (9, 5)
# After quantizing layer conv2d_3 | Measured accuracy drop -0.00021628636314489997 | Acceptable accuracy drop: 1.220703125e-06
# Quantizing layer conv2d_4
# (10, 6) (11, 7) 0.00021628636314489997
# Chosen:  (10, 6)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 2.44140625e-06
# Quantizing layer conv2d_5
# (7, 3) (8, 3) 0.00032442954471728993
# Chosen:  (7, 3)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 4.8828125e-06
# Quantizing layer conv2d_6
# (12, 8) (11, 7) 0.0
# Chosen:  (11, 7)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 9.765625e-06
# Quantizing layer conv2d_7
# (11, 7) (11, 7) 0.0
# Chosen:  (11, 7)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 1.953125e-05
# Quantizing layer conv2d_8
# (10, 6) (10, 6) 0.0
# Chosen:  (10, 6)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 3.90625e-05
# Quantizing layer conv2d_9
# (11, 7) (11, 7) 0.0
# Chosen:  (11, 7)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 7.8125e-05
# Quantizing layer conv2d_10
# (9, 6) (9, 6) 0.0
# Chosen:  (9, 6)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 0.00015625
# Quantizing layer conv2d_11
# (8, 5) (9, 6) 0.00010814318157251002
# Chosen:  (8, 5)
# After quantizing layer conv2d_11 | Measured accuracy drop -0.00010814318157238995 | Acceptable accuracy drop: 0.0003125
# Quantizing layer conv2d_12
# (4, 1) (4, 1) 0.0
# Chosen:  (4, 1)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.00032442954471716986 | Acceptable accuracy drop: 0.000625
# Quantizing layer conv2d_13
# (3, 0) (4, 0) 0.0012977181788687996
# Chosen:  (3, 0)
# After quantizing layer conv2d_13 | Measured accuracy drop -0.00032442954471728993 | Acceptable accuracy drop: 0.00125
# Quantizing layer conv2d_14
# (3, 0) (3, 1) 0.0019465772683032593
# Chosen:  (3, 1)
# After quantizing layer conv2d_14 | Measured accuracy drop -0.0005407159078620698 | Acceptable accuracy drop: 0.0025
# Quantizing layer dense_1
# (4, 0) (5, 1) 0.0037850113550341284
# Chosen:  (5, 1)
# After quantizing layer dense_1 | Measured accuracy drop -0.00043257272628967986 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_act[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_fxp_model(opt_params_act[alloc_type]))
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(a_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 92.470 %
# Quantized model accuracy: 92.510 %
# Accuracy drop of -0.043 %

# %%
with open(output_path + 'fixed/a_scores.p', 'wb') as f:
    pickle.dump(a_scores, f, protocol=pickle.HIGHEST_PROTOCOL)

with open(output_path + 'fixed/opt_params_a.p', 'wb') as f:
    pickle.dump(opt_params_act, f, protocol=pickle.HIGHEST_PROTOCOL)

with open(output_path + 'fixed/acc_drop_a.p', 'wb') as f:
    pickle.dump(acc_drop_a, f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
## Accuracy drop
x = np.arange(1, len(layer_names) + 1, 1)

plt.figure(figsize=(10, 7))
for k in acc_drop_w:
    plt.plot(x, acc_drop_a[k].values(), 'o-', label=k)
plt.title('Accuracy drop');
plt.xlabel('Layers');
plt.ylabel('Accuracy drop');
plt.xticks(x, layer_names, rotation='vertical')
plt.grid()
plt.legend();

# %%
x = np.arange(1, 16, 1)
num_layers = len(x)
n = 0.005 # loss of 0.5%
y1 = np.ones(x.shape) * n # constant
y2 = n/num_layers * x
y3 = n/num_layers**2 * x**2 # Quadratic
y4 = n/num_layers**3 * x**3 # Cubic
y5 = n/2**num_layers * 2**x # Exponential
y6 = n/np.log(num_layers) * np.log(x) # log

fig, axes = plt.subplots(3, 2, figsize=(20, 27))
ax = axes.flatten()
ax[0].plot(x, y1, 'o-', label='ideal');
ax[0].plot(x, acc_drop_a['constant'].values(), 'o-', label='measured');

ax[1].plot(x, y2, 'o-', label='ideal');
ax[1].plot(x, acc_drop_a['linear'].values(), 'o-', label='measured');

ax[2].plot(x, y3, 'o-', label='ideal');
ax[2].plot(x, acc_drop_a['quadratic'].values(), 'o-', label='measured');

ax[3].plot(x, y4, 'o-', label='ideal');
ax[3].plot(x, acc_drop_a['cubic'].values(), 'o-', label='measured');

ax[4].plot(x, y5, 'o-', label='ideal');
ax[4].plot(x, acc_drop_a['exponential'].values(), 'o-', label='measured');

ax[5].plot(x, y6, 'o-', label='ideal');
ax[5].plot(x, acc_drop_a['log'].values(), 'o-', label='measured');

for i in range(6):
    ax[i].set_xticks(x)
    ax[i].set_xticklabels(layer_names, rotation=90)
    # plt.title('Accuracy drop');
    ax[i].set_xlabel('Layers');
    ax[i].set_ylabel('Accuracy drop');
    ax[i].grid();
    ax[i].legend();

# %%
## Bitwidths
x = np.arange(1, len(layer_names) + 1, 1)

plt.figure(figsize=(10, 7))
for k in opt_params_act:
    bw = [opt_params_act[k][layer][0] for layer in opt_params_act[k]]
    plt.plot(x, bw, 'o-', label=k)
plt.xticks(x, layer_names, rotation='vertical')
plt.title('Bitwidths')
plt.xlabel('Layers');
plt.ylabel('Bitwidth');
plt.grid()
plt.legend();

# %%
plt.figure(figsize=(20, 7))
width = 0.35
x = np.arange(1, 3*len(layer_names) + 1, 3)
for j, k in enumerate(opt_params_act.keys()):
    bw = [opt_params_act[k][layer][0] for layer in opt_params_act[k]]
    plt.bar([i + j*width for i in x], bw, width, label=k)
plt.xticks(x, layer_names, rotation='horizontal')
plt.title('Bitwidths')
plt.xlabel('Layers');
plt.ylabel('Bitwidth');
plt.grid()
plt.legend();

# %%
# for layer in model_obj.model.layers:
#     if layer.weights and layer.name.startswith('conv2d') or layer.name.startswith('dense'):
#         print(layer.input_shape[1:], layer.output_shape[1:])
