# %%
import sys
sys.path.append('C:/Users/320060820/experiments/')
import fxp_quantize
import model_data
from algorithms import fixed_bitwidth
from model_gen import keras_cnn
from algorithms.optimized_search import OptimizedSearch

import keras
import tensorflow as tf
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import pandas as pd
import pickle

# to restart layer numbering
from keras import backend as K
K.clear_session()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Dependent Optimized Search quantization

# %%
input_shape = (28, 28, 1)
num_outputs = 10
num_kernels = 32
num_stages = 7
path_trained_weights = 'C:/Users/320060820/experiments/test_models/mnist_custom/mnist_seq_large_w.h5'
output_path = 'C:/Users/320060820/experiments/outputs/Dependent_Optimized_Search/F Sequential L MNIST/'
name = 'mnist_seq_large'

from test_models.mnist_custom import data
_, test_data = data.get_data()

model_arch = keras_cnn.KerasCNNLarge(input_shape, num_outputs, num_kernels, num_stages, pool_layer_interval = 2, 
                                     path_trained_weights = path_trained_weights)
model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
float_model_acc = model_obj.evaluate_accuracy()[1]
# Out:
# WARNING:tensorflow:From C:\Users\320060820\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\320060820\Anaconda3\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
layer_names = [layer.name for layer in model_obj.model.layers if layer.name.startswith('conv2d') or \
               layer.name.startswith('dense')]
print(layer_names)
# Out:
# ['conv2d_1', 'conv2d_2', 'conv2d_3', 'conv2d_4', 'conv2d_5', 'conv2d_6', 'conv2d_7', 'conv2d_8', 'conv2d_9', 'conv2d_10', 'conv2d_11', 'conv2d_12', 'conv2d_13', 'conv2d_14', 'dense_1']

# %% [markdown]
# ### Function design for allocating accuracy drops per layer

# %%
total_acc_drop = 0.005
# Functions
# x: layer index
# n: total accuracy drop
# s: scale/number of layers
linear = lambda x, n, s: n/s * x
quadratic = lambda x, n, s: n/s**2 * x**2
cubic = lambda x, n, s: n/s**3 * x**3
exponential = lambda x, n, s: n/2**s * 2**x
log = lambda x, n, s: n/np.log(s) * np.log(x)
alloc_types = ['constant', 'linear', 'quadratic', 'cubic', 'exponential', 'log']

# %%
x = np.arange(1, 16, 1)
num_layers = len(x)
n = 0.005 # loss of 0.5%
y1 = np.ones(x.shape) * n # constant
y2 = linear(x, n, num_layers)
y3 = quadratic(x, n, num_layers) # Quadratic
y4 = cubic(x, n, num_layers) # Cubic
y5 = exponential(x, n, num_layers) # Exponential
y6 = log(x, n, num_layers) # log

plt.figure(figsize=(10, 7))
plt.plot(x, y1, 'o-', label='constant');
plt.plot(x, y2, 'o-', label='linear');
plt.plot(x, y3, 'o-', label='quadratic');
plt.plot(x, y4, 'o-', label='cubic');
plt.plot(x, y5, 'o-', label='exponential');
plt.plot(x, y6, 'o-', label='log');
plt.grid();
plt.legend();

# %%
start_bw = 12
w_scores = {}
opt_params_weights = {}
acc_drop_w = {}

# %% [markdown]
# #### Constant

# %%
alloc_type = 'constant'
acc_drop_config = {
    layer: total_acc_drop for layer in layer_names
}
opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
w_scores[alloc_type], opt_params_weights[alloc_type], acc_drop_w[alloc_type] = opts.run('weights', start_bw = start_bw)
# Out:
# {'conv2d_1': [12, 13], 'conv2d_2': [12, 13], 'conv2d_3': [12, 13], 'conv2d_4': [12, 13], 'conv2d_5': [12, 13], 'conv2d_6': [12, 13], 'conv2d_7': [12, 14], 'conv2d_8': [12, 14], 'conv2d_9': [12, 14], 'conv2d_10': [12, 14], 'conv2d_11': [12, 14], 'conv2d_12': [12, 14], 'conv2d_13': [12, 13], 'conv2d_14': [12, 13], 'dense_1': [12, 12]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (3, 5) (4, 5) 0.0036180904522612432
# Chosen:  (4, 5)
# After quantizing layer conv2d_1 | Measured accuracy drop 0.0007035175879397326 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_2
# (3, 5) (4, 6) 0.000100502512562803
# Chosen:  (3, 5)
# After quantizing layer conv2d_2 | Measured accuracy drop 0.000402010050251212 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_3
# (2, 3) (2, 3) 0.0
# Chosen:  (2, 3)
# After quantizing layer conv2d_3 | Measured accuracy drop 0.0009045226130653386 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_4
# (2, 3) (3, 4) 0.0015075376884422678
# Chosen:  (3, 4)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.0024120603015074953 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_5
# (3, 4) (4, 5) 0.00040201005025132346
# Chosen:  (3, 4)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.0027135678391960157 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_6
# (3, 4) (4, 5) 0.0012060301507537475
# Chosen:  (3, 4)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.003216080402010031 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_7
# (3, 5) (4, 6) 0.00020100502512571767
# Chosen:  (3, 5)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.0037185929648241574 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_8
# (3, 5) (4, 6) 0.00040201005025121243
# Chosen:  (3, 5)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.004020100502512567 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_9
# (2, 4) (3, 5) 0.0007035175879396209
# Chosen:  (2, 4)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.004422110552763778 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_10
# (2, 4) (3, 5) 0.0003015075376884089
# Chosen:  (2, 4)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.004422110552763778 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_11
# (3, 5) (4, 6) 0.0003015075376885208
# Chosen:  (3, 5)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.004623115577889496 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_12
# (3, 5) (3, 5) 0.0
# Chosen:  (3, 5)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.004522613065326582 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_13
# (2, 4) (3, 5) 0.0003015075376885208
# Chosen:  (2, 4)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.004723618090452299 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_14
# (2, 4) (2, 4) 0.0
# Chosen:  (2, 4)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.004522613065326582 | Acceptable accuracy drop: 0.005
# Quantizing layer dense_1
# (2, 3) (3, 4) 0.0003015075376884089
# Chosen:  (2, 3)
# After quantizing layer dense_1 | Measured accuracy drop 0.004221105527638172 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_weights[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
    model_obj = fxp_quantize.fix_weights_quantization(model_obj, opt_params_weights[alloc_type])
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(w_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 99.500 %
# Quantized model accuracy: 99.080 %
# Accuracy drop of 0.422 %

# %% [markdown]
# #### Linear

# %%
alloc_type = 'linear'

acc_drop_config = {
    layer_names[i - 1]: linear(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
w_scores[alloc_type], opt_params_weights[alloc_type], acc_drop_w[alloc_type] = opts.run('weights', start_bw = start_bw)
# Out:
# {'conv2d_1': [12, 13], 'conv2d_2': [12, 13], 'conv2d_3': [12, 13], 'conv2d_4': [12, 13], 'conv2d_5': [12, 13], 'conv2d_6': [12, 13], 'conv2d_7': [12, 14], 'conv2d_8': [12, 14], 'conv2d_9': [12, 14], 'conv2d_10': [12, 14], 'conv2d_11': [12, 14], 'conv2d_12': [12, 14], 'conv2d_13': [12, 13], 'conv2d_14': [12, 13], 'dense_1': [12, 12]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (5, 6) (5, 6) 0.0
# Chosen:  (5, 6)
# After quantizing layer conv2d_1 | Measured accuracy drop -0.000402010050251212 | Acceptable accuracy drop: 0.0003333333333333333
# Quantizing layer conv2d_2
# (3, 5) (4, 6) 0.000301507537688409
# Chosen:  (3, 5)
# After quantizing layer conv2d_2 | Measured accuracy drop -0.000100502512562803 | Acceptable accuracy drop: 0.0006666666666666666
# Quantizing layer conv2d_3
# (2, 3) (2, 3) 0.0
# Chosen:  (2, 3)
# After quantizing layer conv2d_3 | Measured accuracy drop 0.000301507537688409 | Acceptable accuracy drop: 0.001
# Quantizing layer conv2d_4
# (3, 5) (3, 5) 0.0
# Chosen:  (3, 5)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.000201005025125606 | Acceptable accuracy drop: 0.0013333333333333333
# Quantizing layer conv2d_5
# (3, 4) (4, 5) 0.0006030150753769297
# Chosen:  (3, 4)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.0010050251256281417 | Acceptable accuracy drop: 0.0016666666666666666
# Quantizing layer conv2d_6
# (3, 4) (4, 5) 0.0007035175879396211
# Chosen:  (3, 4)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.0014070351758793537 | Acceptable accuracy drop: 0.002
# Quantizing layer conv2d_7
# (2, 4) (3, 5) 0.00010050251256280267
# Chosen:  (2, 4)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.002110552763819086 | Acceptable accuracy drop: 0.002333333333333333
# Quantizing layer conv2d_8
# (2, 4) (2, 4) 0.0
# Chosen:  (2, 4)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.002512562814070298 | Acceptable accuracy drop: 0.0026666666666666666
# Quantizing layer conv2d_9
# (2, 4) (2, 4) 0.0
# Chosen:  (2, 4)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.0026130653266332126 | Acceptable accuracy drop: 0.003
# Quantizing layer conv2d_10
# (3, 5) (4, 5) 0.00010050251256280311
# Chosen:  (3, 5)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.002914572864321622 | Acceptable accuracy drop: 0.003333333333333333
# Quantizing layer conv2d_11
# (3, 5) (3, 5) 0.0
# Chosen:  (3, 5)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.003015075376884425 | Acceptable accuracy drop: 0.0036666666666666666
# Quantizing layer conv2d_12
# (2, 4) (3, 5) 0.0008040201005025355
# Chosen:  (2, 4)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.0036180904522613543 | Acceptable accuracy drop: 0.004
# Quantizing layer conv2d_13
# (3, 5) (4, 6) 0.0005025125628140147
# Chosen:  (3, 5)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.004221105527638172 | Acceptable accuracy drop: 0.004333333333333333
# Quantizing layer conv2d_14
# (2, 4) (3, 4) 0.00010050251256280267
# Chosen:  (2, 4)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.003919597989949763 | Acceptable accuracy drop: 0.004666666666666666
# Quantizing layer dense_1
# (2, 2) (2, 2) 0.0
# Chosen:  (2, 2)
# After quantizing layer dense_1 | Measured accuracy drop 0.003417085427135637 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_weights[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
    model_obj = fxp_quantize.fix_weights_quantization(model_obj, opt_params_weights[alloc_type])
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(w_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 99.500 %
# Quantized model accuracy: 99.160 %
# Accuracy drop of 0.342 %

# %% [markdown]
# #### Quadratic

# %%
alloc_type = 'quadratic'

acc_drop_config = {
    layer_names[i - 1]: quadratic(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
w_scores[alloc_type], opt_params_weights[alloc_type], acc_drop_w[alloc_type] = opts.run('weights', start_bw = start_bw)
# Out:
# {'conv2d_1': [12, 13], 'conv2d_2': [12, 13], 'conv2d_3': [12, 13], 'conv2d_4': [12, 13], 'conv2d_5': [12, 13], 'conv2d_6': [12, 13], 'conv2d_7': [12, 14], 'conv2d_8': [12, 14], 'conv2d_9': [12, 14], 'conv2d_10': [12, 14], 'conv2d_11': [12, 14], 'conv2d_12': [12, 14], 'conv2d_13': [12, 13], 'conv2d_14': [12, 13], 'dense_1': [12, 12]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (5, 6) (5, 6) 0.0
# Chosen:  (5, 6)
# After quantizing layer conv2d_1 | Measured accuracy drop -0.000402010050251212 | Acceptable accuracy drop: 2.2222222222222223e-05
# Quantizing layer conv2d_2
# (3, 5) (4, 6) 0.000301507537688409
# Chosen:  (3, 5)
# After quantizing layer conv2d_2 | Measured accuracy drop -0.000100502512562803 | Acceptable accuracy drop: 8.888888888888889e-05
# Quantizing layer conv2d_3
# (3, 5) (3, 5) 0.0
# Chosen:  (3, 5)
# After quantizing layer conv2d_3 | Measured accuracy drop -0.000301507537688409 | Acceptable accuracy drop: 0.0002
# Quantizing layer conv2d_4
# (3, 5) (4, 5) 0.000201005025125606
# Chosen:  (3, 5)
# After quantizing layer conv2d_4 | Measured accuracy drop -0.000100502512562803 | Acceptable accuracy drop: 0.00035555555555555557
# Quantizing layer conv2d_5
# (3, 4) (3, 5) 0.000402010050251212
# Chosen:  (3, 5)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 0.0005555555555555556
# Quantizing layer conv2d_6
# (4, 5) (4, 6) 0.0005025125628141266
# Chosen:  (4, 6)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.000100502512562803 | Acceptable accuracy drop: 0.0008
# Quantizing layer conv2d_7
# (3, 5) (4, 6) 0.0009045226130653387
# Chosen:  (3, 5)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.0010050251256281417 | Acceptable accuracy drop: 0.001088888888888889
# Quantizing layer conv2d_8
# (3, 5) (3, 5) 0.0
# Chosen:  (3, 5)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.0008040201005025356 | Acceptable accuracy drop: 0.0014222222222222223
# Quantizing layer conv2d_9
# (2, 4) (3, 4) 0.0002010050251256061
# Chosen:  (2, 4)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.0010050251256281417 | Acceptable accuracy drop: 0.0018000000000000002
# Quantizing layer conv2d_10
# (2, 4) (3, 5) 0.0013065326633165506
# Chosen:  (2, 4)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.002110552763819086 | Acceptable accuracy drop: 0.0022222222222222222
# Quantizing layer conv2d_11
# (3, 5) (4, 5) 0.00010050251256291456
# Chosen:  (3, 5)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.0016080402010050711 | Acceptable accuracy drop: 0.002688888888888889
# Quantizing layer conv2d_12
# (2, 4) (3, 5) 0.000201005025125606
# Chosen:  (2, 4)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.0019095477386934802 | Acceptable accuracy drop: 0.0032
# Quantizing layer conv2d_13
# (2, 4) (3, 4) 0.00040201005025132346
# Chosen:  (2, 4)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.0026130653266332126 | Acceptable accuracy drop: 0.003755555555555556
# Quantizing layer conv2d_14
# (2, 4) (3, 5) 0.0008040201005024244
# Chosen:  (2, 4)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.003417085427135637 | Acceptable accuracy drop: 0.004355555555555556
# Quantizing layer dense_1
# (2, 2) (2, 3) 0.0007035175879397323
# Chosen:  (2, 3)
# After quantizing layer dense_1 | Measured accuracy drop 0.003015075376884425 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_weights[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
    model_obj = fxp_quantize.fix_weights_quantization(model_obj, opt_params_weights[alloc_type])
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(w_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 99.500 %
# Quantized model accuracy: 99.200 %
# Accuracy drop of 0.302 %

# %% [markdown]
# ### Cubic

# %%
alloc_type = 'cubic'

acc_drop_config = {
    layer_names[i - 1]: cubic(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
w_scores[alloc_type], opt_params_weights[alloc_type], acc_drop_w[alloc_type] = opts.run('weights', start_bw = start_bw)
# Out:
# {'conv2d_1': [12, 13], 'conv2d_2': [12, 13], 'conv2d_3': [12, 13], 'conv2d_4': [12, 13], 'conv2d_5': [12, 13], 'conv2d_6': [12, 13], 'conv2d_7': [12, 14], 'conv2d_8': [12, 14], 'conv2d_9': [12, 14], 'conv2d_10': [12, 14], 'conv2d_11': [12, 14], 'conv2d_12': [12, 14], 'conv2d_13': [12, 13], 'conv2d_14': [12, 13], 'dense_1': [12, 12]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (5, 6) (5, 6) 0.0
# Chosen:  (5, 6)
# After quantizing layer conv2d_1 | Measured accuracy drop -0.000402010050251212 | Acceptable accuracy drop: 1.4814814814814815e-06
# Quantizing layer conv2d_2
# (3, 5) (4, 6) 0.000301507537688409
# Chosen:  (3, 5)
# After quantizing layer conv2d_2 | Measured accuracy drop -0.000100502512562803 | Acceptable accuracy drop: 1.1851851851851852e-05
# Quantizing layer conv2d_3
# (3, 5) (3, 5) 0.0
# Chosen:  (3, 5)
# After quantizing layer conv2d_3 | Measured accuracy drop -0.000301507537688409 | Acceptable accuracy drop: 3.9999999999999996e-05
# Quantizing layer conv2d_4
# (3, 5) (4, 5) 0.000201005025125606
# Chosen:  (3, 5)
# After quantizing layer conv2d_4 | Measured accuracy drop -0.000100502512562803 | Acceptable accuracy drop: 9.481481481481481e-05
# Quantizing layer conv2d_5
# (5, 6) (5, 6) 0.0
# Chosen:  (5, 6)
# After quantizing layer conv2d_5 | Measured accuracy drop -0.000301507537688409 | Acceptable accuracy drop: 0.00018518518518518518
# Quantizing layer conv2d_6
# (3, 5) (4, 6) 0.000301507537688409
# Chosen:  (3, 5)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.000301507537688409 | Acceptable accuracy drop: 0.00031999999999999997
# Quantizing layer conv2d_7
# (4, 6) (4, 6) 0.0
# Chosen:  (4, 6)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.000402010050251212 | Acceptable accuracy drop: 0.0005081481481481481
# Quantizing layer conv2d_8
# (2, 4) (3, 4) 0.000402010050251212
# Chosen:  (2, 4)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.000502512562814015 | Acceptable accuracy drop: 0.0007585185185185185
# Quantizing layer conv2d_9
# (2, 4) (3, 4) 0.0004020100502512121
# Chosen:  (2, 4)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.0010050251256281417 | Acceptable accuracy drop: 0.00108
# Quantizing layer conv2d_10
# (3, 5) (3, 5) 0.0
# Chosen:  (3, 5)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.0007035175879397326 | Acceptable accuracy drop: 0.0014814814814814814
# Quantizing layer conv2d_11
# (2, 4) (3, 5) 0.0017085427135678742
# Chosen:  (3, 5)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.000201005025125606 | Acceptable accuracy drop: 0.001971851851851852
# Quantizing layer conv2d_12
# (2, 4) (3, 5) 0.00040201005025132356
# Chosen:  (2, 4)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.0007035175879397326 | Acceptable accuracy drop: 0.0025599999999999998
# Quantizing layer conv2d_13
# (2, 3) (3, 4) 0.0014070351758794651
# Chosen:  (2, 3)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.0027135678391960157 | Acceptable accuracy drop: 0.0032548148148148145
# Quantizing layer conv2d_14
# (2, 4) (3, 5) 0.0008040201005025355
# Chosen:  (2, 4)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.003919597989949763 | Acceptable accuracy drop: 0.004065185185185185
# Quantizing layer dense_1
# (2, 3) (2, 3) 0.0
# Chosen:  (2, 3)
# After quantizing layer dense_1 | Measured accuracy drop 0.002211055276381889 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_weights[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
    model_obj = fxp_quantize.fix_weights_quantization(model_obj, opt_params_weights[alloc_type])
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(w_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 99.500 %
# Quantized model accuracy: 99.280 %
# Accuracy drop of 0.221 %

# %% [markdown]
# ### Exponential

# %%
alloc_type = 'exponential'

acc_drop_config = {
    layer_names[i - 1]: exponential(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
w_scores[alloc_type], opt_params_weights[alloc_type], acc_drop_w[alloc_type] = opts.run('weights', start_bw = start_bw)
# Out:
# {'conv2d_1': [12, 13], 'conv2d_2': [12, 13], 'conv2d_3': [12, 13], 'conv2d_4': [12, 13], 'conv2d_5': [12, 13], 'conv2d_6': [12, 13], 'conv2d_7': [12, 14], 'conv2d_8': [12, 14], 'conv2d_9': [12, 14], 'conv2d_10': [12, 14], 'conv2d_11': [12, 14], 'conv2d_12': [12, 14], 'conv2d_13': [12, 13], 'conv2d_14': [12, 13], 'dense_1': [12, 12]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (5, 6) (5, 6) 0.0
# Chosen:  (5, 6)
# After quantizing layer conv2d_1 | Measured accuracy drop -0.000402010050251212 | Acceptable accuracy drop: 3.0517578125e-07
# Quantizing layer conv2d_2
# (3, 5) (4, 6) 0.000301507537688409
# Chosen:  (3, 5)
# After quantizing layer conv2d_2 | Measured accuracy drop -0.000100502512562803 | Acceptable accuracy drop: 6.103515625e-07
# Quantizing layer conv2d_3
# (3, 5) (3, 5) 0.0
# Chosen:  (3, 5)
# After quantizing layer conv2d_3 | Measured accuracy drop -0.000301507537688409 | Acceptable accuracy drop: 1.220703125e-06
# Quantizing layer conv2d_4
# (3, 5) (4, 5) 0.000201005025125606
# Chosen:  (3, 5)
# After quantizing layer conv2d_4 | Measured accuracy drop -0.000100502512562803 | Acceptable accuracy drop: 2.44140625e-06
# Quantizing layer conv2d_5
# (5, 6) (5, 6) 0.0
# Chosen:  (5, 6)
# After quantizing layer conv2d_5 | Measured accuracy drop -0.000301507537688409 | Acceptable accuracy drop: 4.8828125e-06
# Quantizing layer conv2d_6
# (4, 6) (5, 6) 0.000100502512562803
# Chosen:  (4, 6)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 9.765625e-06
# Quantizing layer conv2d_7
# (3, 5) (4, 6) 0.000100502512562803
# Chosen:  (3, 5)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 1.953125e-05
# Quantizing layer conv2d_8
# (10, 12) (10, 12) 0.0
# Chosen:  (10, 12)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 3.90625e-05
# Quantizing layer conv2d_9
# (8, 10) (8, 10) 0.0
# Chosen:  (8, 10)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 7.8125e-05
# Quantizing layer conv2d_10
# (4, 6) (4, 6) 0.0
# Chosen:  (4, 6)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 0.00015625
# Quantizing layer conv2d_11
# (3, 5) (4, 5) 0.000100502512562803
# Chosen:  (3, 5)
# After quantizing layer conv2d_11 | Measured accuracy drop -0.000201005025125606 | Acceptable accuracy drop: 0.0003125
# Quantizing layer conv2d_12
# (2, 4) (3, 5) 0.000502512562814015
# Chosen:  (2, 4)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.000502512562814015 | Acceptable accuracy drop: 0.000625
# Quantizing layer conv2d_13
# (2, 4) (3, 4) 0.00010050251256291456
# Chosen:  (2, 4)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.0006030150753769296 | Acceptable accuracy drop: 0.00125
# Quantizing layer conv2d_14
# (2, 3) (3, 4) 0.0018090452261306771
# Chosen:  (3, 4)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.000502512562814015 | Acceptable accuracy drop: 0.0025
# Quantizing layer dense_1
# (2, 2) (3, 3) 0.00040201005025132356
# Chosen:  (2, 2)
# After quantizing layer dense_1 | Measured accuracy drop 0.0007035175879397326 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_weights[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
    model_obj = fxp_quantize.fix_weights_quantization(model_obj, opt_params_weights[alloc_type])
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(w_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 99.500 %
# Quantized model accuracy: 99.430 %
# Accuracy drop of 0.070 %

# %% [markdown]
# ### Log

# %%
alloc_type = 'log'

acc_drop_config = {
    layer_names[i - 1]: log(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
w_scores[alloc_type], opt_params_weights[alloc_type], acc_drop_w[alloc_type] = opts.run('weights', start_bw = start_bw)

# %%
if not isinstance(opt_params_weights[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
    model_obj = fxp_quantize.fix_weights_quantization(model_obj, opt_params_weights[alloc_type])
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(w_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 99.500 %
# Quantized model accuracy: 99.100 %
# Accuracy drop of 0.402 %

# %%
with open(output_path + 'fixed/w_scores.p', 'wb') as f:
    pickle.dump(w_scores, f, protocol=pickle.HIGHEST_PROTOCOL)

with open(output_path + 'fixed/opt_params_w.p', 'wb') as f:
    pickle.dump(opt_params_weights, f, protocol=pickle.HIGHEST_PROTOCOL)

with open(output_path + 'fixed/acc_drop_w.p', 'wb') as f:
    pickle.dump(acc_drop_w, f, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Observing results for the types of allocations

# %%
## Bitwidths
x = np.arange(1, len(layer_names) + 1, 1)

plt.figure(figsize=(10, 7))
for k in opt_params_weights:
    bw = [opt_params_weights[k][layer][0] for layer in opt_params_weights[k]]
    plt.plot(x, bw, 'o-', label=k)
plt.xticks(x, layer_names, rotation='vertical')
plt.title('Bitwidths')
plt.xlabel('Layers');
plt.ylabel('Bitwidth');
plt.grid()
plt.legend();

# %%
plt.figure(figsize=(20, 7))
width = 0.35
x = np.arange(1, 3*len(layer_names) + 1, 3)
for j, k in enumerate(opt_params_weights.keys()):
    bw = [opt_params_weights[k][layer][0] for layer in opt_params_weights[k]]
    plt.bar([i + j*width for i in x], bw, width, label=k)
plt.xticks(x, layer_names, rotation='vertical')
plt.title('Bitwidths')
plt.xlabel('Layers');
plt.ylabel('Bitwidth');
plt.grid()
plt.legend();

# %%
## Accuracy drop
x = np.arange(1, len(layer_names) + 1, 1)

plt.figure(figsize=(10, 7))
for k in acc_drop_w:
    plt.plot(x, acc_drop_w[k].values(), 'o-', label=k)
plt.title('Accuracy drop');
plt.xlabel('Layers');
plt.ylabel('Accuracy drop');
plt.xticks(x, layer_names, rotation='vertical');
plt.grid()
plt.legend();

# %%
x = np.arange(1, 16, 1)
num_layers = len(x)
n = 0.005 # loss of 0.5%
y1 = np.ones(x.shape) * n # constant
y2 = n/num_layers * x
y3 = n/num_layers**2 * x**2 # Quadratic
y4 = n/num_layers**3 * x**3 # Cubic
y5 = n/2**num_layers * 2**x # Exponential
y6 = n/np.log(num_layers) * np.log(x) # log

fig, axes = plt.subplots(3, 2, figsize=(20, 27))
ax = axes.flatten()
ax[0].plot(x, y1, 'o-', label='ideal');
ax[0].plot(x, acc_drop_w['constant'].values(), 'o-', label='measured');

ax[1].plot(x, y2, 'o-', label='ideal');
ax[1].plot(x, acc_drop_w['linear'].values(), 'o-', label='measured');

ax[2].plot(x, y3, 'o-', label='ideal');
ax[2].plot(x, acc_drop_w['quadratic'].values(), 'o-', label='measured');

ax[3].plot(x, y4, 'o-', label='ideal');
ax[3].plot(x, acc_drop_w['cubic'].values(), 'o-', label='measured');

ax[4].plot(x, y5, 'o-', label='ideal');
ax[4].plot(x, acc_drop_w['exponential'].values(), 'o-', label='measured');

ax[5].plot(x, y6, 'o-', label='ideal');
ax[5].plot(x, acc_drop_w['log'].values(), 'o-', label='measured');

for i in range(6):
    ax[i].set_xticks(x)
    ax[i].set_xticklabels(layer_names, rotation=90)
    # plt.title('Accuracy drop');
    ax[i].set_xlabel('Layers');
    ax[i].set_ylabel('Accuracy drop');
    ax[i].grid();
    ax[i].legend();

# %%
model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())

# %%
num_params = []
for layer in model_obj.model.layers:
    if layer.weights and layer.name.startswith('conv2d') or layer.name.startswith('dense'):
        w = layer.get_weights()[0]
        num_weights = len(w.flatten())
        print(layer.name, num_weights)
        num_params.append(num_weights)
# Out:
# conv2d_1 288
# conv2d_2 9216
# conv2d_3 9216
# conv2d_4 9216
# conv2d_5 9216
# conv2d_6 9216
# conv2d_7 18432
# conv2d_8 36864
# conv2d_9 36864
# conv2d_10 36864
# conv2d_11 36864
# conv2d_12 36864
# conv2d_13 36864
# conv2d_14 36864
# dense_1 640

# %%
total_memory = {}
for k in opt_params_weights:
    bw = [opt_params_weights[k][layer][0] for layer in opt_params_weights[k]]
    total_memory[k] = sum([bw[i] * num_params[i] for i in range(len(layer_names))])

memory_consumption = [total_memory[k] for k in total_memory]
memory_consumption_MB = [i/(8*1024**2) for i in memory_consumption]

# %%
plt.figure(figsize=(10, 7))
plt.bar(np.arange(1, len(memory_consumption_MB) + 1, 1), memory_consumption_MB);
plt.xticks(np.arange(1, len(memory_consumption_MB) + 1, 1), alloc_types, rotation='horizontal');
plt.ylabel('Memory consumption (MB)');

# %% [markdown]
# # Activations

# %%
start_bw = 16
a_scores = {}
opt_params_act = {}
acc_drop_a = {}

# %%
alloc_type = 'constant'

acc_drop_config = {
    layer: 0.005 for layer in layer_names
}
opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
a_scores[alloc_type], opt_params_act[alloc_type], acc_drop_a[alloc_type] = opts.run('activations', start_bw = start_bw)
# Out:
# {'conv2d_1': [16, 15], 'conv2d_2': [16, 12], 'conv2d_3': [16, 11], 'conv2d_4': [16, 11], 'conv2d_5': [16, 11], 'conv2d_6': [16, 11], 'conv2d_7': [16, 12], 'conv2d_8': [16, 11], 'conv2d_9': [16, 11], 'conv2d_10': [16, 11], 'conv2d_11': [16, 11], 'conv2d_12': [16, 11], 'conv2d_13': [16, 11], 'conv2d_14': [16, 11], 'dense_1': [16, 10]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (4, 4) (5, 5) 0.0023115577889446922
# Chosen:  (5, 5)
# After quantizing layer conv2d_1 | Measured accuracy drop 0.0020100502512562833 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_2
# (4, 2) (5, 2) 0.0023115577889446922
# Chosen:  (5, 2)
# After quantizing layer conv2d_2 | Measured accuracy drop 0.0016080402010050711 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_3
# (4, 1) (5, 1) 0.0005025125628141266
# Chosen:  (4, 1)
# After quantizing layer conv2d_3 | Measured accuracy drop 0.0027135678391960157 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_4
# (2, -2) (3, -1) 0.003115577889447228
# Chosen:  (3, -1)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.0018090452261306771 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_5
# (3, -2) (4, -1) 0.0012060301507537475
# Chosen:  (3, -2)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.002512562814070298 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_6
# (3, -1) (4, 0) 0.001708542713567874
# Chosen:  (4, 0)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.002211055276381889 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_7
# (3, 0) (4, 1) 0.000904522613065339
# Chosen:  (3, 0)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.004020100502512567 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_8
# (3, -1) (3, -1) 0.0
# Chosen:  (3, -1)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.003919597989949763 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_9
# (3, -2) (3, -2) 0.0
# Chosen:  (3, -2)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.003417085427135637 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_10
# (3, -1) (4, 0) 0.0007035175879397323
# Chosen:  (3, -1)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.004120603015075369 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_11
# (4, 0) (5, 1) 0.00010050251256280354
# Chosen:  (4, 0)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.004522613065326582 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_12
# (3, 0) (4, 0) 0.000502512562814127
# Chosen:  (3, 0)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.004924623115577905 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_13
# (11, 6) (11, 6) 0.0
# Chosen:  (11, 6)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.004924623115577905 | Acceptable accuracy drop: 0.005
# Quantizing layer conv2d_14
# (7, 4) (7, 4) 0.0
# Chosen:  (7, 4)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.004824120603015102 | Acceptable accuracy drop: 0.005
# Quantizing layer dense_1
# (8, 4) (8, 4) 0.0
# Chosen:  (8, 4)
# After quantizing layer dense_1 | Measured accuracy drop 0.004824120603015102 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_act[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_fxp_model(opt_params_act[alloc_type]))
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(a_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 99.500 %
# Quantized model accuracy: 99.020 %
# Accuracy drop of 0.482 %

# %% [markdown]
# #### Linear

# %%
alloc_type = 'linear'

acc_drop_config = {
    layer_names[i - 1]: linear(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
a_scores[alloc_type], opt_params_act[alloc_type], acc_drop_a[alloc_type] = opts.run('activations', start_bw = start_bw)
# Out:
# {'conv2d_1': [16, 15], 'conv2d_2': [16, 12], 'conv2d_3': [16, 11], 'conv2d_4': [16, 11], 'conv2d_5': [16, 11], 'conv2d_6': [16, 11], 'conv2d_7': [16, 12], 'conv2d_8': [16, 11], 'conv2d_9': [16, 11], 'conv2d_10': [16, 11], 'conv2d_11': [16, 11], 'conv2d_12': [16, 11], 'conv2d_13': [16, 11], 'conv2d_14': [16, 11], 'dense_1': [16, 10]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (7, 7) (7, 7) 0.0
# Chosen:  (7, 7)
# After quantizing layer conv2d_1 | Measured accuracy drop -0.000100502512562803 | Acceptable accuracy drop: 0.0003333333333333333
# Quantizing layer conv2d_2
# (5, 2) (6, 3) 0.000301507537688409
# Chosen:  (5, 2)
# After quantizing layer conv2d_2 | Measured accuracy drop 0.000301507537688409 | Acceptable accuracy drop: 0.0006666666666666666
# Quantizing layer conv2d_3
# (3, 0) (4, 0) 0.0005025125628141266
# Chosen:  (3, 0)
# After quantizing layer conv2d_3 | Measured accuracy drop 0.0006030150753769296 | Acceptable accuracy drop: 0.001
# Quantizing layer conv2d_4
# (3, -1) (4, 0) 0.00030150753768852056
# Chosen:  (3, -1)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.0008040201005025356 | Acceptable accuracy drop: 0.0013333333333333333
# Quantizing layer conv2d_5
# (3, -2) (4, -1) 0.000201005025125606
# Chosen:  (3, -2)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.0013065326633165506 | Acceptable accuracy drop: 0.0016666666666666666
# Quantizing layer conv2d_6
# (4, 0) (5, 1) 0.00020100502512571767
# Chosen:  (4, 0)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.0017085427135678742 | Acceptable accuracy drop: 0.002
# Quantizing layer conv2d_7
# (4, 1) (5, 1) 0.00010050251256280289
# Chosen:  (4, 1)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.0018090452261306771 | Acceptable accuracy drop: 0.002333333333333333
# Quantizing layer conv2d_8
# (3, -1) (3, -1) 0.0
# Chosen:  (3, -1)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.0018090452261306771 | Acceptable accuracy drop: 0.0026666666666666666
# Quantizing layer conv2d_9
# (3, -1) (4, -1) 0.0003015075376884093
# Chosen:  (3, -1)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.0024120603015074953 | Acceptable accuracy drop: 0.003
# Quantizing layer conv2d_10
# (3, -1) (4, 0) 0.000402010050251212
# Chosen:  (3, -1)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.0031155778894472277 | Acceptable accuracy drop: 0.003333333333333333
# Quantizing layer conv2d_11
# (4, 1) (4, 1) 0.0
# Chosen:  (4, 1)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.0026130653266332126 | Acceptable accuracy drop: 0.0036666666666666666
# Quantizing layer conv2d_12
# (3, 0) (4, 0) 0.0008040201005025355
# Chosen:  (3, 0)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.0036180904522613543 | Acceptable accuracy drop: 0.004
# Quantizing layer conv2d_13
# (3, -2) (3, -1) 0.0006030150753769297
# Chosen:  (3, -1)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.003417085427135637 | Acceptable accuracy drop: 0.004333333333333333
# Quantizing layer conv2d_14
# (3, 0) (4, 1) 0.0006030150753768178
# Chosen:  (3, 0)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.004422110552763778 | Acceptable accuracy drop: 0.004666666666666666
# Quantizing layer dense_1
# (5, 1) (6, 2) 0.00010050251256280267
# Chosen:  (5, 1)
# After quantizing layer dense_1 | Measured accuracy drop 0.004723618090452299 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_act[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_fxp_model(opt_params_act[alloc_type]))
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(a_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 99.500 %
# Quantized model accuracy: 99.030 %
# Accuracy drop of 0.472 %

# %% [markdown]
# #### Quadratic

# %%
alloc_type = 'quadratic'

acc_drop_config = {
    layer_names[i - 1]: quadratic(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
a_scores[alloc_type], opt_params_act[alloc_type], acc_drop_a[alloc_type] = opts.run('activations', start_bw = start_bw)
# Out:
# {'conv2d_1': [16, 15], 'conv2d_2': [16, 12], 'conv2d_3': [16, 11], 'conv2d_4': [16, 11], 'conv2d_5': [16, 11], 'conv2d_6': [16, 11], 'conv2d_7': [16, 12], 'conv2d_8': [16, 11], 'conv2d_9': [16, 11], 'conv2d_10': [16, 11], 'conv2d_11': [16, 11], 'conv2d_12': [16, 11], 'conv2d_13': [16, 11], 'conv2d_14': [16, 11], 'dense_1': [16, 10]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (12, 11) (12, 11) 0.0
# Chosen:  (12, 11)
# After quantizing layer conv2d_1 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 2.2222222222222223e-05
# Quantizing layer conv2d_2
# (6, 3) (6, 3) 0.0
# Chosen:  (6, 3)
# After quantizing layer conv2d_2 | Measured accuracy drop -0.000100502512562803 | Acceptable accuracy drop: 8.888888888888889e-05
# Quantizing layer conv2d_3
# (5, 2) (6, 2) 0.000301507537688409
# Chosen:  (5, 2)
# After quantizing layer conv2d_3 | Measured accuracy drop 0.000100502512562803 | Acceptable accuracy drop: 0.0002
# Quantizing layer conv2d_4
# (4, 0) (5, 1) 0.000201005025125606
# Chosen:  (4, 0)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.000301507537688409 | Acceptable accuracy drop: 0.00035555555555555557
# Quantizing layer conv2d_5
# (4, 0) (5, 0) 0.000100502512562803
# Chosen:  (4, 0)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.000100502512562803 | Acceptable accuracy drop: 0.0005555555555555556
# Quantizing layer conv2d_6
# (4, 0) (5, 1) 0.000402010050251212
# Chosen:  (4, 0)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.000402010050251212 | Acceptable accuracy drop: 0.0008
# Quantizing layer conv2d_7
# (3, 0) (4, 0) 0.000100502512562803
# Chosen:  (3, 0)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.0007035175879397326 | Acceptable accuracy drop: 0.001088888888888889
# Quantizing layer conv2d_8
# (3, -1) (3, -1) 0.0
# Chosen:  (3, -1)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.0007035175879397326 | Acceptable accuracy drop: 0.0014222222222222223
# Quantizing layer conv2d_9
# (3, -1) (4, 0) 0.00020100502512571756
# Chosen:  (3, -1)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.0007035175879397326 | Acceptable accuracy drop: 0.0018000000000000002
# Quantizing layer conv2d_10
# (4, 0) (5, 1) 0.000402010050251212
# Chosen:  (4, 0)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.0011055276381909446 | Acceptable accuracy drop: 0.0022222222222222222
# Quantizing layer conv2d_11
# (3, -1) (4, 0) 0.0009045226130653383
# Chosen:  (3, -1)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.002110552763819086 | Acceptable accuracy drop: 0.002688888888888889
# Quantizing layer conv2d_12
# (3, -1) (3, 0) 0.0003015075376884091
# Chosen:  (3, 0)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.0017085427135678742 | Acceptable accuracy drop: 0.0032
# Quantizing layer conv2d_13
# (2, -2) (3, -1) 0.0008040201005025359
# Chosen:  (2, -2)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.003316582914572834 | Acceptable accuracy drop: 0.003755555555555556
# Quantizing layer conv2d_14
# (2, -1) (3, 0) 0.00020100502512571767
# Chosen:  (2, -1)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.0037185929648241574 | Acceptable accuracy drop: 0.004355555555555556
# Quantizing layer dense_1
# (3, -1) (4, 0) 0.0010050251256281412
# Chosen:  (3, -1)
# After quantizing layer dense_1 | Measured accuracy drop 0.004824120603015102 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_act[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_fxp_model(opt_params_act[alloc_type]))
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(a_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 99.500 %
# Quantized model accuracy: 99.020 %
# Accuracy drop of 0.482 %

# %% [markdown]
# ### Cubic

# %%
alloc_type = 'cubic'
acc_drop_config = {
    layer_names[i - 1]: cubic(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
a_scores[alloc_type], opt_params_act[alloc_type], acc_drop_a[alloc_type] = opts.run('activations', start_bw = start_bw)
# Out:
# {'conv2d_1': [16, 15], 'conv2d_2': [16, 12], 'conv2d_3': [16, 11], 'conv2d_4': [16, 11], 'conv2d_5': [16, 11], 'conv2d_6': [16, 11], 'conv2d_7': [16, 12], 'conv2d_8': [16, 11], 'conv2d_9': [16, 11], 'conv2d_10': [16, 11], 'conv2d_11': [16, 11], 'conv2d_12': [16, 11], 'conv2d_13': [16, 11], 'conv2d_14': [16, 11], 'dense_1': [16, 10]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (12, 11) (12, 11) 0.0
# Chosen:  (12, 11)
# After quantizing layer conv2d_1 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 1.4814814814814815e-06
# Quantizing layer conv2d_2
# (6, 3) (6, 3) 0.0
# Chosen:  (6, 3)
# After quantizing layer conv2d_2 | Measured accuracy drop -0.000100502512562803 | Acceptable accuracy drop: 1.1851851851851852e-05
# Quantizing layer conv2d_3
# (6, 2) (6, 2) 0.0
# Chosen:  (6, 2)
# After quantizing layer conv2d_3 | Measured accuracy drop -0.000201005025125606 | Acceptable accuracy drop: 3.9999999999999996e-05
# Quantizing layer conv2d_4
# (4, 0) (5, 1) 0.000100502512562803
# Chosen:  (4, 0)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 9.481481481481481e-05
# Quantizing layer conv2d_5
# (3, -1) (4, -1) 0.000100502512562803
# Chosen:  (3, -1)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.000100502512562803 | Acceptable accuracy drop: 0.00018518518518518518
# Quantizing layer conv2d_6
# (4, 0) (5, 0) 0.000100502512562803
# Chosen:  (4, 0)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.000301507537688409 | Acceptable accuracy drop: 0.00031999999999999997
# Quantizing layer conv2d_7
# (4, 1) (5, 1) 0.000201005025125606
# Chosen:  (4, 1)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.000201005025125606 | Acceptable accuracy drop: 0.0005081481481481481
# Quantizing layer conv2d_8
# (4, 0) (5, 1) 0.000100502512562803
# Chosen:  (4, 0)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.000301507537688409 | Acceptable accuracy drop: 0.0007585185185185185
# Quantizing layer conv2d_9
# (4, -1) (5, 0) 0.0006030150753769296
# Chosen:  (4, -1)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.0009045226130653386 | Acceptable accuracy drop: 0.00108
# Quantizing layer conv2d_10
# (4, 0) (4, 0) 0.0
# Chosen:  (4, 0)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.0011055276381909446 | Acceptable accuracy drop: 0.0014814814814814814
# Quantizing layer conv2d_11
# (3, -1) (3, 0) 0.00010050251256280311
# Chosen:  (3, 0)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.0009045226130653386 | Acceptable accuracy drop: 0.001971851851851852
# Quantizing layer conv2d_12
# (3, -1) (4, 0) 0.0010050251256281415
# Chosen:  (3, -1)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.002211055276381889 | Acceptable accuracy drop: 0.0025599999999999998
# Quantizing layer conv2d_13
# (2, -2) (3, -1) 0.00010050251256280311
# Chosen:  (2, -2)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.002211055276381889 | Acceptable accuracy drop: 0.0032548148148148145
# Quantizing layer conv2d_14
# (2, -1) (3, 0) 0.0006030150753769297
# Chosen:  (2, -1)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.002914572864321622 | Acceptable accuracy drop: 0.004065185185185185
# Quantizing layer dense_1
# (3, -1) (4, 0) 0.0020100502512562833
# Chosen:  (4, 0)
# After quantizing layer dense_1 | Measured accuracy drop 0.002914572864321622 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_act[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_fxp_model(opt_params_act[alloc_type]))
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(a_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 99.500 %
# Quantized model accuracy: 99.210 %
# Accuracy drop of 0.291 %

# %% [markdown]
# ### Exponential

# %%
alloc_type = 'exponential'

acc_drop_config = {
    layer_names[i - 1]: exponential(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
a_scores[alloc_type], opt_params_act[alloc_type], acc_drop_a[alloc_type] = opts.run('activations', start_bw = 12)
# Out:
# {'conv2d_1': [12, 11], 'conv2d_2': [12, 8], 'conv2d_3': [12, 7], 'conv2d_4': [12, 7], 'conv2d_5': [12, 7], 'conv2d_6': [12, 7], 'conv2d_7': [12, 8], 'conv2d_8': [12, 7], 'conv2d_9': [12, 7], 'conv2d_10': [12, 7], 'conv2d_11': [12, 7], 'conv2d_12': [12, 7], 'conv2d_13': [12, 7], 'conv2d_14': [12, 7], 'dense_1': [12, 6]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (12, 11) (12, 11) 0.0
# Chosen:  (12, 11)
# After quantizing layer conv2d_1 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 3.0517578125e-07
# Quantizing layer conv2d_2
# (6, 3) (6, 3) 0.0
# Chosen:  (6, 3)
# After quantizing layer conv2d_2 | Measured accuracy drop -0.000100502512562803 | Acceptable accuracy drop: 6.103515625e-07
# Quantizing layer conv2d_3
# (6, 2) (6, 2) 0.0
# Chosen:  (6, 2)
# After quantizing layer conv2d_3 | Measured accuracy drop -0.000201005025125606 | Acceptable accuracy drop: 1.220703125e-06
# Quantizing layer conv2d_4
# (4, 0) (5, 1) 0.000100502512562803
# Chosen:  (4, 0)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 2.44140625e-06
# Quantizing layer conv2d_5
# (5, 1) (5, 0) 0.000201005025125606
# Chosen:  (5, 0)
# After quantizing layer conv2d_5 | Measured accuracy drop -0.000201005025125606 | Acceptable accuracy drop: 4.8828125e-06
# Quantizing layer conv2d_6
# (6, 2) (6, 2) 0.0
# Chosen:  (6, 2)
# After quantizing layer conv2d_6 | Measured accuracy drop -0.000100502512562803 | Acceptable accuracy drop: 9.765625e-06
# Quantizing layer conv2d_7
# (4, 1) (5, 1) 0.000100502512562803
# Chosen:  (4, 1)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 1.953125e-05
# Quantizing layer conv2d_8
# (6, 2) (6, 2) 0.0
# Chosen:  (6, 2)
# After quantizing layer conv2d_8 | Measured accuracy drop -0.000100502512562803 | Acceptable accuracy drop: 3.90625e-05
# Quantizing layer conv2d_9
# (7, 2) (7, 2) 0.0
# Chosen:  (7, 2)
# After quantizing layer conv2d_9 | Measured accuracy drop -0.000100502512562803 | Acceptable accuracy drop: 7.8125e-05
# Quantizing layer conv2d_10
# (5, 2) (6, 2) 0.000301507537688409
# Chosen:  (5, 2)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.000100502512562803 | Acceptable accuracy drop: 0.00015625
# Quantizing layer conv2d_11
# (5, 2) (6, 2) 0.000100502512562803
# Chosen:  (5, 2)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.000201005025125606 | Acceptable accuracy drop: 0.0003125
# Quantizing layer conv2d_12
# (3, -1) (4, 0) 0.000100502512562803
# Chosen:  (3, -1)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.000502512562814015 | Acceptable accuracy drop: 0.000625
# Quantizing layer conv2d_13
# (3, -1) (4, 0) 0.000201005025125606
# Chosen:  (3, -1)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.0008040201005025356 | Acceptable accuracy drop: 0.00125
# Quantizing layer conv2d_14
# (2, -1) (3, 0) 0.0005025125628140151
# Chosen:  (2, -1)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.0014070351758793537 | Acceptable accuracy drop: 0.0025
# Quantizing layer dense_1
# (3, -1) (4, 0) 0.0012060301507537475
# Chosen:  (3, -1)
# After quantizing layer dense_1 | Measured accuracy drop 0.003216080402010031 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_act[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_fxp_model(opt_params_act[alloc_type]))
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(a_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 99.500 %
# Quantized model accuracy: 99.180 %
# Accuracy drop of 0.322 %

# %% [markdown]
# ### Log

# %%
alloc_type = 'log'

acc_drop_config = {
    layer_names[i - 1]: log(i, total_acc_drop, len(layer_names)) for i in range(1, len(layer_names) + 1)
}

opts = OptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc)
a_scores[alloc_type], opt_params_act[alloc_type], acc_drop_a[alloc_type] = opts.run('activations', start_bw = start_bw)
# Out:
# {'conv2d_1': [16, 15], 'conv2d_2': [16, 12], 'conv2d_3': [16, 11], 'conv2d_4': [16, 11], 'conv2d_5': [16, 11], 'conv2d_6': [16, 11], 'conv2d_7': [16, 12], 'conv2d_8': [16, 11], 'conv2d_9': [16, 11], 'conv2d_10': [16, 11], 'conv2d_11': [16, 11], 'conv2d_12': [16, 11], 'conv2d_13': [16, 11], 'conv2d_14': [16, 11], 'dense_1': [16, 10]}
# Finding quantization for each layer depending on quantization for previous layers
# Quantizing layer conv2d_1
# (12, 11) (12, 11) 0.0
# Chosen:  (12, 11)
# After quantizing layer conv2d_1 | Measured accuracy drop 0.0 | Acceptable accuracy drop: 0.0
# Quantizing layer conv2d_2
# (4, 1) (5, 2) 0.0008040201005025356
# Chosen:  (4, 1)
# After quantizing layer conv2d_2 | Measured accuracy drop 0.0011055276381909446 | Acceptable accuracy drop: 0.0012797901240490775
# Quantizing layer conv2d_3
# (5, 2) (6, 3) 0.00030150753768852056
# Chosen:  (5, 2)
# After quantizing layer conv2d_3 | Measured accuracy drop 0.0017085427135678742 | Acceptable accuracy drop: 0.002028419355411065
# Quantizing layer conv2d_4
# (3, -1) (4, 0) 0.0005025125628140149
# Chosen:  (3, -1)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.002211055276381889 | Acceptable accuracy drop: 0.002559580248098155
# Quantizing layer conv2d_5
# (3, -1) (4, -1) 0.0005025125628141266
# Chosen:  (3, -1)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.002814070351758819 | Acceptable accuracy drop: 0.0029715806445889353
# Quantizing layer conv2d_6
# (5, 1) (5, 1) 0.0
# Chosen:  (5, 1)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.0027135678391960157 | Acceptable accuracy drop: 0.003308209479460142
# Quantizing layer conv2d_7
# (4, 1) (4, 1) 0.0
# Chosen:  (4, 1)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.0026130653266332126 | Acceptable accuracy drop: 0.0035928251039498895
# Quantizing layer conv2d_8
# (4, 0) (4, 0) 0.0
# Chosen:  (4, 0)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.002512562814070298 | Acceptable accuracy drop: 0.0038393703721472322
# Quantizing layer conv2d_9
# (3, -1) (4, 0) 0.0011055276381909443
# Chosen:  (3, -1)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.003919597989949763 | Acceptable accuracy drop: 0.00405683871082213
# Quantizing layer conv2d_10
# (4, 0) (5, 1) 0.0003015075376884089
# Chosen:  (4, 0)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.003919597989949763 | Acceptable accuracy drop: 0.0042513707686380135
# Quantizing layer conv2d_11
# (4, 0) (4, 0) 0.0
# Chosen:  (4, 0)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.0038190954773869605 | Acceptable accuracy drop: 0.004427346420355128
# Quantizing layer conv2d_12
# (4, 0) (5, 1) 0.00020100502512560622
# Chosen:  (4, 0)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.004321608040200976 | Acceptable accuracy drop: 0.00458799960350922
# Quantizing layer conv2d_13
# (3, 0) (4, 1) 0.0002010050251257181
# Chosen:  (3, 0)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.004623115577889496 | Acceptable accuracy drop: 0.004735786205915922
# Quantizing layer conv2d_14
# (5, 1) (5, 2) 0.0003015075376885199
# Chosen:  (5, 2)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.004522613065326582 | Acceptable accuracy drop: 0.004872615227998966
# Quantizing layer dense_1
# (6, 2) (7, 3) 0.00020100502512560535
# Chosen:  (6, 2)
# After quantizing layer dense_1 | Measured accuracy drop 0.004824120603015102 | Acceptable accuracy drop: 0.005

# %%
if not isinstance(opt_params_act[alloc_type], int):
    print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

    model_obj = model_data.Model(name, test_data, model=model_arch.get_fxp_model(opt_params_act[alloc_type]))
    fxp_model_acc = model_obj.evaluate_accuracy()[1]
    print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
    print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

    opts.plot_scores_matrix(a_scores[alloc_type], 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 99.500 %
# Quantized model accuracy: 99.020 %
# Accuracy drop of 0.482 %

# %%
with open(output_path + 'fixed/a_scores.p', 'wb') as f:
    pickle.dump(a_scores, f, protocol=pickle.HIGHEST_PROTOCOL)

with open(output_path + 'fixed/opt_params_a.p', 'wb') as f:
    pickle.dump(opt_params_act, f, protocol=pickle.HIGHEST_PROTOCOL)

with open(output_path + 'fixed/acc_drop_a.p', 'wb') as f:
    pickle.dump(acc_drop_a, f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
## Accuracy drop
x = np.arange(1, len(layer_names) + 1, 1)

plt.figure(figsize=(10, 7))
for k in acc_drop_w:
    plt.plot(x, acc_drop_a[k].values(), 'o-', label=k)
plt.title('Accuracy drop');
plt.xlabel('Layers');
plt.ylabel('Accuracy drop');
plt.xticks(x, layer_names, rotation='vertical')
plt.grid()
plt.legend();

# %%
x = np.arange(1, 16, 1)
num_layers = len(x)
n = 0.005 # loss of 0.5%
y1 = np.ones(x.shape) * n # constant
y2 = n/num_layers * x
y3 = n/num_layers**2 * x**2 # Quadratic
y4 = n/num_layers**3 * x**3 # Cubic
y5 = n/2**num_layers * 2**x # Exponential
y6 = n/np.log(num_layers) * np.log(x) # log

fig, axes = plt.subplots(3, 2, figsize=(20, 27))
ax = axes.flatten()
ax[0].plot(x, y1, 'o-', label='ideal');
ax[0].plot(x, acc_drop_a['constant'].values(), 'o-', label='measured');

ax[1].plot(x, y2, 'o-', label='ideal');
ax[1].plot(x, acc_drop_a['linear'].values(), 'o-', label='measured');

ax[2].plot(x, y3, 'o-', label='ideal');
ax[2].plot(x, acc_drop_a['quadratic'].values(), 'o-', label='measured');

ax[3].plot(x, y4, 'o-', label='ideal');
ax[3].plot(x, acc_drop_a['cubic'].values(), 'o-', label='measured');

ax[4].plot(x, y5, 'o-', label='ideal');
ax[4].plot(x, acc_drop_a['exponential'].values(), 'o-', label='measured');

ax[5].plot(x, y6, 'o-', label='ideal');
ax[5].plot(x, acc_drop_a['log'].values(), 'o-', label='measured');

for i in range(6):
    ax[i].set_xticks(x)
    ax[i].set_xticklabels(layer_names, rotation=90)
    # plt.title('Accuracy drop');
    ax[i].set_xlabel('Layers');
    ax[i].set_ylabel('Accuracy drop');
    ax[i].grid();
    ax[i].legend();

# %%
## Bitwidths
x = np.arange(1, len(layer_names) + 1, 1)

plt.figure(figsize=(10, 7))
for k in opt_params_act:
    bw = [opt_params_act[k][layer][0] for layer in opt_params_act[k]]
    plt.plot(x, bw, 'o-', label=k)
plt.xticks(x, layer_names, rotation='vertical')
plt.title('Bitwidths')
plt.xlabel('Layers');
plt.ylabel('Bitwidth');
plt.grid()
plt.legend();

# %%
plt.figure(figsize=(20, 7))
width = 0.35
x = np.arange(1, 3*len(layer_names) + 1, 3)
for j, k in enumerate(opt_params_act.keys()):
    bw = [opt_params_act[k][layer][0] for layer in opt_params_act[k]]
    plt.bar([i + j*width for i in x], bw, width, label=k)
plt.xticks(x, layer_names, rotation='horizontal')
plt.title('Bitwidths')
plt.xlabel('Layers');
plt.ylabel('Bitwidth');
plt.grid()
plt.legend();
