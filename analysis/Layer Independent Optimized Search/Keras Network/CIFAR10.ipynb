# %%
import sys
sys.path.append('C:/Users/320060820/experiments/')
import fxp_quantize
import model_data
from algorithms import fixed_bitwidth
from model_gen import keras_cnn
from algorithms.ind_optimized_search import IndependentOptimizedSearch

import keras
import tensorflow as tf
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import itertools

# to restart layer numbering
from keras import backend as K
K.clear_session()
# Out:
# Using TensorFlow backend.

# %%
input_shape = (32, 32, 3)
num_outputs = 10
num_kernels = 32
num_stages = 7
path_trained_weights = 'C:/Users/320060820/experiments/test_models/cifar_keras/cifar_seq_large_w.h5'
name = 'cifar_seq_large'
total_acc_drop = 0.003

from test_models.cifar_keras import data
_, test_data = data.get_data()

model_arch = keras_cnn.KerasCNNLarge(input_shape, num_outputs, num_kernels, num_stages, pool_layer_interval = 2, 
                                     path_trained_weights = path_trained_weights)
model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
float_model_acc = model_obj.evaluate_accuracy()[1]
# Out:
# WARNING:tensorflow:From C:\Users\320060820\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\320060820\Anaconda3\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %% [markdown]
# ### Weights

# %%
layer_names = []

for layer in model_obj.model.layers:
    if layer.name.startswith('conv2d') or layer.name.startswith('dense'):
        layer_names.append(layer.name)

# %%
# weights
acc_drop_config = {
    layer_name: 0.003 for layer_name in layer_names
}
opts = IndependentOptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc, layer_independent_quant=True)
w_scores, opt_params_weights, acc_drop_w = opts.run('weights', start_bw = 8)
opt_params_weights
# Out:
# {'conv2d_1': [8, 9], 'conv2d_2': [8, 9], 'conv2d_3': [8, 9], 'conv2d_4': [8, 9], 'conv2d_5': [8, 9], 'conv2d_6': [8, 9], 'conv2d_7': [8, 9], 'conv2d_8': [8, 9], 'conv2d_9': [8, 9], 'conv2d_10': [8, 9], 'conv2d_11': [8, 9], 'conv2d_12': [8, 9], 'conv2d_13': [8, 9], 'conv2d_14': [8, 9], 'dense_1': [8, 7]}
# Finding quantization for each layer independently of other layers
# Quantizing layer conv2d_1
# Global opt: (8, 9) Local opt: (9, 10) Performance diff: 0.000728
# Chosen:  (8, 9)
# After quantizing layer conv2d_1 | Measured accuracy drop 0.001334 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_2
# Global opt: (5, 6) Local opt: (5, 7) Performance diff: 0.001698
# Chosen:  (5, 7)
# After quantizing layer conv2d_2 | Measured accuracy drop 0.001577 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_3
# Global opt: (5, 6) Local opt: (6, 7) Performance diff: 0.001092
# Chosen:  (5, 6)
# After quantizing layer conv2d_3 | Measured accuracy drop 0.001941 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_4
# Global opt: (5, 6) Local opt: (6, 7) Performance diff: 0.002062
# Chosen:  (6, 7)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.002790 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_5
# Global opt: (5, 6) Local opt: (5, 6) Performance diff: 0.000000
# Chosen:  (5, 6)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.001577 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_6
# Global opt: (4, 5) Local opt: (5, 6) Performance diff: 0.002426
# Chosen:  (5, 6)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.002062 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_7
# Global opt: (4, 6) Local opt: (5, 6) Performance diff: 0.001213
# Chosen:  (4, 6)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.002062 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_8
# Global opt: (4, 6) Local opt: (5, 7) Performance diff: 0.001456
# Chosen:  (4, 6)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.001213 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_9
# Global opt: (4, 6) Local opt: (5, 6) Performance diff: 0.000121
# Chosen:  (4, 6)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.001820 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_10
# Global opt: (3, 5) Local opt: (3, 5) Performance diff: 0.000000
# Chosen:  (3, 5)
# After quantizing layer conv2d_10 | Measured accuracy drop -0.000849 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_11
# Global opt: (4, 6) Local opt: (5, 6) Performance diff: 0.000121
# Chosen:  (4, 6)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.000364 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_12
# Global opt: (2, 4) Local opt: (3, 5) Performance diff: 0.002548
# Chosen:  (3, 5)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.000971 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_13
# Global opt: (2, 3) Local opt: (2, 4) Performance diff: 0.001698
# Chosen:  (2, 4)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.005338 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_14
# Global opt: (2, 4) Local opt: (3, 5) Performance diff: 0.000364
# Chosen:  (2, 4)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.007400 | Acceptable accuracy drop: 0.003000
# Quantizing layer dense_1
# Global opt: (3, 4) Local opt: (4, 5) Performance diff: 0.003033
# Chosen:  (4, 5)
# After quantizing layer dense_1 | Measured accuracy drop 0.011282 | Acceptable accuracy drop: 0.003000
# {'conv2d_1': (8, 9),
#  'conv2d_2': (5, 7),
#  'conv2d_3': (5, 6),
#  'conv2d_4': (6, 7),
#  'conv2d_5': (5, 6),
#  'conv2d_6': (5, 6),
#  'conv2d_7': (4, 6),
#  'conv2d_8': (4, 6),
#  'conv2d_9': (4, 6),
#  'conv2d_10': (3, 5),
#  'conv2d_11': (4, 6),
#  'conv2d_12': (3, 5),
#  'conv2d_13': (2, 4),
#  'conv2d_14': (2, 4),
#  'dense_1': (4, 5)}

# %%
print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
model_obj = fxp_quantize.fix_weights_quantization(model_obj, opt_params_weights)
fxp_model_acc = model_obj.evaluate_accuracy()[1]
print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

opts.plot_scores_matrix(w_scores, 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 82.430 %
# Quantized model accuracy: 81.500 %
# Accuracy drop of 1.128 %

# %%
for layer in w_scores:
    print(f'Layer {layer} acc drop: {w_scores[layer][opt_params_weights[layer][0]][opt_params_weights[layer][1]]:.5f}')
# Out:
# Layer conv2d_1 acc drop: 0.00133
# Layer conv2d_2 acc drop: -0.00036
# Layer conv2d_3 acc drop: 0.00146
# Layer conv2d_4 acc drop: 0.00036
# Layer conv2d_5 acc drop: 0.00036
# Layer conv2d_6 acc drop: -0.00024
# Layer conv2d_7 acc drop: 0.00121
# Layer conv2d_8 acc drop: 0.00146
# Layer conv2d_9 acc drop: -0.00061
# Layer conv2d_10 acc drop: -0.00182
# Layer conv2d_11 acc drop: 0.00097
# Layer conv2d_12 acc drop: -0.00036
# Layer conv2d_13 acc drop: 0.00097
# Layer conv2d_14 acc drop: 0.00170
# Layer dense_1 acc drop: -0.00012

# %%
x = np.arange(1, len(acc_drop_w.values()) + 1, 1)
y = np.array(list(acc_drop_w.values())) * 100
labels = list(acc_drop_w.keys())

plt.figure(figsize=(10, 7))
plt.plot(x, y, 'o-');
plt.xlabel('Layer Quantized')
plt.ylabel('Accuracy drop compared to float model (%)')
plt.xticks(x, labels, rotation='vertical');
plt.grid()

# %%
import pickle

save_path = 'C:/Users/320060820/experiments/outputs/Independent_Optimized_Search/Keras CIFAR10/'

with open(save_path + 'scores_w.p', 'wb') as f:
    pickle.dump(w_scores, f)
with open(save_path + 'opt_params_w.p', 'wb') as f:
    pickle.dump(opt_params_weights, f)
with open(save_path + 'acc_drop_w.p', 'wb') as f:
    pickle.dump(acc_drop_w, f)

# %% [markdown]
# ## Biases

# %%
# biases
acc_drop_config = {
    layer_name: 0.003 for layer_name in layer_names
}
opts = IndependentOptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc, layer_independent_quant=True)
b_scores, opt_params_biases, acc_drop_b = opts.run('biases', start_bw = 8)
opt_params_biases
# Out:
# {'conv2d_1': [8, 10], 'conv2d_2': [8, 10], 'conv2d_3': [8, 10], 'conv2d_4': [8, 9], 'conv2d_5': [8, 9], 'conv2d_6': [8, 9], 'conv2d_7': [8, 10], 'conv2d_8': [8, 10], 'conv2d_9': [8, 9], 'conv2d_10': [8, 10], 'conv2d_11': [8, 9], 'conv2d_12': [8, 9], 'conv2d_13': [8, 9], 'conv2d_14': [8, 10], 'dense_1': [8, 9]}
# Finding quantization for each layer independently of other layers
# Quantizing layer conv2d_1
# Global opt: (5, 7) Local opt: (6, 8) Performance diff: 0.001820
# Chosen:  (6, 8)
# After quantizing layer conv2d_1 | Measured accuracy drop 0.001092 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_2
# Global opt: (1, 3) Local opt: (2, 3) Performance diff: 0.000849
# Chosen:  (1, 3)
# After quantizing layer conv2d_2 | Measured accuracy drop 0.000485 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_3
# Global opt: (2, 4) Local opt: (2, 3) Performance diff: 0.000000
# Chosen:  (2, 3)
# After quantizing layer conv2d_3 | Measured accuracy drop 0.001092 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_4
# Global opt: (2, 4) Local opt: (3, 4) Performance diff: 0.001213
# Chosen:  (2, 4)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.000971 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_5
# Global opt: (1, 2) Local opt: (2, 3) Performance diff: 0.000728
# Chosen:  (1, 2)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.004489 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_6
# Global opt: (1, 2) Local opt: (1, 1) Performance diff: 0.000000
# Chosen:  (1, 1)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.005338 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_7
# Global opt: (1, 3) Local opt: (1, 2) Performance diff: 0.000000
# Chosen:  (1, 2)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.003882 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_8
# Global opt: (1, 3) Local opt: (1, 2) Performance diff: 0.000000
# Chosen:  (1, 2)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.003397 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_9
# Global opt: (1, 2) Local opt: (2, 2) Performance diff: 0.000849
# Chosen:  (1, 2)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.002790 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_10
# Global opt: (1, 3) Local opt: (1, 2) Performance diff: 0.000000
# Chosen:  (1, 2)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.002426 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_11
# Global opt: (1, 2) Local opt: (2, 2) Performance diff: 0.000364
# Chosen:  (1, 2)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.002912 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_12
# Global opt: (1, 2) Local opt: (2, 3) Performance diff: 0.002305
# Chosen:  (2, 3)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.003154 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_13
# Global opt: (1, 2) Local opt: (2, 3) Performance diff: 0.000243
# Chosen:  (1, 2)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.003639 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_14
# Global opt: (1, 3) Local opt: (2, 3) Performance diff: 0.000243
# Chosen:  (1, 3)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.004125 | Acceptable accuracy drop: 0.003000
# Quantizing layer dense_1
# Global opt: (1, 2) Local opt: (2, 3) Performance diff: 0.000485
# Chosen:  (1, 2)
# After quantizing layer dense_1 | Measured accuracy drop 0.004489 | Acceptable accuracy drop: 0.003000
# {'conv2d_1': (6, 8),
#  'conv2d_2': (1, 3),
#  'conv2d_3': (2, 3),
#  'conv2d_4': (2, 4),
#  'conv2d_5': (1, 2),
#  'conv2d_6': (1, 1),
#  'conv2d_7': (1, 2),
#  'conv2d_8': (1, 2),
#  'conv2d_9': (1, 2),
#  'conv2d_10': (1, 2),
#  'conv2d_11': (1, 2),
#  'conv2d_12': (2, 3),
#  'conv2d_13': (1, 2),
#  'conv2d_14': (1, 3),
#  'dense_1': (1, 2)}

# %%
print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
model_obj = fxp_quantize.fix_biases_quantization(model_obj, opt_params_biases)
fxp_model_acc = model_obj.evaluate_accuracy()[1]
print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

opts.plot_scores_matrix(b_scores, 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 82.430 %
# Quantized model accuracy: 82.060 %
# Accuracy drop of 0.449 %

# %%
for layer in b_scores:
    print(f'Layer {layer} acc drop: {b_scores[layer][opt_params_biases[layer][0]][opt_params_biases[layer][1]]:.5f}')
# Out:
# Layer conv2d_1 acc drop: 0.00109
# Layer conv2d_2 acc drop: 0.00024
# Layer conv2d_3 acc drop: 0.00036
# Layer conv2d_4 acc drop: 0.00146
# Layer conv2d_5 acc drop: 0.00182
# Layer conv2d_6 acc drop: 0.00085
# Layer conv2d_7 acc drop: -0.00158
# Layer conv2d_8 acc drop: 0.00000
# Layer conv2d_9 acc drop: -0.00012
# Layer conv2d_10 acc drop: -0.00073
# Layer conv2d_11 acc drop: 0.00218
# Layer conv2d_12 acc drop: -0.00012
# Layer conv2d_13 acc drop: 0.00097
# Layer conv2d_14 acc drop: 0.00085
# Layer dense_1 acc drop: 0.00182

# %%
x = np.arange(1, len(acc_drop_b.values()) + 1, 1)
y = np.array(list(acc_drop_b.values())) * 100
labels = list(acc_drop_b.keys())

plt.figure(figsize=(10, 7))
plt.plot(x, y, 'o-');
plt.xlabel('Layer Quantized')
plt.ylabel('Accuracy drop compared to float model (%)')
plt.xticks(x, labels, rotation='vertical');
plt.grid()

# %%
# activations
acc_drop_config = {
    layer_name: 0.003 for layer_name in layer_names
}
opts = IndependentOptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc, layer_independent_quant=True)
a_scores, opt_params_act, acc_drop_a = opts.run('activations', start_bw = 8)
opt_params_act
# Out:
# {'conv2d_1': [8, 7], 'conv2d_2': [8, 4], 'conv2d_3': [8, 3], 'conv2d_4': [8, 3], 'conv2d_5': [8, 2], 'conv2d_6': [8, 3], 'conv2d_7': [8, 3], 'conv2d_8': [8, 3], 'conv2d_9': [8, 2], 'conv2d_10': [8, 3], 'conv2d_11': [8, 3], 'conv2d_12': [8, 2], 'conv2d_13': [8, 2], 'conv2d_14': [8, 2], 'dense_1': [8, 2]}
# Finding quantization for each layer independently of other layers
# Quantizing layer conv2d_1
# Global opt: (7, 7) Local opt: (8, 8) Performance diff: 0.001698
# Chosen:  (8, 8)
# After quantizing layer conv2d_1 | Measured accuracy drop -0.000364 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_2
# Global opt: (6, 3) Local opt: (6, 3) Performance diff: 0.000000
# Chosen:  (6, 3)
# After quantizing layer conv2d_2 | Measured accuracy drop 0.001456 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_3
# Global opt: (6, 2) Local opt: (7, 3) Performance diff: 0.001334
# Chosen:  (6, 2)
# After quantizing layer conv2d_3 | Measured accuracy drop 0.002426 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_4
# Global opt: (4, 0) Local opt: (5, 1) Performance diff: 0.000607
# Chosen:  (4, 0)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.000000 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_5
# Global opt: (5, 0) Local opt: (6, 1) Performance diff: 0.001941
# Chosen:  (6, 1)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.000728 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_6
# Global opt: (4, 0) Local opt: (5, 1) Performance diff: 0.001698
# Chosen:  (5, 1)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.001334 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_7
# Global opt: (4, 1) Local opt: (5, 2) Performance diff: 0.002548
# Chosen:  (5, 2)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.002184 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_8
# Global opt: (4, 0) Local opt: (5, 1) Performance diff: 0.002669
# Chosen:  (5, 1)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.002184 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_9
# Global opt: (4, 0) Local opt: (5, 0) Performance diff: 0.000971
# Chosen:  (4, 0)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.001698 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_10
# Global opt: (5, 1) Local opt: (6, 2) Performance diff: 0.000607
# Chosen:  (5, 1)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.001698 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_11
# Global opt: (4, 1) Local opt: (4, 1) Performance diff: 0.000000
# Chosen:  (4, 1)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.002912 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_12
# Global opt: (3, 0) Local opt: (4, 0) Performance diff: 0.001456
# Chosen:  (3, 0)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.008007 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_13
# Global opt: (4, 0) Local opt: (4, 0) Performance diff: 0.000000
# Chosen:  (4, 0)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.008856 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_14
# Global opt: (4, 0) Local opt: (5, 1) Performance diff: 0.000728
# Chosen:  (4, 0)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.009705 | Acceptable accuracy drop: 0.003000
# Quantizing layer dense_1
# Global opt: (4, 0) Local opt: (5, 1) Performance diff: 0.000728
# Chosen:  (4, 0)
# After quantizing layer dense_1 | Measured accuracy drop 0.012010 | Acceptable accuracy drop: 0.003000
# {'conv2d_1': (8, 8),
#  'conv2d_2': (6, 3),
#  'conv2d_3': (6, 2),
#  'conv2d_4': (4, 0),
#  'conv2d_5': (6, 1),
#  'conv2d_6': (5, 1),
#  'conv2d_7': (5, 2),
#  'conv2d_8': (5, 1),
#  'conv2d_9': (4, 0),
#  'conv2d_10': (5, 1),
#  'conv2d_11': (4, 1),
#  'conv2d_12': (3, 0),
#  'conv2d_13': (4, 0),
#  'conv2d_14': (4, 0),
#  'dense_1': (4, 0)}

# %%
print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

model_obj = model_data.Model(name, test_data, model=model_arch.get_fxp_model(opt_params_act))
fxp_model_acc = model_obj.evaluate_accuracy()[1]
print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

opts.plot_scores_matrix(a_scores, 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 82.430 %
# Quantized model accuracy: 81.440 %
# Accuracy drop of 1.201 %

# %%
for layer in a_scores:
    print(f'Layer {layer} acc drop: {a_scores[layer][opt_params_act[layer][0]][opt_params_act[layer][1]]:.5f}')
# Out:
# Layer conv2d_1 acc drop: -0.00036
# Layer conv2d_2 acc drop: 0.00024
# Layer conv2d_3 acc drop: 0.00133
# Layer conv2d_4 acc drop: -0.00049
# Layer conv2d_5 acc drop: -0.00036
# Layer conv2d_6 acc drop: 0.00109
# Layer conv2d_7 acc drop: -0.00061
# Layer conv2d_8 acc drop: -0.00061
# Layer conv2d_9 acc drop: 0.00206
# Layer conv2d_10 acc drop: 0.00158
# Layer conv2d_11 acc drop: -0.00182
# Layer conv2d_12 acc drop: 0.00146
# Layer conv2d_13 acc drop: 0.00109
# Layer conv2d_14 acc drop: 0.00121
# Layer dense_1 acc drop: 0.00073

# %%
x = np.arange(1, len(acc_drop_a.values()) + 1, 1)
y = np.array(list(acc_drop_a.values())) * 100
labels = list(acc_drop_a.keys())

plt.figure(figsize=(10, 7))
plt.plot(x, y, 'o-');
plt.xlabel('Layer Quantized')
plt.ylabel('Accuracy drop compared to float model (%)')
plt.xticks(x, labels, rotation='vertical');
plt.grid()

# %%
with open(save_path + 'opt_params_w.p', 'rb') as f:
    opt_params_weights = pickle.load(f)

# %%
def quantize_evaluate(model_arch, test_data, float_model_acc, w_quant_params, b_quant_params={}, a_quant_params={}):
    
    if a_quant_params:
        model_obj = model_data.Model('name', test_data, model=model_arch.get_fxp_model(a_quant_params))
    else:
        model_obj = model_data.Model('name', test_data, model=model_arch.get_float_model())
    
    model_obj = fxp_quantize.fix_weights_quantization(model_obj, w_quant_params)
    if b_quant_params:
        model_obj = fxp_quantize.fix_biases_quantization(model_obj, b_quant_params)
    
    return (float_model_acc - model_obj.evaluate_accuracy()[1]) / float_model_acc

# %%
def evaluate_seq_quant_performance(model_arch, test_data, float_model_acc, w_quant_params, b_quant_params, a_quant_params):
    
    acc_drop_b = {}
    for i in range(1, len(list(b_quant_params.keys())) + 1):
        test_case = dict(itertools.islice(b_quant_params.items(), i))
        a = quantize_evaluate(model_arch, test_data, float_model_acc, w_quant_params, test_case)
        acc_drop_b[list(test_case.keys())[-1]] = a
        print(acc_drop_b)

    acc_drop_a = {}
    for i in range(1, len(list(a_quant_params.keys())) + 1):
        test_case = dict(itertools.islice(a_quant_params.items(), i))
        a = quantize_evaluate(model_arch, test_data, float_model_acc, w_quant_params, b_quant_params, test_case)
        acc_drop_a[list(test_case.keys())[-1]] = a
        print(acc_drop_a)
        
    return acc_drop_b, acc_drop_a

# %%
acc_drop_b, acc_drop_a = evaluate_seq_quant_performance(model_arch, test_data, float_model_acc, opt_params_weights, 
                                            opt_params_biases,
                                            opt_params_act)
# Out:
# {'conv2d_1': 0.011160985078248193}
# {'conv2d_1': 0.011160985078248193, 'conv2d_2': 0.013344656071818523}
# {'conv2d_1': 0.011160985078248193, 'conv2d_2': 0.013344656071818523, 'conv2d_3': 0.015164381899793845}
# {'conv2d_1': 0.011160985078248193, 'conv2d_2': 0.013344656071818523, 'conv2d_3': 0.015164381899793845, 'conv2d_4': 0.015407012010190518}
# {'conv2d_1': 0.011160985078248193, 'conv2d_2': 0.013344656071818523, 'conv2d_3': 0.015164381899793845, 'conv2d_4': 0.015407012010190518, 'conv2d_5': 0.016013587286182202}
# {'conv2d_1': 0.011160985078248193, 'conv2d_2': 0.013344656071818523, 'conv2d_3': 0.015164381899793845, 'conv2d_4': 0.015407012010190518, 'conv2d_5': 0.016013587286182202, 'conv2d_6': 0.02110881960451302}
# {'conv2d_1': 0.011160985078248193, 'conv2d_2': 0.013344656071818523, 'conv2d_3': 0.015164381899793845, 'conv2d_4': 0.015407012010190518, 'conv2d_5': 0.016013587286182202, 'conv2d_6': 0.02110881960451302, 'conv2d_7': 0.02268591532209153}
# {'conv2d_1': 0.011160985078248193, 'conv2d_2': 0.013344656071818523, 'conv2d_3': 0.015164381899793845, 'conv2d_4': 0.015407012010190518, 'conv2d_5': 0.016013587286182202, 'conv2d_6': 0.02110881960451302, 'conv2d_7': 0.02268591532209153, 'conv2d_8': 0.020138299162926192}
# {'conv2d_1': 0.011160985078248193, 'conv2d_2': 0.013344656071818523, 'conv2d_3': 0.015164381899793845, 'conv2d_4': 0.015407012010190518, 'conv2d_5': 0.016013587286182202, 'conv2d_6': 0.02110881960451302, 'conv2d_7': 0.02268591532209153, 'conv2d_8': 0.020138299162926192, 'conv2d_9': 0.01965303894213271}
# {'conv2d_1': 0.011160985078248193, 'conv2d_2': 0.013344656071818523, 'conv2d_3': 0.015164381899793845, 'conv2d_4': 0.015407012010190518, 'conv2d_5': 0.016013587286182202, 'conv2d_6': 0.02110881960451302, 'conv2d_7': 0.02268591532209153, 'conv2d_8': 0.020138299162926192, 'conv2d_9': 0.01965303894213271, 'conv2d_10': 0.019895669052529517}
# {'conv2d_1': 0.011160985078248193, 'conv2d_2': 0.013344656071818523, 'conv2d_3': 0.015164381899793845, 'conv2d_4': 0.015407012010190518, 'conv2d_5': 0.016013587286182202, 'conv2d_6': 0.02110881960451302, 'conv2d_7': 0.02268591532209153, 'conv2d_8': 0.020138299162926192, 'conv2d_9': 0.01965303894213271, 'conv2d_10': 0.019895669052529517, 'conv2d_11': 0.018439888390149206}
# {'conv2d_1': 0.011160985078248193, 'conv2d_2': 0.013344656071818523, 'conv2d_3': 0.015164381899793845, 'conv2d_4': 0.015407012010190518, 'conv2d_5': 0.016013587286182202, 'conv2d_6': 0.02110881960451302, 'conv2d_7': 0.02268591532209153, 'conv2d_8': 0.020138299162926192, 'conv2d_9': 0.01965303894213271, 'conv2d_10': 0.019895669052529517, 'conv2d_11': 0.018439888390149206, 'conv2d_12': 0.018439888390149206}
# {'conv2d_1': 0.011160985078248193, 'conv2d_2': 0.013344656071818523, 'conv2d_3': 0.015164381899793845, 'conv2d_4': 0.015407012010190518, 'conv2d_5': 0.016013587286182202, 'conv2d_6': 0.02110881960451302, 'conv2d_7': 0.02268591532209153, 'conv2d_8': 0.020138299162926192, 'conv2d_9': 0.01965303894213271, 'conv2d_10': 0.019895669052529517, 'conv2d_11': 0.018439888390149206, 'conv2d_12': 0.018439888390149206, 'conv2d_13': 0.019410408831736035}
# {'conv2d_1': 0.011160985078248193, 'conv2d_2': 0.013344656071818523, 'conv2d_3': 0.015164381899793845, 'conv2d_4': 0.015407012010190518, 'conv2d_5': 0.016013587286182202, 'conv2d_6': 0.02110881960451302, 'conv2d_7': 0.02268591532209153, 'conv2d_8': 0.020138299162926192, 'conv2d_9': 0.01965303894213271, 'conv2d_10': 0.019895669052529517, 'conv2d_11': 0.018439888390149206, 'conv2d_12': 0.018439888390149206, 'conv2d_13': 0.019410408831736035, 'conv2d_14': 0.020744874438917874}
# {'conv2d_1': 0.011160985078248193, 'conv2d_2': 0.013344656071818523, 'conv2d_3': 0.015164381899793845, 'conv2d_4': 0.015407012010190518, 'conv2d_5': 0.016013587286182202, 'conv2d_6': 0.02110881960451302, 'conv2d_7': 0.02268591532209153, 'conv2d_8': 0.020138299162926192, 'conv2d_9': 0.01965303894213271, 'conv2d_10': 0.019895669052529517, 'conv2d_11': 0.018439888390149206, 'conv2d_12': 0.018439888390149206, 'conv2d_13': 0.019410408831736035, 'conv2d_14': 0.020744874438917874, 'dense_1': 0.018075943224554195}
# {'conv2d_1': 0.0192890937765377}
# {'conv2d_1': 0.0192890937765377, 'conv2d_2': 0.017105422782967367}
# {'conv2d_1': 0.0192890937765377, 'conv2d_2': 0.017105422782967367, 'conv2d_3': 0.01831857333495087}
# {'conv2d_1': 0.0192890937765377, 'conv2d_2': 0.017105422782967367, 'conv2d_3': 0.01831857333495087, 'conv2d_4': 0.01734805289336404}
# {'conv2d_1': 0.0192890937765377, 'conv2d_2': 0.017105422782967367, 'conv2d_3': 0.01831857333495087, 'conv2d_4': 0.01734805289336404, 'conv2d_5': 0.01819725827975253}
# {'conv2d_1': 0.0192890937765377, 'conv2d_2': 0.017105422782967367, 'conv2d_3': 0.01831857333495087, 'conv2d_4': 0.01734805289336404, 'conv2d_5': 0.01819725827975253, 'conv2d_6': 0.019774353997331046}
# {'conv2d_1': 0.0192890937765377, 'conv2d_2': 0.017105422782967367, 'conv2d_3': 0.01831857333495087, 'conv2d_4': 0.01734805289336404, 'conv2d_5': 0.01819725827975253, 'conv2d_6': 0.019774353997331046, 'conv2d_7': 0.019410408831736035}
# {'conv2d_1': 0.0192890937765377, 'conv2d_2': 0.017105422782967367, 'conv2d_3': 0.01831857333495087, 'conv2d_4': 0.01734805289336404, 'conv2d_5': 0.01819725827975253, 'conv2d_6': 0.019774353997331046, 'conv2d_7': 0.019410408831736035, 'conv2d_8': 0.018925148610942688}
# {'conv2d_1': 0.0192890937765377, 'conv2d_2': 0.017105422782967367, 'conv2d_3': 0.01831857333495087, 'conv2d_4': 0.01734805289336404, 'conv2d_5': 0.01819725827975253, 'conv2d_6': 0.019774353997331046, 'conv2d_7': 0.019410408831736035, 'conv2d_8': 0.018925148610942688, 'conv2d_9': 0.021715394880504703}
# {'conv2d_1': 0.0192890937765377, 'conv2d_2': 0.017105422782967367, 'conv2d_3': 0.01831857333495087, 'conv2d_4': 0.01734805289336404, 'conv2d_5': 0.01819725827975253, 'conv2d_6': 0.019774353997331046, 'conv2d_7': 0.019410408831736035, 'conv2d_8': 0.018925148610942688, 'conv2d_9': 0.021715394880504703, 'conv2d_10': 0.024141695984471707}
# {'conv2d_1': 0.0192890937765377, 'conv2d_2': 0.017105422782967367, 'conv2d_3': 0.01831857333495087, 'conv2d_4': 0.01734805289336404, 'conv2d_5': 0.01819725827975253, 'conv2d_6': 0.019774353997331046, 'conv2d_7': 0.019410408831736035, 'conv2d_8': 0.018925148610942688, 'conv2d_9': 0.021715394880504703, 'conv2d_10': 0.024141695984471707, 'conv2d_11': 0.027417202474827203}
# {'conv2d_1': 0.0192890937765377, 'conv2d_2': 0.017105422782967367, 'conv2d_3': 0.01831857333495087, 'conv2d_4': 0.01734805289336404, 'conv2d_5': 0.01819725827975253, 'conv2d_6': 0.019774353997331046, 'conv2d_7': 0.019410408831736035, 'conv2d_8': 0.018925148610942688, 'conv2d_9': 0.021715394880504703, 'conv2d_10': 0.024141695984471707, 'conv2d_11': 0.027417202474827203, 'conv2d_12': 0.03687977678029841}
# {'conv2d_1': 0.0192890937765377, 'conv2d_2': 0.017105422782967367, 'conv2d_3': 0.01831857333495087, 'conv2d_4': 0.01734805289336404, 'conv2d_5': 0.01819725827975253, 'conv2d_6': 0.019774353997331046, 'conv2d_7': 0.019410408831736035, 'conv2d_8': 0.018925148610942688, 'conv2d_9': 0.021715394880504703, 'conv2d_10': 0.024141695984471707, 'conv2d_11': 0.027417202474827203, 'conv2d_12': 0.03687977678029841, 'conv2d_13': 0.03566662622831491}
# {'conv2d_1': 0.0192890937765377, 'conv2d_2': 0.017105422782967367, 'conv2d_3': 0.01831857333495087, 'conv2d_4': 0.01734805289336404, 'conv2d_5': 0.01819725827975253, 'conv2d_6': 0.019774353997331046, 'conv2d_7': 0.019410408831736035, 'conv2d_8': 0.018925148610942688, 'conv2d_9': 0.021715394880504703, 'conv2d_10': 0.024141695984471707, 'conv2d_11': 0.027417202474827203, 'conv2d_12': 0.03687977678029841, 'conv2d_13': 0.03566662622831491, 'conv2d_14': 0.04440131020259623}
# {'conv2d_1': 0.0192890937765377, 'conv2d_2': 0.017105422782967367, 'conv2d_3': 0.01831857333495087, 'conv2d_4': 0.01734805289336404, 'conv2d_5': 0.01819725827975253, 'conv2d_6': 0.019774353997331046, 'conv2d_7': 0.019410408831736035, 'conv2d_8': 0.018925148610942688, 'conv2d_9': 0.021715394880504703, 'conv2d_10': 0.024141695984471707, 'conv2d_11': 0.027417202474827203, 'conv2d_12': 0.03687977678029841, 'conv2d_13': 0.03566662622831491, 'conv2d_14': 0.04440131020259623, 'dense_1': 0.06417566419992728}

# %%
import pickle
save_path = 'C:/Users/320060820/experiments/outputs/Independent_Optimized_Search/Keras CIFAR10/'

with open(save_path + 'scores_b.p', 'wb') as f:
    pickle.dump(b_scores, f)
with open(save_path + 'opt_params_b.p', 'wb') as f:
    pickle.dump(opt_params_biases, f)
with open(save_path + 'acc_drop_b.p', 'wb') as f:
    pickle.dump(acc_drop_b, f)

# %%
save_path = 'C:/Users/320060820/experiments/outputs/Independent_Optimized_Search/Keras CIFAR10/'

with open(save_path + 'scores_a.p', 'wb') as f:
    pickle.dump(a_scores, f)
with open(save_path + 'opt_params_a.p', 'wb') as f:
    pickle.dump(opt_params_act, f)
with open(save_path + 'acc_drop_a.p', 'wb') as f:
    pickle.dump(acc_drop_a, f)
