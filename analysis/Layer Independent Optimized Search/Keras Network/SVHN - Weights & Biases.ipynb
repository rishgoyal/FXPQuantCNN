# %%
import sys
sys.path.append('C:/Users/320060820/experiments/')
import fxp_quantize
import model_data
from algorithms import fixed_bitwidth
from model_gen import keras_cnn
from algorithms.ind_optimized_search import IndependentOptimizedSearch

import keras
import tensorflow as tf
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import itertools

# to restart layer numbering
from keras import backend as K
K.clear_session()
# Out:
# Using TensorFlow backend.

# %%
input_shape = (32, 32, 3)
num_outputs = 10
num_kernels = 32
num_stages = 7
path_trained_weights = 'C:/Users/320060820/experiments/test_models/svhn_keras/svhn_seq_large_w_2.h5'
name = 'svhn_seq_large'
total_acc_drop = 0.005

from test_models.svhn_keras import data
_, test_data = data.get_data()

model_arch = keras_cnn.KerasCNNLarge(input_shape, num_outputs, num_kernels, num_stages, pool_layer_interval = 2, 
                                     path_trained_weights = path_trained_weights)
model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
float_model_acc = model_obj.evaluate_accuracy()[1]
print(float_model_acc)
# Out:
# WARNING:tensorflow:From C:\Users\320060820\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\320060820\Anaconda3\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 0.954479102642901

# %% [markdown]
# ### Weights

# %%
layer_names = []

for layer in model_obj.model.layers:
    if layer.name.startswith('conv2d') or layer.name.startswith('dense'):
        layer_names.append(layer.name)

# %%
# weights
acc_drop_config = {
    layer_name: 0.003 for layer_name in layer_names
}
opts = IndependentOptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc, layer_independent_quant=True)
w_scores, opt_params_weights, acc_drop_w = opts.run('weights', start_bw = 8)
opt_params_weights
# Out:
# {'conv2d_1': [8, 9], 'conv2d_2': [8, 9], 'conv2d_3': [8, 9], 'conv2d_4': [8, 9], 'conv2d_5': [8, 9], 'conv2d_6': [8, 9], 'conv2d_7': [8, 9], 'conv2d_8': [8, 9], 'conv2d_9': [8, 9], 'conv2d_10': [8, 9], 'conv2d_11': [8, 9], 'conv2d_12': [8, 9], 'conv2d_13': [8, 9], 'conv2d_14': [8, 9], 'dense_1': [8, 7]}
# Finding quantization for each layer independently of other layers
# Quantizing layer conv2d_1
# Global opt: (6, 8) Local opt: (7, 9) Performance diff: 0.000443
# Chosen:  (6, 8)
# After quantizing layer conv2d_1 | Measured accuracy drop 0.000644 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_2
# Global opt: (3, 4) Local opt: (3, 4) Performance diff: 0.000000
# Chosen:  (3, 4)
# After quantizing layer conv2d_2 | Measured accuracy drop 0.002777 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_3
# Global opt: (3, 5) Local opt: (3, 5) Performance diff: 0.000000
# Chosen:  (3, 5)
# After quantizing layer conv2d_3 | Measured accuracy drop 0.003622 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_4
# Global opt: (3, 4) Local opt: (3, 4) Performance diff: 0.000000
# Chosen:  (3, 4)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.006439 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_5
# Global opt: (3, 4) Local opt: (4, 5) Performance diff: 0.000885
# Chosen:  (3, 4)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.009901 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_6
# Global opt: (3, 4) Local opt: (3, 4) Performance diff: 0.000000
# Chosen:  (3, 4)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.013523 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_7
# Global opt: (2, 4) Local opt: (3, 5) Performance diff: 0.002938
# Chosen:  (3, 5)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.014287 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_8
# Global opt: (3, 4) Local opt: (3, 5) Performance diff: 0.002254
# Chosen:  (3, 5)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.014851 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_9
# Global opt: (3, 5) Local opt: (4, 6) Performance diff: 0.000080
# Chosen:  (3, 5)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.016219 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_10
# Global opt: (3, 4) Local opt: (3, 5) Performance diff: 0.001690
# Chosen:  (3, 5)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.017467 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_11
# Global opt: (2, 4) Local opt: (3, 5) Performance diff: 0.002455
# Chosen:  (3, 5)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.017829 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_12
# Global opt: (3, 4) Local opt: (4, 5) Performance diff: 0.001650
# Chosen:  (4, 5)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.018473 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_13
# Global opt: (2, 3) Local opt: (2, 3) Performance diff: 0.000000
# Chosen:  (2, 3)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.020123 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_14
# Global opt: (2, 3) Local opt: (2, 4) Performance diff: 0.001972
# Chosen:  (2, 4)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.019922 | Acceptable accuracy drop: 0.003000
# Quantizing layer dense_1
# Global opt: (2, 1) Local opt: (3, 2) Performance diff: 0.001046
# Chosen:  (2, 1)
# After quantizing layer dense_1 | Measured accuracy drop 0.029098 | Acceptable accuracy drop: 0.003000
# {'conv2d_1': (6, 8),
#  'conv2d_2': (3, 4),
#  'conv2d_3': (3, 5),
#  'conv2d_4': (3, 4),
#  'conv2d_5': (3, 4),
#  'conv2d_6': (3, 4),
#  'conv2d_7': (3, 5),
#  'conv2d_8': (3, 5),
#  'conv2d_9': (3, 5),
#  'conv2d_10': (3, 5),
#  'conv2d_11': (3, 5),
#  'conv2d_12': (4, 5),
#  'conv2d_13': (2, 3),
#  'conv2d_14': (2, 4),
#  'dense_1': (2, 1)}

# %%
print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
model_obj = fxp_quantize.fix_weights_quantization(model_obj, opt_params_weights)
fxp_model_acc = model_obj.evaluate_accuracy()[1]
print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

opts.plot_scores_matrix(w_scores, 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 95.448 %
# Quantized model accuracy: 92.671 %
# Accuracy drop of 2.910 %

# %%
for layer in w_scores:
    print(f'Layer {layer} acc drop: {w_scores[layer][opt_params_weights[layer][0]][opt_params_weights[layer][1]]:.5f}')
# Out:
# Layer conv2d_1 acc drop: 0.00064
# Layer conv2d_2 acc drop: -0.00056
# Layer conv2d_3 acc drop: -0.00048
# Layer conv2d_4 acc drop: -0.00052
# Layer conv2d_5 acc drop: 0.00161
# Layer conv2d_6 acc drop: 0.00080
# Layer conv2d_7 acc drop: -0.00008
# Layer conv2d_8 acc drop: 0.00044
# Layer conv2d_9 acc drop: 0.00028
# Layer conv2d_10 acc drop: 0.00117
# Layer conv2d_11 acc drop: 0.00024
# Layer conv2d_12 acc drop: -0.00048
# Layer conv2d_13 acc drop: 0.00028
# Layer conv2d_14 acc drop: -0.00056
# Layer dense_1 acc drop: 0.00237

# %%
x = np.arange(1, len(acc_drop_w.values()) + 1, 1)
y = np.array(list(acc_drop_w.values())) * 100
labels = list(acc_drop_w.keys())

plt.figure(figsize=(10, 7))
plt.plot(x, y, 'o-');
plt.xlabel('Layer Quantized')
plt.ylabel('Accuracy drop compared to float model (%)')
plt.xticks(x, labels, rotation='vertical');
plt.grid()

# %%
import pickle

save_path = 'C:/Users/320060820/experiments/outputs/Independent_Optimized_Search/Keras SVHN/'

with open(save_path + 'scores_w.p', 'wb') as f:
    pickle.dump(w_scores, f)
with open(save_path + 'opt_params_w.p', 'wb') as f:
    pickle.dump(opt_params_weights, f)
with open(save_path + 'acc_drop_w.p', 'wb') as f:
    pickle.dump(acc_drop_w, f)

# %% [markdown]
# ### Biases

# %%
# biases
acc_drop_config = {
    layer_name: 0.003 for layer_name in layer_names
}
opts = IndependentOptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc, layer_independent_quant=True)
b_scores, opt_params_biases, acc_drop_b = opts.run('biases', start_bw = 8)
opt_params_biases
# Out:
# {'conv2d_1': [8, 11], 'conv2d_2': [8, 10], 'conv2d_3': [8, 10], 'conv2d_4': [8, 10], 'conv2d_5': [8, 10], 'conv2d_6': [8, 10], 'conv2d_7': [8, 10], 'conv2d_8': [8, 10], 'conv2d_9': [8, 9], 'conv2d_10': [8, 10], 'conv2d_11': [8, 9], 'conv2d_12': [8, 9], 'conv2d_13': [8, 10], 'conv2d_14': [8, 9], 'dense_1': [8, 9]}
# Finding quantization for each layer independently of other layers
# Quantizing layer conv2d_1
# Global opt: (2, 5) Local opt: (3, 5) Performance diff: 0.004669
# Chosen:  (3, 5)
# After quantizing layer conv2d_1 | Measured accuracy drop -0.002737 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_2
# Global opt: (1, 3) Local opt: (1, 2) Performance diff: 0.000000
# Chosen:  (1, 2)
# After quantizing layer conv2d_2 | Measured accuracy drop -0.002777 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_3
# Global opt: (1, 3) Local opt: (2, 4) Performance diff: 0.000241
# Chosen:  (1, 3)
# After quantizing layer conv2d_3 | Measured accuracy drop -0.002334 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_4
# Global opt: (1, 3) Local opt: (1, 2) Performance diff: 0.000000
# Chosen:  (1, 2)
# After quantizing layer conv2d_4 | Measured accuracy drop -0.002656 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_5
# Global opt: (1, 3) Local opt: (2, 4) Performance diff: 0.000161
# Chosen:  (1, 3)
# After quantizing layer conv2d_5 | Measured accuracy drop -0.002697 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_6
# Global opt: (1, 3) Local opt: (2, 3) Performance diff: 0.000523
# Chosen:  (1, 3)
# After quantizing layer conv2d_6 | Measured accuracy drop -0.002294 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_7
# Global opt: (1, 3) Local opt: (2, 4) Performance diff: 0.000885
# Chosen:  (1, 3)
# After quantizing layer conv2d_7 | Measured accuracy drop -0.001610 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_8
# Global opt: (1, 3) Local opt: (2, 3) Performance diff: 0.000523
# Chosen:  (1, 3)
# After quantizing layer conv2d_8 | Measured accuracy drop -0.001288 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_9
# Global opt: (1, 2) Local opt: (2, 3) Performance diff: 0.000121
# Chosen:  (1, 2)
# After quantizing layer conv2d_9 | Measured accuracy drop -0.001127 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_10
# Global opt: (1, 3) Local opt: (2, 3) Performance diff: 0.000563
# Chosen:  (1, 3)
# After quantizing layer conv2d_10 | Measured accuracy drop -0.000805 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_11
# Global opt: (1, 2) Local opt: (2, 3) Performance diff: 0.000765
# Chosen:  (1, 2)
# After quantizing layer conv2d_11 | Measured accuracy drop -0.000040 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_12
# Global opt: (1, 2) Local opt: (2, 2) Performance diff: 0.000121
# Chosen:  (1, 2)
# After quantizing layer conv2d_12 | Measured accuracy drop -0.000241 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_13
# Global opt: (1, 3) Local opt: (1, 2) Performance diff: 0.000000
# Chosen:  (1, 2)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.000080 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_14
# Global opt: (1, 2) Local opt: (2, 2) Performance diff: 0.000040
# Chosen:  (1, 2)
# After quantizing layer conv2d_14 | Measured accuracy drop -0.000121 | Acceptable accuracy drop: 0.003000
# Quantizing layer dense_1
# Global opt: (1, 2) Local opt: (2, 3) Performance diff: 0.000362
# Chosen:  (1, 2)
# After quantizing layer dense_1 | Measured accuracy drop -0.000080 | Acceptable accuracy drop: 0.003000
# {'conv2d_1': (3, 5),
#  'conv2d_2': (1, 2),
#  'conv2d_3': (1, 3),
#  'conv2d_4': (1, 2),
#  'conv2d_5': (1, 3),
#  'conv2d_6': (1, 3),
#  'conv2d_7': (1, 3),
#  'conv2d_8': (1, 3),
#  'conv2d_9': (1, 2),
#  'conv2d_10': (1, 3),
#  'conv2d_11': (1, 2),
#  'conv2d_12': (1, 2),
#  'conv2d_13': (1, 2),
#  'conv2d_14': (1, 2),
#  'dense_1': (1, 2)}

# %%
print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

model_obj = model_data.Model(name, test_data, model=model_arch.get_float_model())
model_obj = fxp_quantize.fix_biases_quantization(model_obj, opt_params_biases)
fxp_model_acc = model_obj.evaluate_accuracy()[1]
print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

opts.plot_scores_matrix(b_scores, 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 95.448 %
# Quantized model accuracy: 95.456 %
# Accuracy drop of -0.008 %

# %%
for layer in b_scores:
    print(f'Layer {layer} acc drop: {b_scores[layer][opt_params_biases[layer][0]][opt_params_biases[layer][1]]:.5f}')
# Out:
# Layer conv2d_1 acc drop: -0.00274
# Layer conv2d_2 acc drop: -0.00016
# Layer conv2d_3 acc drop: 0.00024
# Layer conv2d_4 acc drop: -0.00028
# Layer conv2d_5 acc drop: 0.00012
# Layer conv2d_6 acc drop: 0.00040
# Layer conv2d_7 acc drop: 0.00076
# Layer conv2d_8 acc drop: 0.00040
# Layer conv2d_9 acc drop: 0.00000
# Layer conv2d_10 acc drop: 0.00032
# Layer conv2d_11 acc drop: 0.00024
# Layer conv2d_12 acc drop: 0.00024
# Layer conv2d_13 acc drop: -0.00004
# Layer conv2d_14 acc drop: -0.00028
# Layer dense_1 acc drop: 0.00032

# %%
x = np.arange(1, len(acc_drop_b.values()) + 1, 1)
y = np.array(list(acc_drop_b.values())) * 100
labels = list(acc_drop_b.keys())

plt.figure(figsize=(10, 7))
plt.plot(x, y, 'o-');
plt.xlabel('Layer Quantized')
plt.ylabel('Accuracy drop compared to float model (%)')
plt.xticks(x, labels, rotation='vertical');
plt.grid()

# %% [markdown]
# ### Activations

# %%
# activations
acc_drop_config = {
    layer_name: 0.003 for layer_name in layer_names
}
opts = IndependentOptimizedSearch(acc_drop_config, model_arch, name, test_data, float_model_acc, layer_independent_quant=True)
a_scores, opt_params_act, acc_drop_a = opts.run('activations', start_bw = 8)
opt_params_act
# Out:
# {'conv2d_1': [8, 8], 'conv2d_2': [8, 3], 'conv2d_3': [8, 3], 'conv2d_4': [8, 3], 'conv2d_5': [8, 2], 'conv2d_6': [8, 3], 'conv2d_7': [8, 3], 'conv2d_8': [8, 3], 'conv2d_9': [8, 2], 'conv2d_10': [8, 3], 'conv2d_11': [8, 3], 'conv2d_12': [8, 3], 'conv2d_13': [8, 2], 'conv2d_14': [8, 3], 'dense_1': [8, 2]}
# Finding quantization for each layer independently of other layers
# Quantizing layer conv2d_1
# Global opt: (4, 5) Local opt: (5, 6) Performance diff: 0.002455
# Chosen:  (5, 6)
# After quantizing layer conv2d_1 | Measured accuracy drop 0.000282 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_2
# Global opt: (3, 1) Local opt: (4, 1) Performance diff: 0.002938
# Chosen:  (4, 1)
# After quantizing layer conv2d_2 | Measured accuracy drop 0.000644 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_3
# Global opt: (4, 0) Local opt: (5, 1) Performance diff: 0.001248
# Chosen:  (4, 0)
# After quantizing layer conv2d_3 | Measured accuracy drop 0.002817 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_4
# Global opt: (3, -1) Local opt: (4, 0) Performance diff: 0.002415
# Chosen:  (4, 0)
# After quantizing layer conv2d_4 | Measured accuracy drop 0.002857 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_5
# Global opt: (3, -1) Local opt: (4, 0) Performance diff: 0.001127
# Chosen:  (3, -1)
# After quantizing layer conv2d_5 | Measured accuracy drop 0.005755 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_6
# Global opt: (4, 0) Local opt: (5, 1) Performance diff: 0.000523
# Chosen:  (4, 0)
# After quantizing layer conv2d_6 | Measured accuracy drop 0.006560 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_7
# Global opt: (3, 0) Local opt: (4, 1) Performance diff: 0.001811
# Chosen:  (4, 1)
# After quantizing layer conv2d_7 | Measured accuracy drop 0.006842 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_8
# Global opt: (4, 0) Local opt: (5, 0) Performance diff: 0.000282
# Chosen:  (4, 0)
# After quantizing layer conv2d_8 | Measured accuracy drop 0.006641 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_9
# Global opt: (3, -2) Local opt: (4, -1) Performance diff: 0.001731
# Chosen:  (4, -1)
# After quantizing layer conv2d_9 | Measured accuracy drop 0.008130 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_10
# Global opt: (4, 0) Local opt: (5, 1) Performance diff: 0.000483
# Chosen:  (4, 0)
# After quantizing layer conv2d_10 | Measured accuracy drop 0.008572 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_11
# Global opt: (3, -1) Local opt: (4, 0) Performance diff: 0.000805
# Chosen:  (3, -1)
# After quantizing layer conv2d_11 | Measured accuracy drop 0.010464 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_12
# Global opt: (3, -1) Local opt: (4, 0) Performance diff: 0.001006
# Chosen:  (3, -1)
# After quantizing layer conv2d_12 | Measured accuracy drop 0.013241 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_13
# Global opt: (2, -2) Local opt: (3, -1) Performance diff: 0.002415
# Chosen:  (3, -1)
# After quantizing layer conv2d_13 | Measured accuracy drop 0.014167 | Acceptable accuracy drop: 0.003000
# Quantizing layer conv2d_14
# Global opt: (2, -1) Local opt: (3, -1) Performance diff: 0.000644
# Chosen:  (2, -1)
# After quantizing layer conv2d_14 | Measured accuracy drop 0.018634 | Acceptable accuracy drop: 0.003000
# Quantizing layer dense_1
# Global opt: (3, -1) Local opt: (4, 0) Performance diff: 0.001690
# Chosen:  (4, 0)
# After quantizing layer dense_1 | Measured accuracy drop 0.019197 | Acceptable accuracy drop: 0.003000
# {'conv2d_1': (5, 6),
#  'conv2d_2': (4, 1),
#  'conv2d_3': (4, 0),
#  'conv2d_4': (4, 0),
#  'conv2d_5': (3, -1),
#  'conv2d_6': (4, 0),
#  'conv2d_7': (4, 1),
#  'conv2d_8': (4, 0),
#  'conv2d_9': (4, -1),
#  'conv2d_10': (4, 0),
#  'conv2d_11': (3, -1),
#  'conv2d_12': (3, -1),
#  'conv2d_13': (3, -1),
#  'conv2d_14': (2, -1),
#  'dense_1': (4, 0)}

# %%
print(f'Floating point model accuracy: {float_model_acc * 100 :.3f} %')

model_obj = model_data.Model(name, test_data, model=model_arch.get_fxp_model(opt_params_act))
fxp_model_acc = model_obj.evaluate_accuracy()[1]
print(f'Quantized model accuracy: {fxp_model_acc * 100 :.3f} %')
print(f'Accuracy drop of {(float_model_acc - fxp_model_acc) / float_model_acc * 100 :.3f} %')

opts.plot_scores_matrix(a_scores, 5, 3, (20, 30))
# Out:
# Floating point model accuracy: 95.448 %
# Quantized model accuracy: 93.616 %
# Accuracy drop of 1.920 %

# %%
for layer in a_scores:
    print(f'Layer {layer} acc drop: {a_scores[layer][opt_params_act[layer][0]][opt_params_act[layer][1]]:.5f}')
# Out:
# Layer conv2d_1 acc drop: 0.00028
# Layer conv2d_2 acc drop: -0.00044
# Layer conv2d_3 acc drop: 0.00145
# Layer conv2d_4 acc drop: -0.00028
# Layer conv2d_5 acc drop: 0.00193
# Layer conv2d_6 acc drop: 0.00113
# Layer conv2d_7 acc drop: 0.00044
# Layer conv2d_8 acc drop: 0.00048
# Layer conv2d_9 acc drop: 0.00052
# Layer conv2d_10 acc drop: 0.00105
# Layer conv2d_11 acc drop: 0.00064
# Layer conv2d_12 acc drop: 0.00133
# Layer conv2d_13 acc drop: 0.00036
# Layer conv2d_14 acc drop: 0.00161
# Layer dense_1 acc drop: 0.00044

# %%
x = np.arange(1, len(acc_drop_a.values()) + 1, 1)
y = np.array(list(acc_drop_a.values())) * 100
labels = list(acc_drop_a.keys())

plt.figure(figsize=(10, 7))
plt.plot(x, y, 'o-');
plt.xlabel('Layer Quantized')
plt.ylabel('Accuracy drop compared to float model (%)')
plt.xticks(x, labels, rotation='vertical');
plt.grid()

# %%
import pickle
save_path = 'C:/Users/320060820/experiments/outputs/Independent_Optimized_Search/Keras SVHN/'

# %%
with open(save_path + 'opt_params_w.p', 'rb') as f:
    opt_params_weights = pickle.load(f)

# %%
def quantize_evaluate(model_arch, test_data, float_model_acc, w_quant_params, b_quant_params={}, a_quant_params={}):
    
    if a_quant_params:
        model_obj = model_data.Model('name', test_data, model=model_arch.get_fxp_model(a_quant_params))
    else:
        model_obj = model_data.Model('name', test_data, model=model_arch.get_float_model())
    
    model_obj = fxp_quantize.fix_weights_quantization(model_obj, w_quant_params)
    if b_quant_params:
        model_obj = fxp_quantize.fix_biases_quantization(model_obj, b_quant_params)
    
    return (float_model_acc - model_obj.evaluate_accuracy()[1]) / float_model_acc

# %%
def evaluate_seq_quant_performance(model_arch, test_data, float_model_acc, w_quant_params, b_quant_params, a_quant_params):
    
    acc_drop_b = {}
    for i in range(1, len(list(b_quant_params.keys())) + 1):
        test_case = dict(itertools.islice(b_quant_params.items(), i))
        a = quantize_evaluate(model_arch, test_data, float_model_acc, w_quant_params, test_case)
        acc_drop_b[list(test_case.keys())[-1]] = a
        print(acc_drop_b)

    acc_drop_a = {}
    for i in range(1, len(list(a_quant_params.keys())) + 1):
        test_case = dict(itertools.islice(a_quant_params.items(), i))
        a = quantize_evaluate(model_arch, test_data, float_model_acc, w_quant_params, b_quant_params, test_case)
        acc_drop_a[list(test_case.keys())[-1]] = a
        print(acc_drop_a)
        
    return acc_drop_b, acc_drop_a

# %%
acc_drop_b, acc_drop_a = evaluate_seq_quant_performance(model_arch, test_data, float_model_acc, opt_params_weights, 
                                            opt_params_biases,
                                            opt_params_act)
# Out:
# {'conv2d_1': 0.03618143035376509}
# {'conv2d_1': 0.03618143035376509, 'conv2d_2': 0.03626192296856765}
# {'conv2d_1': 0.03618143035376509, 'conv2d_2': 0.03626192296856765, 'conv2d_3': 0.03674487865738314}
# {'conv2d_1': 0.03618143035376509, 'conv2d_2': 0.03626192296856765, 'conv2d_3': 0.03674487865738314, 'conv2d_4': 0.037429065883205215}
# {'conv2d_1': 0.03618143035376509, 'conv2d_2': 0.03626192296856765, 'conv2d_3': 0.03674487865738314, 'conv2d_4': 0.037429065883205215, 'conv2d_5': 0.03666438604258058}
# {'conv2d_1': 0.03618143035376509, 'conv2d_2': 0.03626192296856765, 'conv2d_3': 0.03674487865738314, 'conv2d_4': 0.037429065883205215, 'conv2d_5': 0.03666438604258058, 'conv2d_6': 0.03654364712037668}
# {'conv2d_1': 0.03618143035376509, 'conv2d_2': 0.03626192296856765, 'conv2d_3': 0.03674487865738314, 'conv2d_4': 0.037429065883205215, 'conv2d_5': 0.03666438604258058, 'conv2d_6': 0.03654364712037668, 'conv2d_7': 0.036583893427778014}
# {'conv2d_1': 0.03618143035376509, 'conv2d_2': 0.03626192296856765, 'conv2d_3': 0.03674487865738314, 'conv2d_4': 0.037429065883205215, 'conv2d_5': 0.03666438604258058, 'conv2d_6': 0.03654364712037668, 'conv2d_7': 0.036583893427778014, 'conv2d_8': 0.03714734173139619}
# {'conv2d_1': 0.03618143035376509, 'conv2d_2': 0.03626192296856765, 'conv2d_3': 0.03674487865738314, 'conv2d_4': 0.037429065883205215, 'conv2d_5': 0.03666438604258058, 'conv2d_6': 0.03654364712037668, 'conv2d_7': 0.036583893427778014, 'conv2d_8': 0.03714734173139619, 'conv2d_9': 0.03722783434619875}
# {'conv2d_1': 0.03618143035376509, 'conv2d_2': 0.03626192296856765, 'conv2d_3': 0.03674487865738314, 'conv2d_4': 0.037429065883205215, 'conv2d_5': 0.03666438604258058, 'conv2d_6': 0.03654364712037668, 'conv2d_7': 0.036583893427778014, 'conv2d_8': 0.03714734173139619, 'conv2d_9': 0.03722783434619875, 'conv2d_10': 0.036785124964784484}
# {'conv2d_1': 0.03618143035376509, 'conv2d_2': 0.03626192296856765, 'conv2d_3': 0.03674487865738314, 'conv2d_4': 0.037429065883205215, 'conv2d_5': 0.03666438604258058, 'conv2d_6': 0.03654364712037668, 'conv2d_7': 0.036583893427778014, 'conv2d_8': 0.03714734173139619, 'conv2d_9': 0.03722783434619875, 'conv2d_10': 0.036785124964784484, 'conv2d_11': 0.03779128264981692}
# {'conv2d_1': 0.03618143035376509, 'conv2d_2': 0.03626192296856765, 'conv2d_3': 0.03674487865738314, 'conv2d_4': 0.037429065883205215, 'conv2d_5': 0.03666438604258058, 'conv2d_6': 0.03654364712037668, 'conv2d_7': 0.036583893427778014, 'conv2d_8': 0.03714734173139619, 'conv2d_9': 0.03722783434619875, 'conv2d_10': 0.036785124964784484, 'conv2d_11': 0.03779128264981692, 'conv2d_12': 0.0392401497162635}
# {'conv2d_1': 0.03618143035376509, 'conv2d_2': 0.03626192296856765, 'conv2d_3': 0.03674487865738314, 'conv2d_4': 0.037429065883205215, 'conv2d_5': 0.03666438604258058, 'conv2d_6': 0.03654364712037668, 'conv2d_7': 0.036583893427778014, 'conv2d_8': 0.03714734173139619, 'conv2d_9': 0.03722783434619875, 'conv2d_10': 0.036785124964784484, 'conv2d_11': 0.03779128264981692, 'conv2d_12': 0.0392401497162635, 'conv2d_13': 0.0391194107940596}
# {'conv2d_1': 0.03618143035376509, 'conv2d_2': 0.03626192296856765, 'conv2d_3': 0.03674487865738314, 'conv2d_4': 0.037429065883205215, 'conv2d_5': 0.03666438604258058, 'conv2d_6': 0.03654364712037668, 'conv2d_7': 0.036583893427778014, 'conv2d_8': 0.03714734173139619, 'conv2d_9': 0.03722783434619875, 'conv2d_10': 0.036785124964784484, 'conv2d_11': 0.03779128264981692, 'conv2d_12': 0.0392401497162635, 'conv2d_13': 0.0391194107940596, 'conv2d_14': 0.039320642331066066}
# {'conv2d_1': 0.03618143035376509, 'conv2d_2': 0.03626192296856765, 'conv2d_3': 0.03674487865738314, 'conv2d_4': 0.037429065883205215, 'conv2d_5': 0.03666438604258058, 'conv2d_6': 0.03654364712037668, 'conv2d_7': 0.036583893427778014, 'conv2d_8': 0.03714734173139619, 'conv2d_9': 0.03722783434619875, 'conv2d_10': 0.036785124964784484, 'conv2d_11': 0.03779128264981692, 'conv2d_12': 0.0392401497162635, 'conv2d_13': 0.0391194107940596, 'conv2d_14': 0.039320642331066066, 'dense_1': 0.03907916448665838}
# {'conv2d_1': 0.03855596249044144}
# {'conv2d_1': 0.03855596249044144, 'conv2d_2': 0.038998671871855704}
# {'conv2d_1': 0.03855596249044144, 'conv2d_2': 0.038998671871855704, 'conv2d_3': 0.04318428784159057}
# {'conv2d_1': 0.03855596249044144, 'conv2d_2': 0.038998671871855704, 'conv2d_3': 0.04318428784159057, 'conv2d_4': 0.04555881997826703}
# {'conv2d_1': 0.03855596249044144, 'conv2d_2': 0.038998671871855704, 'conv2d_3': 0.04318428784159057, 'conv2d_4': 0.04555881997826703, 'conv2d_5': 0.04942246548879142}
# {'conv2d_1': 0.03855596249044144, 'conv2d_2': 0.038998671871855704, 'conv2d_3': 0.04318428784159057, 'conv2d_4': 0.04555881997826703, 'conv2d_5': 0.04942246548879142, 'conv2d_6': 0.05421177606954557}
# {'conv2d_1': 0.03855596249044144, 'conv2d_2': 0.038998671871855704, 'conv2d_3': 0.04318428784159057, 'conv2d_4': 0.04555881997826703, 'conv2d_5': 0.04942246548879142, 'conv2d_6': 0.05421177606954557, 'conv2d_7': 0.054332514991749466}
# {'conv2d_1': 0.03855596249044144, 'conv2d_2': 0.038998671871855704, 'conv2d_3': 0.04318428784159057, 'conv2d_4': 0.04555881997826703, 'conv2d_5': 0.04942246548879142, 'conv2d_6': 0.05421177606954557, 'conv2d_7': 0.054332514991749466, 'conv2d_8': 0.0548557169879663}
# {'conv2d_1': 0.03855596249044144, 'conv2d_2': 0.038998671871855704, 'conv2d_3': 0.04318428784159057, 'conv2d_4': 0.04555881997826703, 'conv2d_5': 0.04942246548879142, 'conv2d_6': 0.05421177606954557, 'conv2d_7': 0.054332514991749466, 'conv2d_8': 0.0548557169879663, 'conv2d_9': 0.05831689942447776}
# {'conv2d_1': 0.03855596249044144, 'conv2d_2': 0.038998671871855704, 'conv2d_3': 0.04318428784159057, 'conv2d_4': 0.04555881997826703, 'conv2d_5': 0.04942246548879142, 'conv2d_6': 0.05421177606954557, 'conv2d_7': 0.054332514991749466, 'conv2d_8': 0.0548557169879663, 'conv2d_9': 0.05831689942447776, 'conv2d_10': 0.06519901799009946}
# {'conv2d_1': 0.03855596249044144, 'conv2d_2': 0.038998671871855704, 'conv2d_3': 0.04318428784159057, 'conv2d_4': 0.04555881997826703, 'conv2d_5': 0.04942246548879142, 'conv2d_6': 0.05421177606954557, 'conv2d_7': 0.054332514991749466, 'conv2d_8': 0.0548557169879663, 'conv2d_9': 0.05831689942447776, 'conv2d_10': 0.06519901799009946, 'conv2d_11': 0.07799734374371152}
# {'conv2d_1': 0.03855596249044144, 'conv2d_2': 0.038998671871855704, 'conv2d_3': 0.04318428784159057, 'conv2d_4': 0.04555881997826703, 'conv2d_5': 0.04942246548879142, 'conv2d_6': 0.05421177606954557, 'conv2d_7': 0.054332514991749466, 'conv2d_8': 0.0548557169879663, 'conv2d_9': 0.05831689942447776, 'conv2d_10': 0.06519901799009946, 'conv2d_11': 0.07799734374371152, 'conv2d_12': 0.08423552139091237}
# {'conv2d_1': 0.03855596249044144, 'conv2d_2': 0.038998671871855704, 'conv2d_3': 0.04318428784159057, 'conv2d_4': 0.04555881997826703, 'conv2d_5': 0.04942246548879142, 'conv2d_6': 0.05421177606954557, 'conv2d_7': 0.054332514991749466, 'conv2d_8': 0.0548557169879663, 'conv2d_9': 0.05831689942447776, 'conv2d_10': 0.06519901799009946, 'conv2d_11': 0.07799734374371152, 'conv2d_12': 0.08423552139091237, 'conv2d_13': 0.09176158087495467}
# {'conv2d_1': 0.03855596249044144, 'conv2d_2': 0.038998671871855704, 'conv2d_3': 0.04318428784159057, 'conv2d_4': 0.04555881997826703, 'conv2d_5': 0.04942246548879142, 'conv2d_6': 0.05421177606954557, 'conv2d_7': 0.054332514991749466, 'conv2d_8': 0.0548557169879663, 'conv2d_9': 0.05831689942447776, 'conv2d_10': 0.06519901799009946, 'conv2d_11': 0.07799734374371152, 'conv2d_12': 0.08423552139091237, 'conv2d_13': 0.09176158087495467, 'conv2d_14': 0.1124884291866221}
# {'conv2d_1': 0.03855596249044144, 'conv2d_2': 0.038998671871855704, 'conv2d_3': 0.04318428784159057, 'conv2d_4': 0.04555881997826703, 'conv2d_5': 0.04942246548879142, 'conv2d_6': 0.05421177606954557, 'conv2d_7': 0.054332514991749466, 'conv2d_8': 0.0548557169879663, 'conv2d_9': 0.05831689942447776, 'conv2d_10': 0.06519901799009946, 'conv2d_11': 0.07799734374371152, 'conv2d_12': 0.08423552139091237, 'conv2d_13': 0.09176158087495467, 'conv2d_14': 0.1124884291866221, 'dense_1': 0.11607035054533746}

# %%
with open(save_path + 'scores_b.p', 'wb') as f:
    pickle.dump(b_scores, f)
with open(save_path + 'opt_params_b.p', 'wb') as f:
    pickle.dump(opt_params_biases, f)
with open(save_path + 'acc_drop_b.p', 'wb') as f:
    pickle.dump(acc_drop_b, f)

# %%
with open(save_path + 'scores_a.p', 'wb') as f:
    pickle.dump(a_scores, f)
with open(save_path + 'opt_params_a.p', 'wb') as f:
    pickle.dump(opt_params_act, f)
with open(save_path + 'acc_drop_a.p', 'wb') as f:
    pickle.dump(acc_drop_a, f)
